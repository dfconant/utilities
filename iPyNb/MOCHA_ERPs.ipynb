# %%
from scipy.io import loadmat
from ecog_viz import plotERPs, load_anatomy

# %%
pth = "/Users/david_conant/Documents/MOCHA_61/"

# %%
tokens = ['aa','ae','ah','eh','er','ih','iy','uh','uw']
Es = []
for ind,t in enumerate(tokens):
    tmp = loadmat(pth + t + '_trails.mat')
    Es.append(tmp['D'])

anat = load_anatomy(pth)
plotERPs(Es, align_window = np.array([-1, 1]), yscale='shared', anatomy = anat, labels = tokens)
# Out:
#  [                       0%                       ]
#  [                       1%                       ]  2 of 256 complete
#  [                       1%                       ]  3 of 256 complete
#  [*                      2%                       ]  4 of 256 complete
#  [*                      2%                       ]  5 of 256 complete
#  [*                      2%                       ]  6 of 256 complete
#  [*                      3%                       ]  7 of 256 complete
#  [*                      3%                       ]  8 of 256 complete
#  [**                     4%                       ]  9 of 256 complete
#  [**                     4%                       ]  10 of 256 complete
#  [**                     4%                       ]  11 of 256 complete
#  [**                     5%                       ]  12 of 256 complete
#  [**                     5%                       ]  13 of 256 complete
# ...

# %%
plotERPs(Es, align_window = np.array([-1, 1]), yscale='shared', 
         anatomy = anat, labels = tokens, elects=[185,186,187,168,169,171,172,173,151,152,134,135,136,137,118,119,120])
# Out:
#  [                       0%                       ]
#  [******                12%                       ]  2 of 17 complete
#  [*********             18%                       ]  3 of 17 complete
#  [************          24%                       ]  4 of 17 complete
#  [**************        29%                       ]  5 of 17 complete
#  [*****************     35%                       ]  6 of 17 complete
#  [********************  41%                       ]  7 of 17 complete
#  [**********************47%                       ]  8 of 17 complete
#  [**********************53%                       ]  9 of 17 complete
#  [**********************59%***                    ]  10 of 17 complete
#  [**********************65%******                 ]  11 of 17 complete
#  [**********************71%*********              ]  12 of 17 complete
#  [**********************76%***********            ]  13 of 17 complete
#  [**********************82%**************         ]  14 of 17 complete
# ...

# %%
# Out:
# (201, 894)
