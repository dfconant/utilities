# %%
# %load_ext autoreload
# %autoreload 2
from ECoGstats import makeD_multi, smooth_formants, smooth_warp_formants, process_kin, subtract_baseline, SemiPartialCorrelation
import seaborn as sns
import prettyplotlib as ppl
from matplotlib.backends.backend_agg import (FigureCanvasAgg as FigureCanvas)
from scipy.signal import savgol_filter
import pandas as pd
from BDutils import ProgressBar, resample_array, smart_toeplitz, smooth_derivative,seq_labels,partial_corr
from ecog_viz import plotWeights, gestural_score, plotERPs, set_style_black
from sklearn.cross_validation import train_test_split
from sklearn.decomposition import PCA
from sklearn.lda import LDA
from sklearn.linear_model import Ridge
import scipy as sp
from IPython.display import Image
import scipy.stats as stats
import matplotlib.gridspec as gridspec
import numpy as np
import matplotlib.pyplot as plt
import VisEcog
import imaging
import os
import matplotlib.image as mpimg
import brewer2mpl
import re
import pdb
set_style_black()
pth = '/Users/david_conant/Dropbox/Vowels/Figs
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ###Trace Comparisons

# %%
subj='EC41'
blocks = [19,20,22,27]
pth = '/Users/david_conant/Dropbox/Vowels/'+subj + '/'

tokens = ['AAA','IYY','UWW','AEE','AHH','EHH','ERR','IHH','UHH']
#tokens = ['HAWED','HEED','WHOOD','HAD','HUD','HEAD','HEARD','HID','HOOD']
kfeats = ['kFrontTongueX','kFMidTongueX','kMidTongueX','kBMidTongueX','kBackTongueX','kFrontTongueY','kFMidTongueY','kMidTongueY',
          'kBMidTongueY','kBackTongueY','kLipOpening','kLipWidth','kJawX','kJawY']
efeats = seq_labels('e',256)
fs = 100
#Load in Dmatrices

#Electrodes
window = np.array([-1,1])   #TODO: try wider window for more timepoints
[E,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='HG')
Es = [E[d] for d in tokens]
vSMC = np.concatenate((np.where(anat=='preCG')[0],np.where(anat=='postCG')[0]),87)
vSMC_logic = np.zeros(256,dtype=bool)
vSMC_logic[vSMC] = True
Eall = np.concatenate(Es,axis=2)
Eall_norm = subtract_baseline(Eall)
# Out:
# File found; Loading...
# Loaded
# >
#  /Users/david_conant/Dropbox/changrepo/python/datautils/ECoGstats.py(1086)subtract_baseline()
# -> return Dout
# (Pdb) baseline[2,:,2]
# array([ 0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445,
#         0.62104445,  0.62104445,  0.62104445,  0.62104445,  0.62104445])
# (Pdb) baseline[:,2,2]
# array([             nan,   6.39147777e-01,   6.21044446e-01,
#          9.34776294e-01,  -1.78615811e-01,   4.85365396e-01,
#         -8.05427799e-01,   3.61565017e-01,   1.32560105e+00,
#          1.19609964e+00,  -1.21272424e+00,  -6.91420259e-01,
#         -3.17099703e-01,  -4.32716941e-01,   5.74712944e-01,
#          1.99357831e+00,              nan,  -1.28641043e+00,
#         -4.14812541e-02,   8.06539584e-01,   9.04920635e-01,
#         -2.84322122e-01,  -5.95464796e-02,  -9.49531595e-02,
#         -1.68561829e+00,  -2.83858119e-01,  -8.64102530e-01,
#          7.47707595e-04,  -9.24321884e-02,  -2.13922178e-01,
#          6.10388468e-03,   2.14993090e+00,              nan,
#          3.60584697e-01,  -7.77053231e-02,   1.65545015e-01,
#         -3.10837763e-01,  -7.77154716e-01,  -2.93524842e-01,
#          5.32964953e-02,  -5.98386495e-01,  -1.56347254e-01,
#          5.22360338e-01,  -6.52498923e-01,   2.28288701e-01,
#         -2.95272564e-01,  -1.01140451e-01,  -5.24900320e-01,
#         -9.00657988e-01,   4.48125840e-02,  -5.59330472e-02,
#         -3.21343417e-01,   3.47950852e-01,   5.88632270e-01,
#          4.90768438e-01,  -6.62545446e-02,   5.31918601e-01,
#         -1.09729295e+00,   7.32901139e-02,  -1.10658683e-01,
#         -1.19300756e-02,   6.57159699e-01,  -1.82126682e-01,
#         -3.82544921e-01,  -5.93285819e-01,  -6.28623170e-01,
#         -6.60658012e-01,  -5.52758240e-01,  -5.03726566e-01,
#         -5.52005653e-01,  -9.72164032e-02,  -1.23025820e-01,
#         -3.47118115e-01,  -3.29352299e-01,  -1.21001676e+00,
#         -1.60858919e-01,  -9.60165136e-02,   5.71034078e-02,
#         -1.89217348e-01,   1.00266676e+00,   2.63442423e-01,
#         -2.23745441e-01,   1.60348460e-01,   1.56912330e-01,
#          3.97581340e-01,   4.39024111e-01,  -3.08290183e-01,
#         -7.34610123e-02,  -2.93324133e-01,   3.23669438e-01,
#          4.06167721e-02,  -3.88022002e-02,              nan,
#         -7.05661333e-01,  -5.96209088e-01,  -7.14122354e-01,
#          2.18530956e-01,  -9.92123125e-01,  -1.03093067e+00,
#          1.30204171e-01,  -8.12518806e-02,  -5.59418691e-01,
#          6.70370897e-01,  -5.53586612e-01,  -2.68888353e-01,
#          1.17591053e+00,  -1.47590761e-01,   4.66713083e-01,
#          9.39343627e-02,  -6.47957891e-01,  -1.34885744e-01,
#         -6.59280130e-01,  -3.92981320e-01,  -1.75027498e-01,
#         -2.58732111e-01,  -8.74823742e-02,   5.80204547e-01,
#         -4.92604506e-01,  -1.25979651e-01,   7.00107382e-01,
#         -9.45210531e-01,  -4.75093729e-01,  -7.81646542e-01,
#         -7.48881382e-03,  -3.11953011e-01,   5.94446247e-01,
#         -9.44059014e-02,  -5.76548223e-01,  -9.11116570e-01,
#         -3.31087531e-01,   1.87579602e-01,   1.47226240e+00,
#          6.44138779e-01,   1.59682827e-01,   2.40260666e-02,
#         -3.50266611e-03,  -4.55825269e-01,   6.00857958e-02,
#         -9.58988017e-01,  -2.73079424e-01,   2.43087660e-01,
#         -8.02819796e-01,   2.65974205e+00,   1.45923093e+00,
#                     nan,              nan,   7.57092449e-02,
#          6.80426169e-02,   1.18912452e-01,   1.48251408e+00,
#          9.07226326e-01,   3.27150934e-01,  -3.42925171e-01,
#         -5.12736605e-01,  -5.80563761e-01,  -1.97043251e-01,
#          2.06838180e-01,   3.65867068e-01,   2.23987871e+00,
#          1.08300741e+00,              nan,              nan,
#                     nan,   2.30396909e-01,   7.47735190e-01,
#         -6.54803974e-01,  -1.29169559e-01,  -5.34088242e-01,
#         -1.65820739e-01,   1.66334919e-01,   3.44643176e-02,
#         -4.46977983e-01,  -1.11231805e-01,   2.67289459e-01,
#         -2.86558028e-01,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,  -3.84015171e-01,
#          5.39893176e-02,   8.61289247e-04,  -1.76785988e-01,
#          2.01799849e-01,              nan,              nan,
#                     nan,   5.80719028e-02,   1.14637268e+00,
#          1.10946424e+00,  -1.39090557e-01,  -7.29314804e-01,
#         -2.43016364e-01,  -4.75124528e-02,              nan,
#         -1.39492274e-01,   7.05020142e-01,  -4.63770098e-02,
#          6.19051481e-01,   2.21248621e-01,              nan,
#                     nan,              nan,   9.14070659e-01,
#          3.66205598e-01,  -3.37680321e-01,  -3.79335771e-01,
#          2.25194442e-01,   9.36186243e-02,  -6.10534755e-02,
#          4.72776288e-01,  -5.72407434e-01,  -2.46513121e-01,
#          7.54295536e-01,   5.88777966e-01,   8.19518955e-01,
#          3.18282329e-01,  -8.53229715e-02,  -7.10637982e-01,
#          3.85966614e-01,  -1.52776674e-01,   7.50398937e-01,
#          2.56038434e-01,   7.99552215e-01,   1.07716838e+00,
#          6.09414601e-01,   1.13103483e+00,  -7.63343663e-01,
#         -2.07193577e-01,  -2.47649000e-01,  -8.56819846e-01,
#          1.98554963e-01,  -5.93185556e-01,   2.56846264e-01,
#          4.30625256e-01,   8.98576393e-01,  -5.41922347e-01,
#         -1.05025799e+00,   2.59859646e-01,   1.10062153e-01,
#          5.90024705e-01,   7.86892035e-01,   1.77019184e+00,
#          7.95283917e-02,  -4.75248182e-01,   1.20301212e+00,
#          8.76021592e-01])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-841c15a038e2> in <module>()
#      18 vSMC_logic[vSMC] = True
#      19 Eall = np.concatenate(Es,axis=2)
# ---> 20 Eall_norm = subtract_baseline(Eall)
#
# /Users/david_conant/Dropbox/changrepo/python/datautils/ECoGstats.py in subtract_baseline(Dall)
#    1084     pdb.set_trace()
#    1085
# -> 1086     return Dout
#
# /Users/david_conant/Dropbox/changrepo/python/datautils/ECoGstats.py in subtract_baseline(Dall)
#    1084     pdb.set_trace()
#    1085
# -> 1086     return Dout
#
# /Users/david_conant/anaconda/lib/python2.7/bdb.pyc in trace_dispatch(self, frame, event, arg)
#      47             return # None
#      48         if event == 'line':
# ---> 49             return self.dispatch_line(frame)
#      50         if event == 'call':
#      51             return self.dispatch_call(frame, arg)
#
# /Users/david_conant/anaconda/lib/python2.7/bdb.pyc in dispatch_line(self, frame)
#      65     def dispatch_line(self, frame):
#      66         if self.stop_here(frame) or self.break_here(frame):
# ---> 67             self.user_line(frame)
#      68             if self.quitting: raise BdbQuit
#      69         return self.trace_dispatch
#
# /Users/david_conant/anaconda/lib/python2.7/pdb.pyc in user_line(self, frame)
#     156             self._wait_for_mainpyfile = 0
#     157         if self.bp_commands(frame):
# --> 158             self.interaction(frame, None)
#     159
#     160     def bp_commands(self,frame):
#
# /Users/david_conant/anaconda/lib/python2.7/pdb.pyc in interaction(self, frame, traceback)
#     208         self.setup(frame, traceback)
#     209         self.print_stack_entry(self.stack[self.curindex])
# --> 210         self.cmdloop()
#     211         self.forget()
#     212
#
# /Users/david_conant/anaconda/lib/python2.7/cmd.pyc in cmdloop(self, intro)
#     128                     if self.use_rawinput:
#     129                         try:
# --> 130                             line = raw_input(self.prompt)
#     131                         except EOFError:
#     132                             line = 'EOF'
#
# /Users/david_conant/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/ipkernel.pyc in <lambda>(prompt)
#     361         # raw_input in the user namespace.
#     362         if content.get('allow_stdin', False):
# --> 363             raw_input = lambda prompt='': self._raw_input(prompt, ident, parent)
#     364             input = lambda prompt='': eval(raw_input(prompt))
#     365         else:
#
# /Users/david_conant/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/ipkernel.pyc in _raw_input(self, prompt, ident, parent)
#     763             except KeyboardInterrupt:
#     764                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 765                 raise KeyboardInterrupt
#     766             else:
#     767                 break
#
# KeyboardInterrupt:

# %%
plt.plot(Eall[2,:,1])
plt.plot(Eall_norm[2,:,1])

# %%
Eshp = np.reshape(Eall,(256,-1),order = 'F')
Enormshp = np.reshape(Eall_norm,(256,-1),order = 'F')

# %%
plt.plot(Eshp[2,:10000])
#plt.plot(Enormshp[2,:10000])

# %% [markdown]
# ###ERPs

# %%
subj='EC41'
blocks = [19,20,22,27]
pth = '/Users/david_conant/Dropbox/Vowels/'+subj + '/'

tokens = ['AAA','IYY','UWW']

window = np.array([-1,1])
[D,anat,start_times,stop_times] = makeD_multi(pth,blocks,tokens,align_window=window)
Ds = [D[d] for d in tokens]

fig_filename = save_pth + 'EC41_ERPs_cat3_normed.png'
ax = ev.plotERPs(Ds,align_window = np.array([-1,1]), anatomy = anat,labels = tokens, fig_filename=fig_filename)
# Out:
# File found; Loading...
# Loaded
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-b1eb52a2c43a> in <module>()
#       9 Ds = [D[d] for d in tokens]
#      10
# ---> 11 fig_filename = save_pth + 'EC41_ERPs_cat3_normed.png'
#      12 ax = ev.plotERPs(Ds,align_window = np.array([-1,1]), anatomy = anat,labels = tokens, fig_filename=fig_filename)
#
# NameError: name 'save_pth' is not defined

# %%
def get_data(subj,blocks,base_sub=False):
    pth = '/Users/david_conant/Dropbox/Vowels/'+subj + '/'

    tokens = ['AAA','IYY','UWW','AEE','AHH','EHH','ERR','IHH','UHH']
    #tokens = ['HAWED','HEED','WHOOD','HAD','HUD','HEAD','HEARD','HID','HOOD']
    kfeats = ['kFrontTongueX','kFMidTongueX','kMidTongueX','kBMidTongueX','kBackTongueX','kFrontTongueY','kFMidTongueY','kMidTongueY',
              'kBMidTongueY','kBackTongueY','kLipOpening','kLipWidth','kJawX','kJawY']
    efeats = seq_labels('e',256)
    fs = 100
    #Load in Dmatrices

    #Electrodes
    window = np.array([-1,1])   #TODO: try wider window for more timepoints
    [E,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='HG')
    Es = [E[d] for d in tokens]
    vSMC = np.concatenate((np.where(anat=='preCG')[0],np.where(anat=='postCG')[0]),87)
    vSMC_logic = np.zeros(256,dtype=bool)
    vSMC_logic[vSMC] = True
    Eall = np.concatenate(Es,axis=2)
    if base_sub:
        Eall = subtract_baseline(Eall)
    Eall = resample_array(Eall,[Eall.shape[0],np.diff(window)*fs,Eall.shape[2]])

    #Kinematics
    #window = np.array([0.25,0.75])
    [K,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,dtype='kin',align_window = window)
    Ks = [K[d] for d in tokens]
    stops = [stop_times[d] for d in tokens]
    starts = [start_times[d] for d in tokens]
    Ks = process_kin(Ks,stops,starts,window,numTongue=10,wrt_start=True,norm_length=False)
    Kall = np.concatenate(Ks,axis=2)
    Kall = resample_array(Kall,[Kall.shape[0],np.diff(window)*fs,Kall.shape[2]])
    
    return Kall,Eall,anat

# %%
def do_correlations(Kall,Eall,anat,decorr = False):
#################################
    #Do correlations
    fs = 100
    vSMC = np.concatenate((np.where(anat=='preCG')[0],np.where(anat=='postCG')[0]))
    #vSMC = np.where((anat!='STG') & (anat!='MTG') & (anat!='MTG'))[0]
    vSMC_logic = np.zeros(256,dtype=bool)
    vSMC_logic[vSMC] = True
    
    tokens = ['AAA','IYY','UWW','AEE','AHH','EHH','ERR','IHH','UHH','HAWED','HEED',
              'WHOOD','HAD','HUD','HEAD','HEARD','HID','HOOD']
    #tokens = ['HAWED','HEED','WHOOD','HAD','HUD','HEAD','HEARD','HID','HOOD']
    kfeats = ['kFrontTongueX','kFMidTongueX','kMidTongueX','kBMidTongueX','kBackTongueX','kFrontTongueY',
              'kFMidTongueY','kMidTongueY','kBMidTongueY','kBackTongueY','kLipOpening','kLipWidth','kJawX','kJawY']
    efeats = seq_labels('e',256)

    lags = np.linspace(-1,.5,40)
    Rs = np.empty((14,256,len(lags)))
    Rp = np.empty((14,256,len(lags)))
    ps = np.empty((14,256,len(lags)))
    pp = np.empty((14,256,len(lags)))
    prog = ProgressBar(len(lags))
    groups = [range(10),range(10,12),range(12,14)]
    win_size=0.5
    win_start = 1
    Rpc = []
    for ilag, lag in enumerate(lags):

        #Lag by removing data
        t_unlagged = np.arange(75,125)
        t_lagged = np.arange(np.floor((win_start+lag)*fs),np.floor((win_start+win_size)*fs+lag*fs)).astype(int)
        Klagged = Kall[:,t_unlagged,:]
        Elagged = Eall[:,t_lagged,:]   #behavior-leading lag

        #Reshape across trials
        Kinematics = np.reshape(Klagged,(Klagged.shape[0],-1),order='F').transpose()
        Kinematics = pd.DataFrame(Kinematics,columns = kfeats)
        #Kinematics.fillna(Kinematics.median(),inplace=True)
        #Kinematics = pd.Series(dict(enumerate(Eall.transpose())))

        HG = np.reshape(Elagged,(Elagged.shape[0],-1),order='F').transpose()
        HG = pd.DataFrame(HG,columns = efeats)
        vsmcHG = HG#.iloc[:,vSMC]
        #vsmcHG.dropna(axis =1,how='any',inplace=True)
        data = pd.concat([vsmcHG,Kinematics],axis=1)
        data.dropna(axis=1,how='all',inplace=True)   #Drop bad features
        data.dropna(axis=0,how='all',inplace=True)   #Drop bad observations
        data.dropna(axis=0,how='any',inplace=True)   #Drop bad observations
        data.dropna(axis=1,how='any',inplace=True)   #Drop bad features
        good_efeats = data.filter(regex=r'^e\S', axis=1).columns.values
        good_kfeats = data.filter(regex=r'^k\S', axis=1).columns.values
        if decorr:
            hat,tilde = SemiPartialCorrelation(data[Kinematics.columns],groups)
            data[Kinematics.columns] = tilde
        #Rpc.append(partial_corr(data))
        #groups = [range(10),range(10,12),range(12,14)]
        #for g in groups:
            #Rpc[g] = 

        good_elects = []
        inner = Kinematics.shape[1]
        outer = vsmcHG.shape[1]
        for e in good_efeats:
            good_elects.append(int(e[1:]))
            for i,k in enumerate(good_kfeats):
                #Rs[i,good_elects[-1],ilag],ps[i,good_elects[-1],ilag] = sp.stats.spearmanr(data.loc[:,e],data.loc[:,k])
                Rp[i,good_elects[-1],ilag],pp[i,good_elects[-1],ilag] = sp.stats.pearsonr(data.loc[:,e],data.loc[:,k])
        prog.animate(ilag+1)

    #########################################
    #plot stuff
    good_vSMC_logic = np.zeros(256,dtype=bool)
    good_vSMC_logic[good_elects] = True
    Rp[:,~good_vSMC_logic,:] = 0
    pp[:,~good_vSMC_logic,:] = 1
    Rp[abs(Rp) > 1] = 0
    #Rs[abs(Rs) > 1] = 0
    pp[abs(pp) > 1 ]= 1
    #ps[abs(ps) > 1] = 1
    pp = abs(1-pp)
    lips = np.nanmean(np.square(Rp[10:12,:,0]),axis=0)
    tonguey = np.nanmean(np.square(Rp[5:10,:,0]),axis=0)
    tonguex = np.nanmean(np.square(Rp[0:5,:,0]),axis=0)
    tongueF = np.nanmean(np.square(Rp[[0,1,5,6],:,0]),axis=0)
    tongueB = np.nanmean(np.square(Rp[[3,4,8,9],:,0]),axis=0)
    jaw = np.nanmean(np.square(Rp[12:,:,0]),axis=0)

    plips = np.nanmean(np.square(pp[10:12,:,0]),axis=0)
    ptonguey = np.nanmean(np.square(pp[5:10,:,0]),axis=0)
    ptonguex = np.nanmean(np.square(pp[0:5,:,0]),axis=0)
    ptongueF = np.nanmean(np.square(pp[[0,1,5,6],:,0]),axis=0)
    ptongueB = np.nanmean(np.square(pp[[3,4,8,9],:,0]),axis=0)
    pjaw = np.nanmean(np.square(pp[12:,:,0]),axis=0)

    artics = np.vstack((tonguex,tonguey,lips,jaw)).transpose()
    #ID electrodes according to their correlation with articulators
        #according to max r values
    rpc = Rp[:,:,:26]
    max_elects = np.amax(abs(rpc),axis=2)
    shaped_max_elects = np.reshape(max_elects.copy(),(14,16,16))
    vSMC_shaped = np.rot90(np.reshape(good_vSMC_logic,(16,16)),k=3)
    for i in range(14):
        shaped_max_elects[i,:,:] = np.rot90(shaped_max_elects[i,:,:],k=3)

    
    fig,axes = plt.subplots(figsize = (12,8))
    plt.subplot(3,2,1)
    plt.pcolor(Rp[:,vSMC_logic,0])
    plt.colorbar()
    plt.subplot(3,2,5)
    plt.plot(lags,np.nanmean(abs(Rp[1,vSMC_logic,:]),axis=0))
    plt.subplot(3,2,3)
    plt.pcolor(Rp[1,vSMC_logic,:])
    plt.colorbar()

    plt.subplot(3,2,2)
    plt.pcolor(pp[:,vSMC_logic,0])
    plt.colorbar()
    plt.subplot(3,2,6)
    plt.plot(lags,np.nanmean(pp[1,vSMC_logic,:],axis=0))
    plt.subplot(3,2,4)
    plt.pcolor(pp[1,vSMC_logic,:])
    plt.colorbar()

    #fig_filename = save_pth + subj + '_correlation_somatotopy.png'
    #savefig(fig_filename,facecolor='k', edgecolor='k',bbox_inches='tight')
    
    return shaped_max_elects,vSMC_shaped

# %%
def plot_corrs(to_plot,elects,do_plot=False):
    
    out = np.empty((16,16,14))
    kfeats = ['kFrontTongueX','kFMidTongueX','kMidTongueX','kBMidTongueX','kBackTongueX','kFrontTongueY',
          'kFMidTongueY','kMidTongueY','kBMidTongueY','kBackTongueY','kLipOpening','kLipWidth','kJawX','kJawY']
    if do_plot:
        fig = plt.subplots(figsize=(20,60))
    for feat in range(14):
        plotted = to_plot[feat,:,:]
        
        #plt.pcolor(plotted,cmap='gray')
        #plt.colorbar()
        #plt.gca().set_aspect('equal')
        #g_filt = sp.ndimage.filters.gaussian_filter(plotted,0.6,order=0)
        #g_filt = sp.ndimage.morphology.grey_erosion(g_filt,size=(2,2))
        g_filt = sp.ndimage.morphology.grey_dilation(plotted,size=(2,2))
        g_filt = sp.ndimage.filters.gaussian_filter(g_filt,0.6,order=0)
        g_filt = sp.ndimage.morphology.grey_erosion(g_filt,size=(1,1))
        g_filt = sp.ndimage.filters.gaussian_filter(g_filt,0.6,order=0)

        g_filt[~elects] = 0
        #g_filt[g_filt<0.04]=0.04
        if do_plot:
            plt.subplot(7,2,feat+1)
            plt.pcolor(g_filt,cmap='gist_heat')
            plt.colorbar()
            plt.gca().set_aspect('equal')
            plt.title(kfeats[feat][1:])

        out[:,:,feat] = g_filt

    
    return out

# %%
#EC92############
subj = 'EC92'
blocks = [35,36,37,45]
Kall,Eall,anat = get_data(subj,blocks)
to_plot,elects = do_correlations(Kall,Eall,anat,decorr=False)
vSMC = (anat=='preCG') | (anat=='postCG')
vSMC = np.rot90(np.reshape(vSMC,(16,16)),k=3)
vSMC92_weights = plot_corrs(to_plot,vSMC)

Kall,Eall,anat = get_data(subj,blocks,base_sub=True)
to_plot,elects = do_correlations(Kall,Eall,anat,decorr=False)
vSMC = (anat=='preCG') | (anat=='postCG')
vSMC = np.rot90(np.reshape(vSMC,(16,16)),k=3)
vSMC92_weights = plot_corrs(to_plot,vSMC)
# Out:
# File found; Loading...
# Loaded
# File found; Loading...
# Loaded
#  [                       0%                       ]
#  [**                     5%                       ]  2 of 40 complete
#  [****                   8%                       ]  3 of 40 complete
#  [*****                 10%                       ]  4 of 40 complete
#  [******                13%                       ]  5 of 40 complete
#  [*******               15%                       ]  6 of 40 complete
#  [*********             18%                       ]  7 of 40 complete
#  [**********            20%                       ]  8 of 40 complete
#  [***********           23%                       ]  9 of 40 complete
#  [************          25%                       ]  10 of 40 complete
#  [*************         28%                       ]  11 of 40 complete
#  [**************        30%                       ]  12 of 40 complete
#  [****************      33%                       ]  13 of 40 complete
#  [*****************     35%                       ]  14 of 40 complete
#  [******************    38%                       ]  15 of 40 complete
#  [*******************   40%                       ]  16 of 40 complete
#  [********************* 43%                       ]  17 of 40 complete
#  [**********************45%                       ]  18 of 40 complete
#  [**********************48%                       ]  19 of 40 complete
#  [**********************50%                       ]  20 of 40 complete
#  [**********************53%                       ]  21 of 40 complete
#  [**********************55%*                      ]  22 of 40 complete
#  [**********************57%**                     ]  23 of 40 complete
#  [**********************60%****                   ]  24 of 40 complete
#  [**********************63%*****                  ]  25 of 40 complete
#  [**********************65%******                 ]  26 of 40 complete
#  [**********************68%********               ]  27 of 40 complete
#  [**********************70%*********              ]  28 of 40 complete
#  [**********************73%**********             ]  29 of 40 complete
#  [**********************75%***********            ]  30 of 40 complete
#  [**********************78%************           ]  31 of 40 complete
#  [**********************80%*************          ]  32 of 40 complete
#  [**********************83%***************        ]  33 of 40 complete
#  [**********************85%****************       ]  34 of 40 complete
#  [**********************88%*****************      ]  35 of 40 complete
#  [**********************90%******************     ]  36 of 40 complete
#  [**********************93%********************   ]  37 of 40 complete
#  [**********************95%*********************  ]  38 of 40 complete
#  [**********************98%********************** ]  39 of 40 complete
#  [*********************100%***********************]  40 of 40 complete
# File found; Loading...
# Loaded
# File found; Loading...
# Loaded
#  [                       0%                       ]
#  [**                     5%                       ]  2 of 40 complete
#  [****                   8%                       ]  3 of 40 complete
#  [*****                 10%                       ]  4 of 40 complete
#  [******                13%                       ]  5 of 40 complete
#  [*******               15%                       ]  6 of 40 complete
#  [*********             18%                       ]  7 of 40 complete
#  [**********            20%                       ]  8 of 40 complete
#  [***********           23%                       ]  9 of 40 complete
#  [************          25%                       ]  10 of 40 complete
#  [*************         28%                       ]  11 of 40 complete
#  [**************        30%                       ]  12 of 40 complete
#  [****************      33%                       ]  13 of 40 complete
#  [*****************     35%                       ]  14 of 40 complete
#  [******************    38%                       ]  15 of 40 complete
#  [*******************   40%                       ]  16 of 40 complete
#  [********************* 43%                       ]  17 of 40 complete
#  [**********************45%                       ]  18 of 40 complete
#  [**********************48%                       ]  19 of 40 complete
#  [**********************50%                       ]  20 of 40 complete
#  [**********************53%                       ]  21 of 40 complete
#  [**********************55%*                      ]  22 of 40 complete
#  [**********************57%**                     ]  23 of 40 complete
#  [**********************60%****                   ]  24 of 40 complete
#  [**********************63%*****                  ]  25 of 40 complete
#  [**********************65%******                 ]  26 of 40 complete
#  [**********************68%********               ]  27 of 40 complete
#  [**********************70%*********              ]  28 of 40 complete
#  [**********************73%**********             ]  29 of 40 complete
#  [**********************75%***********            ]  30 of 40 complete
#  [**********************78%************           ]  31 of 40 complete
#  [**********************80%*************          ]  32 of 40 complete
#  [**********************83%***************        ]  33 of 40 complete
#  [**********************85%****************       ]  34 of 40 complete
#  [**********************88%*****************      ]  35 of 40 complete
#  [**********************90%******************     ]  36 of 40 complete
#  [**********************93%********************   ]  37 of 40 complete
#  [**********************95%*********************  ]  38 of 40 complete
#  [**********************98%********************** ]  39 of 40 complete
#  [*********************100%***********************]  40 of 40 complete

# %%
#EC41############
subj = 'EC41'
blocks = [19,20,22,27]
Kall,Eall,anat = get_data(subj,blocks)
to_plot,elects = do_correlations(Kall,Eall,anat,decorr=False)
vSMC = (anat=='preCG') | (anat=='postCG')
vSMC = np.rot90(np.reshape(vSMC,(16,16)),k=3)
vSMC41_weights = plot_corrs(to_plot,vSMC)

Kall,Eall,anat = get_data(subj,blocks,base_sub=True)
to_plot,elects = do_correlations(Kall,Eall,anat,decorr=False)
vSMC = (anat=='preCG') | (anat=='postCG')
vSMC = np.rot90(np.reshape(vSMC,(16,16)),k=3)
vSMC41_weights = plot_corrs(to_plot,vSMC)
# Out:
# File found; Loading...
# Loaded
# File found; Loading...
# Loaded
#  [                       0%                       ]
#  [**                     5%                       ]  2 of 40 complete
#  [****                   8%                       ]  3 of 40 complete
#  [*****                 10%                       ]  4 of 40 complete
#  [******                13%                       ]  5 of 40 complete
#  [*******               15%                       ]  6 of 40 complete
#  [*********             18%                       ]  7 of 40 complete
#  [**********            20%                       ]  8 of 40 complete
#  [***********           23%                       ]  9 of 40 complete
#  [************          25%                       ]  10 of 40 complete
#  [*************         28%                       ]  11 of 40 complete
#  [**************        30%                       ]  12 of 40 complete
#  [****************      33%                       ]  13 of 40 complete
#  [*****************     35%                       ]  14 of 40 complete
#  [******************    38%                       ]  15 of 40 complete
#  [*******************   40%                       ]  16 of 40 complete
#  [********************* 43%                       ]  17 of 40 complete
#  [**********************45%                       ]  18 of 40 complete
#  [**********************48%                       ]  19 of 40 complete
#  [**********************50%                       ]  20 of 40 complete
#  [**********************53%                       ]  21 of 40 complete
#  [**********************55%*                      ]  22 of 40 complete
#  [**********************57%**                     ]  23 of 40 complete
#  [**********************60%****                   ]  24 of 40 complete
#  [**********************63%*****                  ]  25 of 40 complete
#  [**********************65%******                 ]  26 of 40 complete
#  [**********************68%********               ]  27 of 40 complete
#  [**********************70%*********              ]  28 of 40 complete
#  [**********************73%**********             ]  29 of 40 complete
#  [**********************75%***********            ]  30 of 40 complete
#  [**********************78%************           ]  31 of 40 complete
#  [**********************80%*************          ]  32 of 40 complete
#  [**********************83%***************        ]  33 of 40 complete
#  [**********************85%****************       ]  34 of 40 complete
#  [**********************88%*****************      ]  35 of 40 complete
#  [**********************90%******************     ]  36 of 40 complete
#  [**********************93%********************   ]  37 of 40 complete
#  [**********************95%*********************  ]  38 of 40 complete
#  [**********************98%********************** ]  39 of 40 complete
#  [*********************100%***********************]  40 of 40 complete
# File found; Loading...
# Loaded
# File found; Loading...
# Loaded
#  [                       0%                       ]
#  [**                     5%                       ]  2 of 40 complete
#  [****                   8%                       ]  3 of 40 complete
#  [*****                 10%                       ]  4 of 40 complete
#  [******                13%                       ]  5 of 40 complete
#  [*******               15%                       ]  6 of 40 complete
#  [*********             18%                       ]  7 of 40 complete
#  [**********            20%                       ]  8 of 40 complete
#  [***********           23%                       ]  9 of 40 complete
#  [************          25%                       ]  10 of 40 complete
#  [*************         28%                       ]  11 of 40 complete
#  [**************        30%                       ]  12 of 40 complete
#  [****************      33%                       ]  13 of 40 complete
#  [*****************     35%                       ]  14 of 40 complete
#  [******************    38%                       ]  15 of 40 complete
#  [*******************   40%                       ]  16 of 40 complete
#  [********************* 43%                       ]  17 of 40 complete
#  [**********************45%                       ]  18 of 40 complete
#  [**********************48%                       ]  19 of 40 complete
#  [**********************50%                       ]  20 of 40 complete
#  [**********************53%                       ]  21 of 40 complete
#  [**********************55%*                      ]  22 of 40 complete
#  [**********************57%**                     ]  23 of 40 complete
#  [**********************60%****                   ]  24 of 40 complete
#  [**********************63%*****                  ]  25 of 40 complete
#  [**********************65%******                 ]  26 of 40 complete
#  [**********************68%********               ]  27 of 40 complete
#  [**********************70%*********              ]  28 of 40 complete
#  [**********************73%**********             ]  29 of 40 complete
#  [**********************75%***********            ]  30 of 40 complete
#  [**********************78%************           ]  31 of 40 complete
#  [**********************80%*************          ]  32 of 40 complete
#  [**********************83%***************        ]  33 of 40 complete
#  [**********************85%****************       ]  34 of 40 complete
#  [**********************88%*****************      ]  35 of 40 complete
#  [**********************90%******************     ]  36 of 40 complete
#  [**********************93%********************   ]  37 of 40 complete
#  [**********************95%*********************  ]  38 of 40 complete
#  [**********************98%********************** ]  39 of 40 complete
#  [*********************100%***********************]  40 of 40 complete

# %% [markdown]
# #Compare EC41 somatotopy to EC92

# %% [markdown]
# #### I finally finished preprocessing EC92. How do his somatotopy results look?

# %% [markdown]
# ###EC92

# %%
Image(filename = '/Users/david_conant/Dropbox/Vowels/ec92/EC92_brain+grid2D.png')

# %% [markdown]
# ###EC41

# %%
Image(filename = '/Users/david_conant/Dropbox/Vowels/ec41/EC41_brain+grid2D.png')

# %%
groups = [range(10),range(10,12),range(12,14)]
labs = ['Tongue','Lips','Jaw']

for i,g in enumerate(groups):
    fig = plt.subplots(1,2,figsize=[20,7])
    plt.subplot(1,2,1)
    vSMC41 = np.nanmean(vSMC41_weights[:,:,g],axis=2)
    plt.pcolor(vSMC41,cmap='gist_heat')
    plt.colorbar()
    plt.gca().set_aspect('equal')
    plt.title(labs[i] + ' vSMC_EC41')
    
    plt.subplot(1,2,2)
    vSMC92 = np.nanmean(vSMC92_weights[:,:,g],axis=2)
    plt.pcolor(vSMC92,cmap='gist_heat')
    plt.colorbar()
    plt.gca().set_aspect('equal')
    plt.title(labs[i] + ' vSMC_EC92')
    
    
    plt.suptitle(labs[i],fontsize=20)
    plt.show()

# %% [markdown]
# #### I think there is definitely a shared trend for tongue vs lips/jaw, but the distinction between lips and jaw is difficult to intepret for two reasons. 1) He has a rather small brain, and thus far fewer vSMC electrodes. I think it's likely that we'd see larger differences, especially between lips and jaw, with a smaller grid spacing. 2) He (like me) didn't use his lips and jaw much (hence the lower correlation values), so we're not working with much variability to start with.

# %% [markdown]
# #Compare effects of decorrelation

# %% [markdown]
# #### One important caveat to my prior analyses was that the kinematic features were not independent, and thus overlapping results have ambiguous interpretations. As a starting place, I tried running the kinematic features through a semi-partial correlation before doing the correlations with the electrodes. This will yield the kinematic features that are linearly indpendent of the others, and thus shared correlations can (tentatively) be interpreted as a true overlapping representation.

# %%
#EC92############
subj = 'EC92'
blocks = [35,36,37,45]
Kall,Eall,anat = get_data(subj,blocks)
to_plot,elects = do_correlations(Kall,Eall,anat,decorr=True)
vSMC = (anat=='preCG') | (anat=='postCG')
vSMC = np.rot90(np.reshape(vSMC,(16,16)),k=3)
vSMC92_weights_decorr = plot_corrs(to_plot,vSMC)


#EC41############
subj = 'EC41'
blocks = [19,20,22,27]
Kall,Eall,anat = get_data(subj,blocks)
to_plot,elects = do_correlations(Kall,Eall,anat,decorr=True)
vSMC = (anat=='preCG') | (anat=='postCG')
vSMC = np.rot90(np.reshape(vSMC,(16,16)),k=3)
vSMC41_weights_decorr = plot_corrs(to_plot,vSMC)
# Out:
# File found; Loading...
# Loaded
# File found; Loading...
# Loaded
#  [                       0%                       ]
#  [**                     5%                       ]  2 of 40 complete
#  [****                   8%                       ]  3 of 40 complete
#  [*****                 10%                       ]  4 of 40 complete
#  [******                13%                       ]  5 of 40 complete
#  [*******               15%                       ]  6 of 40 complete
#  [*********             18%                       ]  7 of 40 complete
#  [**********            20%                       ]  8 of 40 complete
#  [***********           23%                       ]  9 of 40 complete
#  [************          25%                       ]  10 of 40 complete
#  [*************         28%                       ]  11 of 40 complete
#  [**************        30%                       ]  12 of 40 complete
#  [****************      33%                       ]  13 of 40 complete
#  [*****************     35%                       ]  14 of 40 complete
#  [******************    38%                       ]  15 of 40 complete
#  [*******************   40%                       ]  16 of 40 complete
#  [********************* 43%                       ]  17 of 40 complete
#  [**********************45%                       ]  18 of 40 complete
#  [**********************48%                       ]  19 of 40 complete
#  [**********************50%                       ]  20 of 40 complete
#  [**********************53%                       ]  21 of 40 complete
#  [**********************55%*                      ]  22 of 40 complete
#  [**********************57%**                     ]  23 of 40 complete
#  [**********************60%****                   ]  24 of 40 complete
#  [**********************63%*****                  ]  25 of 40 complete
#  [**********************65%******                 ]  26 of 40 complete
#  [**********************68%********               ]  27 of 40 complete
#  [**********************70%*********              ]  28 of 40 complete
#  [**********************73%**********             ]  29 of 40 complete
#  [**********************75%***********            ]  30 of 40 complete
#  [**********************78%************           ]  31 of 40 complete
#  [**********************80%*************          ]  32 of 40 complete
#  [**********************83%***************        ]  33 of 40 complete
#  [**********************85%****************       ]  34 of 40 complete
#  [**********************88%*****************      ]  35 of 40 complete
#  [**********************90%******************     ]  36 of 40 complete
#  [**********************93%********************   ]  37 of 40 complete
#  [**********************95%*********************  ]  38 of 40 complete
#  [**********************98%********************** ]  39 of 40 complete
#  [*********************100%***********************]  40 of 40 complete
# File found; Loading...
# Loaded
# File found; Loading...
# Loaded
#  [                       0%                       ]
#  [**                     5%                       ]  2 of 40 complete
#  [****                   8%                       ]  3 of 40 complete
#  [*****                 10%                       ]  4 of 40 complete
#  [******                13%                       ]  5 of 40 complete
#  [*******               15%                       ]  6 of 40 complete
#  [*********             18%                       ]  7 of 40 complete
#  [**********            20%                       ]  8 of 40 complete
#  [***********           23%                       ]  9 of 40 complete
#  [************          25%                       ]  10 of 40 complete
#  [*************         28%                       ]  11 of 40 complete
#  [**************        30%                       ]  12 of 40 complete
#  [****************      33%                       ]  13 of 40 complete
#  [*****************     35%                       ]  14 of 40 complete
#  [******************    38%                       ]  15 of 40 complete
#  [*******************   40%                       ]  16 of 40 complete
#  [********************* 43%                       ]  17 of 40 complete
#  [**********************45%                       ]  18 of 40 complete
#  [**********************48%                       ]  19 of 40 complete
#  [**********************50%                       ]  20 of 40 complete
#  [**********************53%                       ]  21 of 40 complete
#  [**********************55%*                      ]  22 of 40 complete
#  [**********************57%**                     ]  23 of 40 complete
#  [**********************60%****                   ]  24 of 40 complete
#  [**********************63%*****                  ]  25 of 40 complete
#  [**********************65%******                 ]  26 of 40 complete
#  [**********************68%********               ]  27 of 40 complete
#  [**********************70%*********              ]  28 of 40 complete
#  [**********************73%**********             ]  29 of 40 complete
#  [**********************75%***********            ]  30 of 40 complete
#  [**********************78%************           ]  31 of 40 complete
#  [**********************80%*************          ]  32 of 40 complete
#  [**********************83%***************        ]  33 of 40 complete
#  [**********************85%****************       ]  34 of 40 complete
#  [**********************88%*****************      ]  35 of 40 complete
#  [**********************90%******************     ]  36 of 40 complete
#  [**********************93%********************   ]  37 of 40 complete
#  [**********************95%*********************  ]  38 of 40 complete
#  [**********************98%********************** ]  39 of 40 complete
#  [*********************100%***********************]  40 of 40 complete

# %%
groups = [range(10),range(10,12),range(12,14)]
labs = ['Tongue','Lips','Jaw']

for i,g in enumerate(groups):
    fig = plt.subplots(2,2,figsize=[20,15])
    plt.subplot(2,2,1)
    vSMC41 = np.nanmean(vSMC41_weights[:,:,g],axis=2)
    plt.pcolor(vSMC41,cmap='gist_heat')
    plt.colorbar()
    plt.gca().set_aspect('equal')
    plt.title(labs[i] + ' vSMC_EC41')
    
    plt.subplot(2,2,2)
    vSMC92 = np.nanmean(vSMC92_weights[:,:,g],axis=2)
    plt.pcolor(vSMC92,cmap='gist_heat')
    plt.colorbar()
    plt.gca().set_aspect('equal')
    plt.title(labs[i] + ' vSMC_EC92')
    
    plt.subplot(2,2,3)
    vSMC41_decorr = np.nanmean(vSMC41_weights_decorr[:,:,g],axis=2)
    plt.pcolor(vSMC41_decorr,cmap='gist_heat')
    plt.colorbar()
    plt.gca().set_aspect('equal')
    plt.title(labs[i] + ' vSMC_EC41_decorrelated')
    
    plt.subplot(2,2,4)
    vSMC92_decorr = np.nanmean(vSMC92_weights_decorr[:,:,g],axis=2)
    plt.pcolor(vSMC92_decorr,cmap='gist_heat')
    plt.colorbar()
    plt.gca().set_aspect('equal')
    plt.title(labs[i] + ' vSMC_EC92_decorrelated')
    
    plt.suptitle(labs[i],fontsize=20)
    plt.show()

# %% [markdown]
# #### Decorrelating the tongue doesn't change much, which is not surprising considering that very little of the variance of the tongue is shared with the lips or jaw. The jaw and lips change a bit, but not drastically. If anything, it appears to spread out slightly. To me, this suggests that the overlapping regions we see are real rather than the result of statistical dependence.

# %% [markdown]
# #Compare vSMC to all supersylvian

# %% [markdown]
# #### I was curious if we see any patches of correlation outside of vSMC. It would be a different direction than we've discussed before, but I think the question of the larger sequence of movement planning could be a very nice addition to the paper. This is only one  part of that direction.

# %%
#EC92############
subj = 'EC92'
blocks = [35,36,37,45]
Kall,Eall,anat = get_data(subj,blocks)
to_plot,elects = do_correlations(Kall,Eall,anat,decorr=False)
sup_sylvian = (anat!='STG') & (anat!='MTG') & (anat!='ITG')
sup_sylvian = np.rot90(np.reshape(sup_sylvian,(16,16)),k=3)
SS92_weights = plot_corrs(to_plot,sup_sylvian)


#EC41############
subj = 'EC41'
blocks = [19,20,22,27]
Kall,Eall,anat = get_data(subj,blocks)
to_plot,elects = do_correlations(Kall,Eall,anat,decorr=False)
sup_sylvian = (anat!='STG') & (anat!='MTG') & (anat!='ITG')
sup_sylvian = np.rot90(np.reshape(sup_sylvian,(16,16)),k=3)
SS41_weights = plot_corrs(to_plot,sup_sylvian)
# Out:
# File found; Loading...
# Loaded
# File found; Loading...
# Loaded
#  [                       0%                       ]
#  [**                     5%                       ]  2 of 40 complete
#  [****                   8%                       ]  3 of 40 complete
#  [*****                 10%                       ]  4 of 40 complete
#  [******                13%                       ]  5 of 40 complete
#  [*******               15%                       ]  6 of 40 complete
#  [*********             18%                       ]  7 of 40 complete
#  [**********            20%                       ]  8 of 40 complete
#  [***********           23%                       ]  9 of 40 complete
#  [************          25%                       ]  10 of 40 complete
#  [*************         28%                       ]  11 of 40 complete
#  [**************        30%                       ]  12 of 40 complete
#  [****************      33%                       ]  13 of 40 complete
#  [*****************     35%                       ]  14 of 40 complete
#  [******************    38%                       ]  15 of 40 complete
#  [*******************   40%                       ]  16 of 40 complete
#  [********************* 43%                       ]  17 of 40 complete
#  [**********************45%                       ]  18 of 40 complete
#  [**********************48%                       ]  19 of 40 complete
#  [**********************50%                       ]  20 of 40 complete
#  [**********************53%                       ]  21 of 40 complete
#  [**********************55%*                      ]  22 of 40 complete
#  [**********************57%**                     ]  23 of 40 complete
#  [**********************60%****                   ]  24 of 40 complete
#  [**********************63%*****                  ]  25 of 40 complete
#  [**********************65%******                 ]  26 of 40 complete
#  [**********************68%********               ]  27 of 40 complete
#  [**********************70%*********              ]  28 of 40 complete
#  [**********************73%**********             ]  29 of 40 complete
#  [**********************75%***********            ]  30 of 40 complete
#  [**********************78%************           ]  31 of 40 complete
#  [**********************80%*************          ]  32 of 40 complete
#  [**********************83%***************        ]  33 of 40 complete
#  [**********************85%****************       ]  34 of 40 complete
#  [**********************88%*****************      ]  35 of 40 complete
#  [**********************90%******************     ]  36 of 40 complete
#  [**********************93%********************   ]  37 of 40 complete
#  [**********************95%*********************  ]  38 of 40 complete
#  [**********************98%********************** ]  39 of 40 complete
#  [*********************100%***********************]  40 of 40 complete
# File found; Loading...
# Loaded
# File found; Loading...
# Loaded
#  [                       0%                       ]
#  [**                     5%                       ]  2 of 40 complete
#  [****                   8%                       ]  3 of 40 complete
#  [*****                 10%                       ]  4 of 40 complete
#  [******                13%                       ]  5 of 40 complete
#  [*******               15%                       ]  6 of 40 complete
#  [*********             18%                       ]  7 of 40 complete
#  [**********            20%                       ]  8 of 40 complete
#  [***********           23%                       ]  9 of 40 complete
#  [************          25%                       ]  10 of 40 complete
#  [*************         28%                       ]  11 of 40 complete
#  [**************        30%                       ]  12 of 40 complete
#  [****************      33%                       ]  13 of 40 complete
#  [*****************     35%                       ]  14 of 40 complete
#  [******************    38%                       ]  15 of 40 complete
#  [*******************   40%                       ]  16 of 40 complete
#  [********************* 43%                       ]  17 of 40 complete
#  [**********************45%                       ]  18 of 40 complete
#  [**********************48%                       ]  19 of 40 complete
#  [**********************50%                       ]  20 of 40 complete
#  [**********************53%                       ]  21 of 40 complete
#  [**********************55%*                      ]  22 of 40 complete
#  [**********************57%**                     ]  23 of 40 complete
#  [**********************60%****                   ]  24 of 40 complete
#  [**********************63%*****                  ]  25 of 40 complete
#  [**********************65%******                 ]  26 of 40 complete
#  [**********************68%********               ]  27 of 40 complete
#  [**********************70%*********              ]  28 of 40 complete
#  [**********************73%**********             ]  29 of 40 complete
#  [**********************75%***********            ]  30 of 40 complete
#  [**********************78%************           ]  31 of 40 complete
#  [**********************80%*************          ]  32 of 40 complete
#  [**********************83%***************        ]  33 of 40 complete
#  [**********************85%****************       ]  34 of 40 complete
#  [**********************88%*****************      ]  35 of 40 complete
#  [**********************90%******************     ]  36 of 40 complete
#  [**********************93%********************   ]  37 of 40 complete
#  [**********************95%*********************  ]  38 of 40 complete
#  [**********************98%********************** ]  39 of 40 complete
#  [*********************100%***********************]  40 of 40 complete

# %%
groups = [range(10),range(10,12),range(12,14)]
labs = ['Tongue','Lips','Jaw']

for i,g in enumerate(groups):
    fig = plt.subplots(2,2,figsize=[20,15])
    plt.subplot(2,2,1)
    vSMC41 = np.nanmean(vSMC41_weights[:,:,g],axis=2)
    plt.pcolor(vSMC41,cmap='gist_heat')
    plt.colorbar()
    plt.gca().set_aspect('equal')
    plt.title(labs[i] + ' vSMC_EC41')
    
    plt.subplot(2,2,2)
    vSMC92 = np.nanmean(vSMC92_weights[:,:,g],axis=2)
    plt.pcolor(vSMC92,cmap='gist_heat')
    plt.colorbar()
    plt.gca().set_aspect('equal')
    plt.title(labs[i] + ' vSMC_EC92')
    
    plt.subplot(2,2,3)
    SS41 = np.nanmean(SS41_weights[:,:,g],axis=2)
    plt.pcolor(SS41,cmap='gist_heat')
    plt.colorbar()
    plt.gca().set_aspect('equal')
    plt.title(labs[i] + ' Suprasylvian_EC41')
    
    plt.subplot(2,2,4)
    SS92 = np.nanmean(SS92_weights[:,:,g],axis=2)
    plt.pcolor(SS92,cmap='gist_heat')
    plt.colorbar()
    plt.gca().set_aspect('equal')
    plt.title(labs[i] + ' Suprasylvian_EC92')
    
    plt.suptitle(labs[i],fontsize=20)
    plt.show()

# %% [markdown]
# #### There does appear to be patches of representation outside of vSMC, even some that are higher than vSMC. I was hoping to see clear second site of correlation (perhaps in IFG?), but instead it doesn't seem consistent between articulators or subjects. There are a lot of possible explanations for this (differences in patient coverage, hemispheric differences, etc). I debated showing this to you because I don't have a clear idea of what this means, but I think the possibility of linking vSMC activity to other areas could be compelling.
