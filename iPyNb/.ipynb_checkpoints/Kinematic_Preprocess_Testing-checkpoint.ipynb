# %%
#Intitialize
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import scipy as sp
import scipy.stats as stats
import numpy as np
from sklearn.cross_validation import train_test_split, LeaveOneOut, LeaveOneLabelOut, ShuffleSplit
from sklearn.decomposition import PCA
from sklearn.lda import LDA
from sklearn.linear_model import Lars, Ridge
import pandas as pd
import pdb
import prettyplotlib as ppl
from BDutils import ProgressBar, moving_average, RunningMedian
from scipy.signal import savgol_filter
import seaborn as sns
import matplotlib.gridspec as gridspec
from ECoGstats import makeD_multi, process_kin, shuffle_df, smooth_formants, Ridge_MLR, Ds2Xy, smooth_derivative,ClusterSeparability
from ecog_viz import LDA_proj_scatter, gestural_score, separability_timecourse,feature_correlations,vowel_svm
from __future__ import division
from matplotlib.backends.backend_agg import (FigureCanvasAgg as FigureCanvas)
from scipy.stats import mstats
from BoLASSO_BgdOLS import BoLASSO_BgdOLS as BoLBO
from scipy.io import loadmat
import Butterworth_Bandpass as bb
from scipy.signal import butter, lfilter, filtfilt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
blockpath = '/Users/david_conant/Dropbox/Vowels/'+subj + '/'+subj +'_B19/'
fname = blockpath + 'Kinematics/Art_data.mat'
art = loadmat(fname)
feats = ['tonguex', 'tonguey', 'lipsx', 'lipsy', 'jawxy', 'nosexy']
featlen = [0,100,100,2,2,2,2]
numfeats = len(art)-3

klen = min([art[feats[0]].shape[0],art[feats[numfeats-1]].shape[0]])
K = np.empty((sum(featlen[:numfeats+1]),klen))
fsum = 0
for cnt in range(numfeats):

    K[fsum:fsum+featlen[cnt+1],:klen] = art[feats[cnt]][:klen,:].transpose()
    fsum = fsum+featlen[cnt+1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-056ff945b8c3> in <module>()
#      14     fsum = fsum+featlen[cnt+1]
#      15
# ---> 16 if bandpass:
#      17     pdb.set_trace()
#
# NameError: name 'bandpass' is not defined

# %%
Kf = bb.butter_bandpass_filter(K,.05,10,30)
# Out:
# > /Users/david_conant/Dropbox/changrepo/python/preprocessing/Butterworth_Bandpass.py(18)butter_bandpass_filter()
# -> y = filtfilt(b, a, data)
# (Pdb) y = filtfilt(b, a, data[1,5000:6000])
# (Pdb) y
# array([ nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan])
# (Pdb) data[1,5000:6000]
# array([         nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#         69.45734334,  72.48008079,  75.39191454,  74.40692018,
#         76.95633632,  71.43298006,  68.37459388,  68.2965641 ,
#         68.16841685,  67.79235826,  66.30925295,  67.30882458,
#         67.67639933,  68.32738238,  68.80058256,  69.37371918,
#         69.69129633,  69.58784592,  69.84589903,  69.78672048,
#         70.05978656,  69.29173578,  68.88434372,  68.45539962,
#         68.55122347,  69.03649323,  69.19681426,  70.36302601,
#         71.68159911,  69.59891061,  71.27368445,  73.25825331,
#         71.90645451,  71.70359144,  72.41385489,  72.63727719,
#         72.84129076,  74.05870088,  73.98728276,  73.78611678,
#         74.30307916,  75.99987059,  76.76202783,  76.93739417,
#         78.62572512,  79.58690522,  78.86363522,  80.16061361,
#         80.07015277,  79.72969706,  78.60106635,  77.42109921,
#         78.25133149,  77.63107223,  78.05702349,  76.20455718,
#         74.91514245,  74.10806927,  73.18616603,  73.70302527,
#         71.14307624,  67.18518749,  67.86014552,  65.76455666,
#         64.8059959 ,  64.56631   ,  66.72207182,  66.17141851,
#         64.46573994,  65.35308243,  65.44222174,  66.28256363,
#         63.19142921,  58.51807779,  61.50508498,  63.13429784,
#         62.55679437,  60.15753545,  58.76134152,  59.21444789,
#         59.43061179,  60.0927508 ,  58.91914129,  57.86822834,
#         59.30670703,  57.8182311 ,  58.01024295,  58.06707138,
#         57.77193149,  58.54083913,  58.70607005,  58.79590672,
#         59.19383826,  58.81041536,  60.98062632,  62.52448993,
#         62.26615791,  62.35624955,  62.13946538,  62.26133596,
#         62.18435442,  62.23247692,  62.20469691,  62.20467083,
#         62.16613582,  62.74252151,  63.31753696,  62.27976386,
#         62.89049146,  62.81285329,  62.41194536,  62.55826289,
#         62.51844894,  62.49737547,  62.67383506,  62.13013847,
#         63.4573961 ,  64.7243067 ,  62.75094587,  61.8169458 ,
#         63.84733213,  66.87648973,  62.3929457 ,  59.5526658 ,
#         60.5807053 ,  59.52149054,  63.27970604,  65.12899859,
#         60.48989684,  59.80005916,  59.94414183,  60.1508488 ,
#         60.19532119,  59.78472784,  60.06232333,  59.65064857,
#         59.73463274,  58.88587587,  59.00913411,  59.75393404,
#         59.02637732,  60.58245995,  57.41560951,  55.3254979 ,
#         56.92042572,  55.94554452,  56.154655  ,  55.5404336 ,
#         57.0223464 ,  55.55142668,  57.94063452,  53.06445392,
#         53.88597897,  61.44717341,  69.50675995,  72.72977799,
#         75.812335  ,  75.74872357,  74.00522959,  72.3211066 ,
#         70.1440319 ,  67.111937  ,  64.72899451,  65.11400333,
#         63.04539814,  63.78930027,  53.67678842,  52.10656966,
#         52.93071718,  59.80975083,  64.81839756,  63.09057957,
#         62.97897892,  61.55702386,  61.75702175,  61.25365437,
#         58.55801275,  55.22950282,  56.21418949,  56.42541543,
#         56.25220058,  55.76128182,  56.17817183,  56.29501169,
#         55.6388051 ,  54.7846997 ,  56.08970055,  54.91258653,
#         54.11119933,  54.4399444 ,  54.27451388,  54.33443358,
#         54.39012143,  53.79044405,  53.36884093,  53.32675625,
#         53.78760302,  53.53405316,  53.46379634,  53.35298895,
#         53.92499306,  53.25583588,  53.58276922,  54.3685664 ,
#         53.93616139,  54.05345116,  54.10625978,  54.08599903,
#         53.94339821,  53.1792907 ,  53.03851711,  53.94960608,
#         54.29911475,  54.11142376,  53.926054  ,  54.3538402 ,
#         53.74949957,  56.72363249,  57.92306005,  57.8557365 ,
#         58.49815458,  59.35985554,  57.31308008,  59.59670726,
#         61.4922306 ,  59.31350268,  59.78375267,  60.70395374,
#         57.33033892,  55.03693945,  55.38055284,  54.53249942,
#         53.44911608,  55.78861601,  52.73678264,  49.49336769,
#         48.5004468 ,  49.83666723,  50.82270106,  48.71667692,
#         45.40552775,  56.28097531,  59.05630641,  57.51801976,
#         58.05944872,  57.42553951,  57.20368384,  57.40225422,
#         57.47183156,  57.10831543,  57.38264651,  56.79136942,
#         56.69969734,  56.67462008,  56.8100804 ,  56.23335186,
#         56.55946763,  56.876241  ,  56.74782775,  56.88089025,
#         56.39177374,  56.25885154,  56.34053842,  56.16534576,
#         56.19846015,  56.09924957,  56.62812353,  57.11623136,
#         57.82955253,  57.7914664 ,  57.86089604,  55.80054991,
#         54.52190858,  50.22298983,  47.97711806,  49.40411305,
#         51.99303175,  53.59722127,  56.57989925,  57.06164431,
#         58.45834047,  59.23579936,  59.6625765 ,  58.33246415,
#         56.80116435,  57.05091877,  57.73973775,  57.46886405,
#         57.28026226,  57.3365901 ,  57.31172503,  57.31418531,
#         57.33599053,  57.19165455,  57.27293392,  57.15337388,
#         57.29020527,  58.00307465,  58.70913356,  59.26930108,
#         58.66427939,  58.66418186,  58.51352256,  58.14095357,
#         58.1389176 ,  58.13007492,  58.13485679,  58.13708604,
#         58.12746568,  58.14698226,  58.11260708,  58.17838965,
#         57.83442909,  57.80028082,  57.74536679,  57.82578084,
#         57.18692393,  57.06832975,  56.81085386,  56.65235992,
#         56.78915121,  56.25478745,  56.38852903,  55.99578837,
#         54.77691313,  54.91636288,  54.23592049,  54.28522997,
#         52.57523394,  51.67143867,  51.4548627 ,  52.37492851,
#         51.13589969,  50.57550728,  49.70429144,  56.72766077,
#         59.27246347,  55.97576416,  55.26043302,  55.44285455,
#         55.07591132,  57.25706407,  55.95754693,  55.08413441,
#         55.26762033,  55.13405611,  55.24204832,  55.12091546,
#         55.67718439,  55.74657976,  55.73480957,  55.72178472,
#         55.81056942,  55.77204671,  55.87383538,  55.22333551,
#         55.65300824,  55.35035201,  55.06557592,  55.39194621,
#         53.40535561,  53.00478301,  53.20277728,  53.12302226,
#         53.1961124 ,  53.11569386,  53.24069218,  52.38070791,
#         52.24068999,  52.30117624,  52.26538444,  52.28898986,
#         52.27409868,  52.28362423,  52.27809927,  52.28134185,
#         52.27994347,  52.28062449,  52.28074164,  52.2808178 ,
#         52.28102517,  52.28097571,  52.28137777,  52.2810391 ,
#         52.28187136,  52.28087037,  52.28284545,  52.2784095 ,
#         52.31315025,  52.31504624,  52.31372196,  52.31419327,
#         52.30606334,  52.31982674,  52.29766855,  52.31595312,
#         52.83253287,  53.1630712 ,  52.66003921,  56.69511905,
#         58.80464229,  64.82161555,  69.03949986,  70.113317  ,
#         71.1293864 ,  72.23074624,  72.10763724,  71.51318059,
#         68.26692541,  64.82673589,  58.06715744,  51.69498912,
#         51.22180708,  52.30045801,  52.36026175,  52.43201037,
#         52.52366606,  52.51445429,  52.53095113,  52.49864427,
#         52.83326634,  52.87061105,  52.86004941,  52.86041128,
#         52.86941661,  52.84948548,  52.88611972,  52.81574281,
#         53.28711235,  52.53435993,  52.42347155,  52.47566367,
#         52.4447009 ,  52.46400048,  52.45277767,  52.45841074,
#         52.45787282,  52.45416323,  52.46353509,  52.4474205 ,
#         52.47538756,  52.4190284 ,  53.05942163,  53.11516837,
#         53.10059704,  53.09414898,  53.13194098,  52.53714119,
#         52.47433142,  52.50322633,  52.48655137,  52.49711085,
#         52.49074191,  52.49479524,  52.49258212,  52.49400367,
#         52.49351516,  52.49387099,  52.4940019 ,  52.49413296,
#         52.49426417,  52.4945411 ,  52.49435813,  52.49507019,
#         52.49410082,  52.49610998,  52.49313964,  52.49826912,
#         52.49008343,  52.50655499,  52.3004886 ,  52.29260324,
#         52.285043  ,  52.45642102,  52.3982105 ,  52.48681851,
#         52.50054962,  52.49428614,  52.49703749,  52.49758742,
#         52.49426322,  52.50148714,  52.48948753,  52.51054076,
#         52.4666654 ,  53.24123831,  53.29185604,  53.26912045,
#         53.28274157,  53.27432674,  53.27994682,  53.27664651,
#         53.27883407,  53.27784557,  53.27852082,  53.27846581,
#         53.27860406,  53.27874245,  53.27888097,  53.27901962,
#         53.27915841,  53.27929732,  53.27943636,  53.27957554,
#         53.27971484,  53.27985427,  53.27999383,  53.28013351,
#         53.28027333,  53.28041327,  53.28055333,  53.28069352,
#         53.28083383,  53.28097427,  53.28111484,  53.28125552,
#         53.28139633,  53.28153726,  53.28167832,  53.28181949,
#         53.28196078,  53.2821022 ,  53.28197019,  53.28284472,
#         53.2815979 ,  53.28413264,  53.28039699,  53.28663324,
#         53.27717294,  53.29339506,  53.26124917,  54.22341409,
#         53.74124178,  53.71756883,  53.72710334,  53.72595456,
#         53.71902452,  53.90336699,  53.03120195,  53.00450891,
#         53.02088339,  53.00662582,  53.02310914,  53.00009475,
#         53.04544058,  50.50437103,  50.45864557,  50.48037259,
#         50.43408638,  50.44170302,  50.43695125,  50.44015946,
#         50.43847711,  50.43960276,  50.43928233,  50.43955093,
#         50.43975319,  50.4397919 ,  50.4400924 ,  50.43998283,
#         50.44037506,  50.43978498,  50.44077674,  50.43865574,
#         51.01463468,  51.0172635 ,  51.01578803,  51.01720381,
#         50.2034657 ,  50.20264858,  50.20299757,  50.20276859,
#         50.20305264,  50.4409837 ,  50.43919219,  50.44152911,
#         50.43785012,  50.44496419,  51.25467471,  50.87719772,
#         50.05614568,  49.22434115,  50.89700263,  51.59184365,
#         51.62717876,  51.62488336,  51.62618214,  51.62511944,
#         51.62555278,  51.62502273,  51.62524905,  51.62474994,
#         51.62509099,  51.6240979 ,  51.62534694,  51.62243622,
#         51.52246156,  51.62631086,  51.62230062,  51.59024514,
#         51.58911591,  51.59048642,  51.58808407,  51.59215281,
#         51.6904888 ,  51.58678734,  51.58980556,  51.58892362,
#         51.65879312,  51.61876499,  51.62639581,  51.61635491,
#         51.63125739,  51.60197862,  51.01156114,  51.57124085,
#         51.54528853,  51.55851248,  51.55013636,  51.55532445,
#         51.55172296,  51.5536861 ,  51.55271629,  51.58919235,
#         51.65628819,  51.65246289,  51.6555711 ,  51.61491958,
#         51.62686597,  51.64439474,  51.6766118 ,  52.34898381,
#         52.32580824,  52.33011466,  52.33649527,  52.31670834,
#         52.36403255,  53.16156561,  53.14643341,  53.11857839,
#         52.60656556,  53.50143535,  54.16799341,  55.72639771,
#         57.46213409,  59.03155311,  60.11122463,  60.10261   ,
#         60.74034497,  60.65795659,  59.87324274,  60.93712197,
#         60.7083592 ,  59.17236045,  54.96418579,  44.47117805,
#         42.27381983,  40.88953597,  41.49198285,  41.36114978,
#         42.24340564,  44.03858084,  44.50185169,  44.39525298,
#         44.62419681,  47.648422  ,  47.72967252,  47.71569067,
#         46.51019676,  47.47850318,  48.40151545,  48.4059868 ,
#         48.37901417,  48.41905023,  48.35731669,  48.38038659,
#         48.02311628,  45.31199125,  45.50383978,  45.41052698,
#         45.46620593,  45.42992608,  45.45503297,  45.47209216,
#         45.36677869,  45.38751635,  45.35747528,  45.4212486 ,
#         46.09242291,  46.03392996,  46.07138367,  46.03505307,
#         46.07854537,  46.01834465,  46.11075695,  45.93128148,
#         44.8827146 ,  45.69939879,  44.94618655,  45.36707621,
#         45.2746099 ,  45.44639577,  45.37360645,  45.51216045,
#         46.34366215,  46.25292111,  46.24972927,  46.22362913,
#         46.30767712,  46.13811612,  45.05062422,  45.86437955,
#         45.85231804,  45.89791952,  45.87684584,  45.87584025,
#         45.89883516,  45.85008001,  45.93050094,  45.67177279,
#         46.01241573,  47.79527839,  45.57501968,  46.00212674,
#         46.37871368,  46.57542014,  46.2613685 ,  45.97385397,
#         45.47151049,  46.72218826,  56.91438743,  56.69656145,
#         57.12804471,  56.85710509,  57.03300961,  56.91500489,
#         56.95689155,  56.94854649,  56.93200978,  56.93057861,
#         57.05321972,  57.24251159,  57.22490458,  57.23253721,
#         57.22866587,  57.22946213,  57.23106531,  57.22619676,
#         57.23469422,  57.22025319,  57.24438051,  57.19336334,
#         56.99903464,  57.25436257,  57.2163495 ,  57.23449731,
#         57.22595934,  57.22505144,  57.19486428,  57.22847662,
#         57.18939396,  57.19483002,  57.19425025,  57.19063521,
#         57.19852914,  57.17740742,  57.04441503,  57.06282399,
#         57.05034204,  57.10453351,  57.06948883,  57.11880761,
#         57.08765507,  57.34399138,  58.10984631,  59.1896821 ,
#         61.80010772,  64.26722359,  67.87622499,  68.8828139 ,
#         69.04277986,  69.76751931,  69.78976099,  70.92296949,
#         71.63519569,  71.70031485,  71.69197232,  71.69593229,
#         71.69145239,  71.69198859,  71.69209209,  71.69090263,
#         71.69149353,  71.691038  ,  71.68912247,  71.69230308,
#         71.6861506 ,  71.6959941 ,  71.67996101,  71.70456566,
#         71.66522531,  71.73253617,  71.57421364,  70.80005149])
# (Pdb) y = filtfilt(b, a, data[5500:7000])
# (Pdb) y
# array([], shape=(0, 17994), dtype=float64)
# (Pdb) y = filtfilt(b, a, data[1,5500:7000])
# (Pdb) y
# array([ 0.86389588,  0.88566449,  0.89896086, ..., -0.96474798,
#        -0.84888346, -0.97612509])
# (Pdb) y.shape
# (1500,)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-f33129b7516c> in <module>()
# ----> 1 Kf = bb.butter_bandpass_filter(K,.05,10,30)
#
# /Users/david_conant/Dropbox/changrepo/python/preprocessing/Butterworth_Bandpass.py in butter_bandpass_filter(data, lowcut, highcut, fs, order)
#      16     b, a = butter_bandpass(lowcut, highcut, fs, order=order)
#      17     pdb.set_trace()
# ---> 18
#      19     y = filtfilt(b, a, data)
#      20     return y
#
# /Users/david_conant/Dropbox/changrepo/python/preprocessing/Butterworth_Bandpass.py in butter_bandpass_filter(data, lowcut, highcut, fs, order)
#      16     b, a = butter_bandpass(lowcut, highcut, fs, order=order)
#      17     pdb.set_trace()
# ---> 18
#      19     y = filtfilt(b, a, data)
#      20     return y
#
# /Users/david_conant/anaconda/lib/python2.7/bdb.pyc in trace_dispatch(self, frame, event, arg)
#      47             return # None
#      48         if event == 'line':
# ---> 49             return self.dispatch_line(frame)
#      50         if event == 'call':
#      51             return self.dispatch_call(frame, arg)
#
# /Users/david_conant/anaconda/lib/python2.7/bdb.pyc in dispatch_line(self, frame)
#      65     def dispatch_line(self, frame):
#      66         if self.stop_here(frame) or self.break_here(frame):
# ---> 67             self.user_line(frame)
#      68             if self.quitting: raise BdbQuit
#      69         return self.trace_dispatch
#
# /Users/david_conant/anaconda/lib/python2.7/pdb.pyc in user_line(self, frame)
#     156             self._wait_for_mainpyfile = 0
#     157         if self.bp_commands(frame):
# --> 158             self.interaction(frame, None)
#     159
#     160     def bp_commands(self,frame):
#
# /Users/david_conant/anaconda/lib/python2.7/pdb.pyc in interaction(self, frame, traceback)
#     208         self.setup(frame, traceback)
#     209         self.print_stack_entry(self.stack[self.curindex])
# --> 210         self.cmdloop()
#     211         self.forget()
#     212
#
# /Users/david_conant/anaconda/lib/python2.7/cmd.pyc in cmdloop(self, intro)
#     128                     if self.use_rawinput:
#     129                         try:
# --> 130                             line = raw_input(self.prompt)
#     131                         except EOFError:
#     132                             line = 'EOF'
#
# /Users/david_conant/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/ipkernel.pyc in <lambda>(prompt)
#     361         # raw_input in the user namespace.
#     362         if content.get('allow_stdin', False):
# --> 363             raw_input = lambda prompt='': self._raw_input(prompt, ident, parent)
#     364             input = lambda prompt='': eval(raw_input(prompt))
#     365         else:
#
# /Users/david_conant/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/ipkernel.pyc in _raw_input(self, prompt, ident, parent)
#     763             except KeyboardInterrupt:
#     764                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 765                 raise KeyboardInterrupt
#     766             else:
#     767                 break
#
# KeyboardInterrupt:

# %%
width = 100
plot(K[1,3000:7000])
med = [sp.stats.nanmedian(K[:,n-width:n]) for n in np.arange(width,K.shape[1])]
# Out:
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/stats/stats.py:400: RuntimeWarning: All-NaN slice encountered
#   warnings.warn("All-NaN slice encountered", RuntimeWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-863ae0d6f891> in <module>()
#       1 width = 100
#       2 plot(K[1,3000:7000])
# ----> 3 med = [sp.stats.nanmedian(K[n-width:n]) for n in np.arange(width,K.shape[1])]
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/numpy/lib/utils.pyc in newfunc(*args, **kwds)
#     133             """`arrayrange` is deprecated, use `arange` instead!"""
#     134             warnings.warn(depdoc, DeprecationWarning)
# --> 135             return func(*args, **kwds)
#     136
#     137         newfunc = _set_function_name(newfunc, old_name)
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/stats/stats.pyc in nanmedian(x, axis)
#     463     if hasattr(np, 'nanmedian'):  # numpy 1.9 faster for some cases
#     464         return np.nanmedian(x, axis)
# --> 465     x = np.apply_along_axis(_nanmedian, axis, x)
#     466     if x.ndim == 0:
#     467         x = float(x.item())
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/numpy/lib/shape_base.pyc in apply_along_axis(func1d, axis, arr, *args)
#      92                 ind[n] = 0
#      93                 n -= 1
# ---> 94             i.put(indlist, ind)
#      95             res = func1d(arr[tuple(i.tolist())],*args)
#      96             outarr[tuple(ind)] = res
#
# KeyboardInterrupt:

# %%
med
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-f7c940637b4c> in <module>()
# ----> 1 med
#
# NameError: name 'med' is not defined

# %%
plot(K[1,3000:7000])
Kmed = sp.signal.medfilt(K.copy(),[201,1])
plot(Kmed[1,3000:7000],color='r')

# %%
b, a = bb.butter_bandpass(0.1, 12, 30, order=5)
y = filtfilt(b,a,K1.values.transpose(),axis=1)
plot(K[1,3000:7000])
plot(y[1,3000:7000],color='r')

# %%
plot(K[205,3000:7000])
plot(y[205,3000:7000],color='r')

# %%
plot(K[1,5500:7000])

# %%
plot(y[1,5500:7000])

# %%
K1 = pd.DataFrame(K.copy().transpose())
K1.fillna(K1.median(),inplace=True)
# Out:
#             0          1          2          3          4          5    \
# 0      50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 1      50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 2      50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 3      50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 4      50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 5      50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 6      50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 7      50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 8      50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 9      50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 10     50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 11     50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 12     50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 13     50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 14     50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 15     50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 16     50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17     50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 18     50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 19     50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 20     50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 21     50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 22     50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 23     50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 24     50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 25     50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 26     50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 27     50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 28     50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 29     50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# ...         ...        ...        ...        ...        ...        ...
# 17964  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17965  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17966  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17967  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17968  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17969  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17970  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17971  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17972  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17973  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17974  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17975  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17976  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17977  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17978  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17979  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17980  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17981  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17982  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17983  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17984  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17985  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17986  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17987  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17988  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17989  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17990  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17991  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17992  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
# 17993  50.22556  52.492582  54.757421  57.001663  59.318419  61.607819
#
#              6          7         8          9       ...             198  \
# 0      63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 1      63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 2      63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 3      63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 4      63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 5      63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 6      63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 7      63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 8      63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 9      63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 10     63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 11     63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 12     63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 13     63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 14     63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 15     63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 16     63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17     63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 18     63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 19     63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 20     63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 21     63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 22     63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 23     63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 24     63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 25     63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 26     63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 27     63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 28     63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 29     63.907866  66.170272  68.53103  70.692879     ...      209.748377
# ...          ...        ...       ...        ...     ...             ...
# 17964  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17965  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17966  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17967  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17968  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17969  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17970  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17971  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17972  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17973  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17974  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17975  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17976  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17977  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17978  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17979  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17980  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17981  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17982  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17983  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17984  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17985  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17986  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17987  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17988  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17989  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17990  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17991  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17992  63.907866  66.170272  68.53103  70.692879     ...      209.748377
# 17993  63.907866  66.170272  68.53103  70.692879     ...      209.748377
#
#              199         200         201         202         203         204  \
# 0      212.03691  181.192375  344.810896  134.960006  256.877160  362.880930
# 1      212.03691  181.192375  344.810896  134.960006  256.877160  362.880930
# 2      212.03691  181.192375  344.810896  134.960006  256.877160  362.880930
# 3      212.03691  181.192375  344.810896  134.960006  256.877160  362.880930
# 4      212.03691  181.192375  344.810896  134.960006  256.877160  362.880930
# 5      212.03691  181.192375  344.810896  134.960006  256.877160  362.880930
# 6      212.03691  181.192375  344.810896  134.960006  256.877160  362.880930
# 7      212.03691  181.192375  344.810896  134.960006  256.877160  362.880930
# 8      212.03691  181.192375  344.810896  134.960006  256.877160  362.880930
# 9      212.03691  181.192375  344.810896  134.960006  256.877160  362.880930
# 10     212.03691  181.192375  344.810896  134.960006  256.877160  362.880930
# 11     212.03691  181.192375  344.810896  134.960006  256.877160  362.880930
# 12     212.03691  181.192375  344.810896  134.960006  256.877160  362.880930
# 13     212.03691  181.192375  344.810896  134.960006  256.877160  362.880930
# 14     212.03691  181.192375  344.810896  134.960006  256.877160  362.880930
# 15     212.03691  181.192375  344.810896  134.960006  256.877160  362.880930
# 16     212.03691  181.192375  344.810896  134.960006  256.877160  362.880930
# 17     212.03691  181.192375  344.810896  134.960006  256.877160  362.880930
# 18     212.03691  181.192375  344.810896  134.960006  256.877160  362.880930
# 19     212.03691  181.192375  344.810896  134.960006  256.877160  362.880930
# 20     212.03691  153.749208  288.773459  195.383551  260.904392  382.923499
# 21     212.03691  153.412580  295.674839  192.541686  262.703987  386.041395
# 22     212.03691  151.682385  289.488281  192.695497  261.568466  384.349814
# 23     212.03691  151.135153  290.147428  195.276112  263.247143  386.343379
# 24     212.03691  153.046224  291.124173  196.868409  263.819786  386.718387
# 25     212.03691  153.941703  296.154568  196.981165  262.848493  385.838383
# 26     212.03691  154.157232  298.275860  193.361026  262.006857  383.826155
# 27     212.03691  157.205531  297.051167  192.517031  262.820067  385.007496
# 28     212.03691  157.967510  290.863481  197.046291  260.834881  384.911676
# 29     212.03691  156.575381  290.421697  198.387061  262.065145  386.014434
# ...          ...         ...         ...         ...         ...         ...
# 17964  212.03691  163.178975  354.715463  148.154021  259.614589  371.859719
# 17965  212.03691  165.285911  352.331543  149.054539  258.926905  371.714139
# 17966  212.03691  165.830119  355.204615  148.817185  258.772713  370.806985
# 17967  212.03691  166.304951  356.984851  149.121303  259.115379  372.141380
# 17968  212.03691  169.586257  358.990846  148.458593  259.812272  372.780566
# 17969  212.03691  171.054754  366.703467  146.821465  260.092040  372.876885
# 17970  212.03691  172.349137  363.002290  146.712118  260.781146  374.091303
# 17971  212.03691  174.291390  370.103707  145.866662  261.134754  374.746467
# 17972  212.03691  174.909325  367.559610  145.439969  261.559065  374.838826
# 17973  212.03691  174.810463  367.109969  141.721333  260.913364  376.087876
# 17974  212.03691  175.024729  371.384110  139.318704  261.876768  376.862335
# 17975  212.03691  176.288065  373.567237  137.072066  261.961413  378.146140
# 17976  212.03691  176.989357  374.760080  135.519629  263.043944  378.705193
# 17977  212.03691  178.798456  376.648926  134.407980  264.459831  380.767080
# 17978  212.03691  181.771186  380.319410  133.651830  266.124458  383.100304
# 17979  212.03691  183.448333  386.879984  132.143001  267.472530  384.311545
# 17980  212.03691  185.988811  385.000443  132.189045  269.158855  386.090966
# 17981  212.03691  188.910620  388.200316  130.704510  270.702039  387.293893
# 17982  212.03691  190.158925  387.756505  130.593549  273.947841  389.464440
# 17983  212.03691  191.454916  389.091679  131.934403  275.255079  391.610456
# 17984  212.03691  191.647191  392.292381  132.686068  278.369468  392.983083
# 17985  212.03691  192.436472  388.197355  134.001308  280.189614  394.570346
# 17986  212.03691  192.309340  389.397651  134.596841  281.680007  396.065844
# 17987  212.03691  192.047555  391.904987  136.590954  283.304356  397.619633
# 17988  212.03691  193.706344  389.790407  137.377137  284.275490  398.770421
# 17989  212.03691  196.555829  396.115920  137.892291  285.025919  399.174226
# 17990  212.03691  198.782399  401.485262  138.327764  287.383481  402.211585
# 17991  212.03691  202.179558  402.504584  139.358483  289.885886  402.683030
# 17992  212.03691  204.360866  407.928544  141.119598  292.507726  406.174287
# 17993  212.03691  203.374662  406.423873  142.098260  294.648730  407.967222
#
#               205        206         207
# 0      289.855564  25.928537  291.350740
# 1      289.855564  25.928537  291.350740
# 2      289.855564  25.928537  291.350740
# 3      289.855564  25.928537  291.350740
# 4      289.855564  25.928537  291.350740
# 5      289.855564  25.928537  291.350740
# 6      289.855564  25.928537  291.350740
# 7      289.855564  25.928537  291.350740
# 8      289.855564  25.928537  291.350740
# 9      289.855564  25.928537  291.350740
# 10     289.855564  25.928537  291.350740
# 11     289.855564  25.928537  291.350740
# 12     289.855564  25.928537  291.350740
# 13     289.855564  25.928537  291.350740
# 14     289.855564  25.928537  291.350740
# 15     289.855564  25.928537  291.350740
# 16     289.855564  25.928537  291.350740
# 17     289.855564  25.928537  291.350740
# 18     289.855564  25.928537  291.350740
# 19     289.855564  25.928537  291.350740
# 20     251.956078  64.481735  251.981199
# 21     252.690850  64.160463  253.665968
# 22     250.497532  63.930890  251.541980
# 23     250.214464  66.141698  251.123231
# 24     250.850618  66.934520  250.920250
# 25     252.158708  65.892301  253.108443
# 26     254.059008  64.947364  254.074779
# 27     254.962629  64.981697  256.038714
# 28     254.949680  65.047357  255.933583
# 29     254.766796  66.114486  255.741759
# ...           ...        ...         ...
# 17964  276.853108  42.555889  281.014039
# 17965  276.996534  43.580971  283.139019
# 17966  278.077273  46.127067  286.649363
# 17967  279.053535  46.072548  287.993886
# 17968  280.023719  47.215236  291.594847
# 17969  281.184445  48.204549  290.282366
# 17970  283.372088  47.469602  292.680865
# 17971  285.154815  45.730823  292.761730
# 17972  285.836601  44.375237  298.850966
# 17973  285.803449  42.634483  298.965955
# 17974  287.591177  39.404463  302.843400
# 17975  290.590756  35.204297  302.294992
# 17976  292.217724  34.579935  305.436453
# 17977  294.971138  32.247550  308.102193
# 17978  299.520733  31.868038  311.736127
# 17979  304.584785  30.063177  315.402780
# 17980  307.525646  28.503529  318.689990
# 17981  309.861548  27.493955  322.825309
# 17982  312.766148  26.795484  327.201289
# 17983  314.175354  27.295258  329.264262
# 17984  315.033798  28.837070  327.529953
# 17985  316.590090  30.693703  329.251801
# 17986  318.356208  31.191705  330.985659
# 17987  318.991923  33.183825  332.791501
# 17988  320.691779  34.052053  331.794088
# 17989  323.059046  34.346160  338.982664
# 17990  327.048265  35.582320  340.994515
# 17991  330.391385  36.911305  347.353650
# 17992  333.713009  39.428308  348.859447
# 17993  334.540254  40.077225  348.447738
#
# [17994 rows x 208 columns]

# %%
np.repeat(np.median(K[f,:]),np.where(bad[f,:])[0].shape[0]).shape
# Out:
# (20,)

# %%
K1[20,bad[20,:]]
# Out:
# array([ nan,  nan,  nan, ...,  nan,  nan,  nan])

# %%
subj = 'EC41'
blocks = [19,20,22,27]
pth = '/Users/david_conant/Dropbox/Vowels/'+subj + '/'
tokens = ['AAA','IYY','UWW','AEE','AHH','EHH','ERR','IHH','UHH']
window = np.array([-1,2])
[K,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,dtype= 'kin',align_window = window)
Ks = [K[d].copy() for d in tokens]
notes = []
for ind,n in enumerate(tokens):
    notes.append([n]*Ks[ind].shape[2])
notes = np.concatenate(notes,axis=0) 

stops = [stop_times[d] for d in tokens]
starts = [start_times[d] for d in tokens]
Ks = process_kin(Ks,stops,starts,window, norm_length=True,velocity = False,wrt_start=True)
Kall = np.concatenate(Ks,axis=2)
kfeats = ['Front Tongue X','Mid Tongue X', 'Back Tongue X','Front Tongue Y','Mid Tongue Y',
         'Back Tongue Y','Lip Opening','Lip Width','Jaw X','Jaw Y']
sns.set_palette('Set1')

#Gestural Score:
#fig_filename = save_pth + subj + '_Kin_hvdGS_legend.png'
gestural_score(Ks,kfeats,tokens,fig_filename =None,window=np.array([-1,2]))
# Out:
# File found; Loading...
# Loaded
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-a0c3bb85a240> in <module>()
#      13 stops = [stop_times[d] for d in tokens]
#      14 starts = [start_times[d] for d in tokens]
# ---> 15 Ks = process_kin(Ks,stops,starts,window, norm_length=True,velocity = False,wrt_start=True)
#      16 Kall = np.concatenate(Ks,axis=2)
#      17 kfeats = ['Front Tongue X','Mid Tongue X', 'Back Tongue X','Front Tongue Y','Mid Tongue Y',
#
# /Users/david_conant/Dropbox/changrepo/python/datautils/ECoGstats.py in process_kin(ds, stops, starts, window, numTongue, wrt_start, norm_length, warp_time, polar, velocity)
#     581     Ds = ds[:]
#     582     if norm_length:
# --> 583         Ds = normalize_contour_length(Ds[:])
#     584
#     585     if polar:
#
# /Users/david_conant/Dropbox/changrepo/python/datautils/ECoGstats.py in normalize_contour_length(Ds)
#     520             for frame in range(D.shape[1]):
#     521                 tng = np.vstack((D[0:100,frame,trial],D[100:200,frame,trial])).transpose()
# --> 522                 tngdist = squareform(pdist(tng))
#     523                 contour_distances = np.diag(tngdist,k=1)
#     524                 contour_length[iD,frame,trial] = np.sum(contour_distances)
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/spatial/distance.pyc in squareform(X, force, checks)
#    1473
#    1474         # Return the distance matrix.
# -> 1475         M = M + M.transpose()
#    1476         return M
#    1477     elif len(s) == 2:
#
# KeyboardInterrupt:

# %%
#Cluster Separability:
Ks = [K[d].copy() for d in tokens]
Ks = process_kin(Ks,stops,starts,window, norm_length=True,velocity = False,wrt_start=True)
separability_timecourse(Ks,tokens,LD=3)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import freqz

# Sample rate and desired cutoff frequencies (in Hz).
fs = 30.0
lowcut = .05
highcut = 10

# Plot the frequency response for a few different orders.
plt.figure(1)
plt.clf()
for order in [3, 6, 9]:
    b, a = bb.butter_bandpass(lowcut, highcut, fs, order=order)
    w, h = freqz(b, a, worN=2000)
    plt.plot((fs * 0.5 / np.pi) * w, abs(h), label="order = %d" % order)

plt.plot([0, 0.5 * fs], [np.sqrt(0.5), np.sqrt(0.5)],
         '--', label='sqrt(0.5)')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Gain')
plt.grid(True)
plt.legend(loc='best')

# Filter a noisy signal.
T = 0.05
nsamples = T * fs
t = np.linspace(0, T, nsamples, endpoint=False)
a = 0.02
f0 = 600.0
x = 0.1 * np.sin(2 * np.pi * 1.2 * np.sqrt(t))
x += 0.01 * np.cos(2 * np.pi * 312 * t + 0.1)
x += a * np.cos(2 * np.pi * f0 * t + .11)
x += 0.03 * np.cos(2 * np.pi * 2000 * t)
plt.figure(2)
plt.clf()
plt.plot(t, x, label='Noisy signal')

y = bb.butter_bandpass_filter(x, lowcut, highcut, fs, order=6)
plt.plot(t, y, label='Filtered signal (%g Hz)' % f0)
plt.xlabel('time (seconds)')
plt.hlines([-a, a], 0, T, linestyles='--')
plt.grid(True)
plt.axis('tight')
plt.legend(loc='upper left')

plt.show()
# Out:
# > /Users/david_conant/Dropbox/changrepo/python/preprocessing/Butterworth_Bandpass.py(18)butter_bandpass_filter()
# -> y = filtfilt(b, a, data)
# (Pdb) continue
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-4d2a245a5bc9> in <module>()
#      37 plt.plot(t, x, label='Noisy signal')
#      38
# ---> 39 y = bb.butter_bandpass_filter(x, lowcut, highcut, fs, order=6)
#      40 plt.plot(t, y, label='Filtered signal (%g Hz)' % f0)
#      41 plt.xlabel('time (seconds)')
#
# /Users/david_conant/Dropbox/changrepo/python/preprocessing/Butterworth_Bandpass.py in butter_bandpass_filter(data, lowcut, highcut, fs, order)
#      16     b, a = butter_bandpass(lowcut, highcut, fs, order=order)
#      17     pdb.set_trace()
# ---> 18     y = filtfilt(b, a, data)
#      19     return y
#      20
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/signal/signaltools.pyc in filtfilt(b, a, x, axis, padtype, padlen)
#    1982     if x.shape[axis] <= edge:
#    1983         raise ValueError("The length of the input vector x must be at least "
# -> 1984                          "padlen, which is %d." % edge)
#    1985
#    1986     if padtype is not None and edge > 0:
#
# ValueError: The length of the input vector x must be at least padlen, which is 39.
