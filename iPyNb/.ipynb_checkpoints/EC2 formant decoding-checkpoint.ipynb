# %%
#Intitialize
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from __future__ import division
import sys
import ecog_viz as ev
import numpy as np
import seaborn as sns
import pandas as pd
import pdb
from brain_utils import brainBaseline
from brain.dataformat.brainformat import *
from IPython.display import Image
from ECoGstats import makeD_multi, combine_cv_labs
sns.set_style('dark')
import string as string

# %%
pth = '/Users/david_conant/Documents/EC2/'
blocks = [105]
#tokens = ['aa','aw','ee','oo','uu','ho','ue']
#subtokens = ['aa','ee','oo']
tokens = ['baa','bee','boo']
window = np.array([-1,1])
[D,anat,start_times,stop_times] = makeD_multi(pth,blocks,tokens,align_window=window)
#Ds = combine_cv_labs(D)
Ds = [D[d] for d in tokens]
ax = ev.plotERPs(Ds,align_window = np.array([-1,1]), anatomy = anat,labels = subtokens,yscale = 'independent')
# Out:
# File found; Loading...
# Loaded
#  [                       0%                       ]
#  [                       1%                       ]  2 of 256 complete
#  [                       1%                       ]  3 of 256 complete
#  [*                      2%                       ]  4 of 256 complete
#  [*                      2%                       ]  5 of 256 complete
#  [*                      2%                       ]  6 of 256 complete
#  [*                      3%                       ]  7 of 256 complete
#  [*                      3%                       ]  8 of 256 complete
#  [**                     4%                       ]  9 of 256 complete
#  [**                     4%                       ]  10 of 256 complete
#  [**                     4%                       ]  11 of 256 complete
#  [**                     5%                       ]  12 of 256 complete
#  [**                     5%                       ]  13 of 256 complete
#  [**                     5%                       ]  14 of 256 complete
#  [***                    6%                       ]  15 of 256 complete
#  [***                    6%                       ]  16 of 256 complete
#  [***                    7%                       ]  17 of 256 complete
#  [***                    7%                       ]  18 of 256 complete
#  [***                    7%                       ]  19 of 256 complete
#  [****                   8%                       ]  20 of 256 complete
#  [****                   8%                       ]  21 of 256 complete
#  [****                   9%                       ]  22 of 256 complete
#  [****                   9%                       ]  23 of 256 complete
#  [****                   9%                       ]  24 of 256 complete
#  [*****                 10%                       ]  25 of 256 complete
#  [*****                 10%                       ]  26 of 256 complete
#  [*****                 11%                       ]  27 of 256 complete
#  [*****                 11%                       ]  28 of 256 complete
#  [*****                 11%                       ]  29 of 256 complete
#  [******                12%                       ]  30 of 256 complete
#  [******                12%                       ]  31 of 256 complete
#  [******                13%                       ]  32 of 256 complete
#  [******                13%                       ]  33 of 256 complete
#  [******                13%                       ]  34 of 256 complete
#  [*******               14%                       ]  35 of 256 complete
#  [*******               14%                       ]  36 of 256 complete
#  [*******               14%                       ]  37 of 256 complete
#  [*******               15%                       ]  38 of 256 complete
#  [*******               15%                       ]  39 of 256 complete
#  [********              16%                       ]  40 of 256 complete
#  [********              16%                       ]  41 of 256 complete
#  [********              16%                       ]  42 of 256 complete
#  [********              17%                       ]  43 of 256 complete
#  [********              17%                       ]  44 of 256 complete
#  [*********             18%                       ]  45 of 256 complete
#  [*********             18%                       ]  46 of 256 complete
#  [*********             18%                       ]  47 of 256 complete
#  [*********             19%                       ]  48 of 256 complete
#  [*********             19%                       ]  49 of 256 complete
#  [**********            20%                       ]  50 of 256 complete
#  [**********            20%                       ]  51 of 256 complete
#  [**********            20%                       ]  52 of 256 complete
#  [**********            21%                       ]  53 of 256 complete
#  [**********            21%                       ]  54 of 256 complete
#  [**********            21%                       ]  55 of 256 complete
#  [***********           22%                       ]  56 of 256 complete
#  [***********           22%                       ]  57 of 256 complete
#  [***********           23%                       ]  58 of 256 complete
#  [***********           23%                       ]  59 of 256 complete
#  [***********           23%                       ]  60 of 256 complete
#  [************          24%                       ]  61 of 256 complete
#  [************          24%                       ]  62 of 256 complete
#  [************          25%                       ]  63 of 256 complete
#  [************          25%                       ]  64 of 256 complete
#  [************          25%                       ]  65 of 256 complete
#  [************          26%                       ]  66 of 256 complete
#  [************          26%                       ]  67 of 256 complete
#  [*************         27%                       ]  68 of 256 complete
#  [*************         27%                       ]  69 of 256 complete
#  [*************         27%                       ]  70 of 256 complete
#  [*************         28%                       ]  71 of 256 complete
#  [*************         28%                       ]  72 of 256 complete
#  [**************        29%                       ]  73 of 256 complete
#  [**************        29%                       ]  74 of 256 complete
#  [**************        29%                       ]  75 of 256 complete
#  [**************        30%                       ]  76 of 256 complete
#  [**************        30%                       ]  77 of 256 complete
#  [**************        30%                       ]  78 of 256 complete
#  [***************       31%                       ]  79 of 256 complete
#  [***************       31%                       ]  80 of 256 complete
#  [***************       32%                       ]  81 of 256 complete
#  [***************       32%                       ]  82 of 256 complete
#  [***************       32%                       ]  83 of 256 complete
#  [****************      33%                       ]  84 of 256 complete
#  [****************      33%                       ]  85 of 256 complete
#  [****************      34%                       ]  86 of 256 complete
#  [****************      34%                       ]  87 of 256 complete
#  [****************      34%                       ]  88 of 256 complete
#  [*****************     35%                       ]  89 of 256 complete
#  [*****************     35%                       ]  90 of 256 complete
#  [*****************     36%                       ]  91 of 256 complete
#  [*****************     36%                       ]  92 of 256 complete
#  [*****************     36%                       ]  93 of 256 complete
#  [******************    37%                       ]  94 of 256 complete
#  [******************    37%                       ]  95 of 256 complete
#  [******************    38%                       ]  96 of 256 complete
#  [******************    38%                       ]  97 of 256 complete
#  [******************    38%                       ]  98 of 256 complete
#  [*******************   39%                       ]  99 of 256 complete
#  [*******************   39%                       ]  100 of 256 complete
#  [*******************   39%                       ]  101 of 256 complete
#  [*******************   40%                       ]  102 of 256 complete
#  [*******************   40%                       ]  103 of 256 complete
#  [********************  41%                       ]  104 of 256 complete
#  [********************  41%                       ]  105 of 256 complete
#  [********************  41%                       ]  106 of 256 complete
#  [********************  42%                       ]  107 of 256 complete
#  [********************  42%                       ]  108 of 256 complete
#  [********************* 43%                       ]  109 of 256 complete
#  [********************* 43%                       ]  110 of 256 complete
#  [********************* 43%                       ]  111 of 256 complete
#  [********************* 44%                       ]  112 of 256 complete
#  [********************* 44%                       ]  113 of 256 complete
#  [**********************45%                       ]  114 of 256 complete
#  [**********************45%                       ]  115 of 256 complete
#  [**********************45%                       ]  116 of 256 complete
#  [**********************46%                       ]  117 of 256 complete
#  [**********************46%                       ]  118 of 256 complete
#  [**********************46%                       ]  119 of 256 complete
#  [**********************47%                       ]  120 of 256 complete
#  [**********************47%                       ]  121 of 256 complete
#  [**********************48%                       ]  122 of 256 complete
#  [**********************48%                       ]  123 of 256 complete
#  [**********************48%                       ]  124 of 256 complete
#  [**********************49%                       ]  125 of 256 complete
#  [**********************49%                       ]  126 of 256 complete
#  [**********************50%                       ]  127 of 256 complete
#  [**********************50%                       ]  128 of 256 complete
#  [**********************50%                       ]  129 of 256 complete
#  [**********************51%                       ]  130 of 256 complete
#  [**********************51%                       ]  131 of 256 complete
#  [**********************52%                       ]  132 of 256 complete
#  [**********************52%                       ]  133 of 256 complete
#  [**********************52%                       ]  134 of 256 complete
#  [**********************53%                       ]  135 of 256 complete
#  [**********************53%                       ]  136 of 256 complete
#  [**********************54%*                      ]  137 of 256 complete
#  [**********************54%*                      ]  138 of 256 complete
#  [**********************54%*                      ]  139 of 256 complete
#  [**********************55%*                      ]  140 of 256 complete
#  [**********************55%*                      ]  141 of 256 complete
#  [**********************55%*                      ]  142 of 256 complete
#  [**********************56%**                     ]  143 of 256 complete
#  [**********************56%**                     ]  144 of 256 complete
#  [**********************57%**                     ]  145 of 256 complete
#  [**********************57%**                     ]  146 of 256 complete
#  [**********************57%**                     ]  147 of 256 complete
#  [**********************58%***                    ]  148 of 256 complete
#  [**********************58%***                    ]  149 of 256 complete
#  [**********************59%***                    ]  150 of 256 complete
#  [**********************59%***                    ]  151 of 256 complete
#  [**********************59%***                    ]  152 of 256 complete
#  [**********************60%****                   ]  153 of 256 complete
#  [**********************60%****                   ]  154 of 256 complete
#  [**********************61%****                   ]  155 of 256 complete
#  [**********************61%****                   ]  156 of 256 complete
#  [**********************61%****                   ]  157 of 256 complete
#  [**********************62%*****                  ]  158 of 256 complete
#  [**********************62%*****                  ]  159 of 256 complete
#  [**********************63%*****                  ]  160 of 256 complete
#  [**********************63%*****                  ]  161 of 256 complete
#  [**********************63%*****                  ]  162 of 256 complete
#  [**********************64%******                 ]  163 of 256 complete
#  [**********************64%******                 ]  164 of 256 complete
#  [**********************64%******                 ]  165 of 256 complete
#  [**********************65%******                 ]  166 of 256 complete
#  [**********************65%******                 ]  167 of 256 complete
#  [**********************66%*******                ]  168 of 256 complete
#  [**********************66%*******                ]  169 of 256 complete
#  [**********************66%*******                ]  170 of 256 complete
#  [**********************67%*******                ]  171 of 256 complete
#  [**********************67%*******                ]  172 of 256 complete
#  [**********************68%********               ]  173 of 256 complete
#  [**********************68%********               ]  174 of 256 complete
#  [**********************68%********               ]  175 of 256 complete
#  [**********************69%********               ]  176 of 256 complete
#  [**********************69%********               ]  177 of 256 complete
#  [**********************70%*********              ]  178 of 256 complete
#  [**********************70%*********              ]  179 of 256 complete
#  [**********************70%*********              ]  180 of 256 complete
#  [**********************71%*********              ]  181 of 256 complete
#  [**********************71%*********              ]  182 of 256 complete
#  [**********************71%*********              ]  183 of 256 complete
#  [**********************72%**********             ]  184 of 256 complete
#  [**********************72%**********             ]  185 of 256 complete
#  [**********************73%**********             ]  186 of 256 complete
#  [**********************73%**********             ]  187 of 256 complete
#  [**********************73%**********             ]  188 of 256 complete
#  [**********************74%***********            ]  189 of 256 complete
#  [**********************74%***********            ]  190 of 256 complete
#  [**********************75%***********            ]  191 of 256 complete
#  [**********************75%***********            ]  192 of 256 complete
#  [**********************75%***********            ]  193 of 256 complete
#  [**********************76%***********            ]  194 of 256 complete
#  [**********************76%***********            ]  195 of 256 complete
#  [**********************77%************           ]  196 of 256 complete
#  [**********************77%************           ]  197 of 256 complete
#  [**********************77%************           ]  198 of 256 complete
#  [**********************78%************           ]  199 of 256 complete
#  [**********************78%************           ]  200 of 256 complete
#  [**********************79%*************          ]  201 of 256 complete
#  [**********************79%*************          ]  202 of 256 complete
#  [**********************79%*************          ]  203 of 256 complete
#  [**********************80%*************          ]  204 of 256 complete
#  [**********************80%*************          ]  205 of 256 complete
#  [**********************80%*************          ]  206 of 256 complete
#  [**********************81%**************         ]  207 of 256 complete
#  [**********************81%**************         ]  208 of 256 complete
#  [**********************82%**************         ]  209 of 256 complete
#  [**********************82%**************         ]  210 of 256 complete
#  [**********************82%**************         ]  211 of 256 complete
#  [**********************83%***************        ]  212 of 256 complete
#  [**********************83%***************        ]  213 of 256 complete
#  [**********************84%***************        ]  214 of 256 complete
#  [**********************84%***************        ]  215 of 256 complete
#  [**********************84%***************        ]  216 of 256 complete
#  [**********************85%****************       ]  217 of 256 complete
#  [**********************85%****************       ]  218 of 256 complete
#  [**********************86%****************       ]  219 of 256 complete
#  [**********************86%****************       ]  220 of 256 complete
#  [**********************86%****************       ]  221 of 256 complete
#  [**********************87%*****************      ]  222 of 256 complete
#  [**********************87%*****************      ]  223 of 256 complete
#  [**********************88%*****************      ]  224 of 256 complete
#  [**********************88%*****************      ]  225 of 256 complete
#  [**********************88%*****************      ]  226 of 256 complete
#  [**********************89%******************     ]  227 of 256 complete
#  [**********************89%******************     ]  228 of 256 complete
#  [**********************89%******************     ]  229 of 256 complete
#  [**********************90%******************     ]  230 of 256 complete
#  [**********************90%******************     ]  231 of 256 complete
#  [**********************91%*******************    ]  232 of 256 complete
#  [**********************91%*******************    ]  233 of 256 complete
#  [**********************91%*******************    ]  234 of 256 complete
#  [**********************92%*******************    ]  235 of 256 complete
#  [**********************92%*******************    ]  236 of 256 complete
#  [**********************93%********************   ]  237 of 256 complete
#  [**********************93%********************   ]  238 of 256 complete
#  [**********************93%********************   ]  239 of 256 complete
#  [**********************94%********************   ]  240 of 256 complete
#  [**********************94%********************   ]  241 of 256 complete
#  [**********************95%*********************  ]  242 of 256 complete
#  [**********************95%*********************  ]  243 of 256 complete
#  [**********************95%*********************  ]  244 of 256 complete
#  [**********************96%*********************  ]  245 of 256 complete
#  [**********************96%*********************  ]  246 of 256 complete
#  [**********************96%*********************  ]  247 of 256 complete
#  [**********************97%********************** ]  248 of 256 complete
#  [**********************97%********************** ]  249 of 256 complete
#  [**********************98%********************** ]  250 of 256 complete
#  [**********************98%********************** ]  251 of 256 complete
#  [**********************98%********************** ]  252 of 256 complete
#  [**********************99%***********************]  253 of 256 complete
#  [**********************99%***********************]  254 of 256 complete
#  [*********************100%***********************]  255 of 256 complete
#  [*********************100%***********************]  256 of 256 complete

# %%
D.keys()
# Out:
# ['bee', 'boo', 'baa']

# %%
#Intitialize
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from ECoGstats import makeD_multi, smooth_formants
import seaborn as sns
import prettyplotlib as ppl
from matplotlib.backends.backend_agg import (FigureCanvasAgg as FigureCanvas)
from scipy.signal import savgol_filter
import pandas as pd
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def gestural_score(Fs,feats,labels):

    co = ppl.brewer2mpl.get_map('Set1','Qualitative',9).mpl_colors
    align_window = window
    tt = np.linspace(align_window[0],align_window[1],Fs[0].shape[1])
    sns.set_context('talk')
    sns.set_style('dark')
    fig, axes = plt.subplots(figsize=(12,40))
    axes.axis('off')
    canvas = FigureCanvas(fig)

    for cnt,f in enumerate(feats):
        yscale = np.empty((len(Fs),2))
        ax = fig.add_subplot(len(feats),1,cnt+1)
        for iD,D in enumerate(Fs):
            mu = savgol_filter(np.nanmean(D[f,:,:],axis=1),5,3)
            ste = savgol_filter(np.nanstd(D[f,:,:],axis=1)/np.sqrt(D.shape[2]),5,3)
            yscale[iD,:] = np.array([np.nanmin(mu[50:75]-10*ste[50:75]), np.nanmax(mu[50:75]+10*ste[50:75])])
            plt.plot(tt,mu,color = co[iD],label=labels[iD])
            plt.fill_between(tt,mu-ste, mu+ste,color = co[iD],alpha=0.5)
            plt.plot([0,0],[ax.get_ylim()[0],ax.get_ylim()[1]], color = 'w')
            plt.legend(loc = 'upper right', bbox_to_anchor=(1.1, 1.1),prop={'size':12})
            plt.text(0.1, 0.9,'F' + str(f), ha='center', va='center', transform=ax.transAxes, fontsize=24)

        ax.set_ylim([np.min(yscale),np.max(yscale)])

# %%
pth = '/Users/david_conant/Documents/EC2/'
blocks = [105]
tokens = ['aa','aw','ee','oo','uu','ho','ue']
subtokens = ['aa','ee','oo']
window = np.array([-1,1])

[F,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='form')
Fs = combine_cv_labs(F)
stops = combine_cv_labs(stop_times)
starts = combine_cv_labs(start_times)
#form_sm = smooth_formants(Fs,starts,stops,window)
feats = range(5)
labels = tokens
gestural_score(form_sm,feats,labels)
# Out:
# File found; Loading...
# Loaded

# %%
plot(Fs[0][1,:,3])

# %%
#Intitialize
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import scipy as sp
import scipy.stats as stats
import numpy as np
from sklearn.cross_validation import train_test_split, LeaveOneOut, LeaveOneLabelOut, ShuffleSplit
from sklearn.decomposition import PCA
from sklearn.linear_model import Lars, Ridge
import pandas as pd
import pdb
import prettyplotlib as ppl
from BDutils import ProgressBar
from scipy.signal import savgol_filter
import seaborn as sns
import matplotlib.gridspec as gridspec
from ECoGstats import makeD_multi, smooth_formants, shuffle_df, combine_cv_labs
from __future__ import division
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def Ds2Xy(Es,Fs,anat,ncomp = 10,erange = np.arange(366,370),frange = np.arange(105,115)):
    #Feature labels
    forms = ['F0','F1','F2','F3','F4']
    
    #Anatomy
    vSMC = np.concatenate((np.where(anat=='preCG')[0],np.where(anat=='postCG')[0]))
    #vSMC = np.arange(0,255)
    #Formants
    Fall = np.concatenate(Fs,axis=2)
    dat = dict(zip(forms,np.nanmean(Fall[:,frange,:],axis = 1)))
    Fmid = pd.DataFrame.from_dict(dat)
    Fmid = Fmid.fillna(Fmid.median(),inplace=True)
    badT = sum(Fmid == 0,axis=1) == 5
    F2_1 = pd.Series(Fmid['F2']/Fmid['F1'],name = 'F2/F1')
    y = pd.concat((Fmid,F2_1),axis=1)
    ##Adjacent Points
    #tmp = pd.concat((y,y),axis = 0,ignore_index=True)
    #y = pd.concat((tmp,y),axis = 0,ignore_index=True)
    ##
    y.apply(np.log10,axis = 0)
    y = (y - y.mean())/y.std(ddof=0)
    yrnd = shuffle_df(y,10,axis=0)
    y = y.values
    yrnd = yrnd.values
    
    Eall = np.concatenate(Es,axis=2)
    Eall = Eall[vSMC,:,:]
    X = np.nanmean(Eall[:,erange,:],axis = 1).transpose()
    ##Adjacent Points
    #X1 = np.nanmean(Eall[:,erange-4,:],axis = 1).transpose()
    #X3 = np.nanmean(Eall[:,erange+4,:],axis = 1).transpose()
    #X = np.concatenate((X,X1,X3),axis = 0)
    ##
    X = pd.DataFrame(X)
    X = X.fillna(X.median(),inplace=True)
    X = X.dropna(axis =1,how='any')
    clf = PCA(n_components = ncomp) 
    clf.fit(X)
    X = clf.transform(X)
    return X,y,yrnd

# %%
def Ridge_MLR(X,y,alpha,CV = 'split',boot=200):
    r2 = np.empty((y.shape[1],boot))
    score = np.empty((y.shape[1],boot))
    yhat = np.empty((y.shape))
    for b in range(boot):
        if CV is 'split':
                X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
                for c in range(y.shape[1]):
                    clf = Ridge(alpha = alpha)
                    clf.fit(X_train,y_train[:,c])
                    yhat = clf.predict(X_test)
                    score[c,b] = clf.score(X_test,y_test[:,c])
                    r = stats.pearsonr(yhat,y_test[:,c])[0]
                    r2[c,b] = r**2
        elif CV is 'LOLO':
            trialLabel = np.tile(np.arange(y.shape[0]/3),3)
            lol = LeaveOneLabelOut(trialLabel)
            for c in range(y.shape[1]):
                for train_index, test_index in lol:
                    clf = Ridge(alpha = alpha)
                    clf.fit(X[train_index,:],y[train_index,c])
                    yhat[test_index,c] = clf.predict(X[test_index,:])
                    #score[c,b] = clf.score(X[train_index,:],y[train_index,c])
                    
                r = stats.pearsonr(yhat[:,c],y[:,c])[0]
                r2[c,b] = r**2
    return np.squeeze(r2), yhat, score

# %%
pth = '/Users/david_conant/Documents/EC2/'
blocks = [105]
tokens = ['aa','aw','ee','oo','uu','ho','ue']

CV = 'split'
boot = 10
ncomp = 10

window = np.array([-1, 1])
[E,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='HG')
Es = combine_cv_labs(E)
[F,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='form')
Fs = combine_cv_labs(F)
stops = combine_cv_labs(stop_times)
starts = combine_cv_labs(start_times)
#Fs = smooth_formants(Fs,starts,stops,window)
tokens = ['aa','ee','oo']
#Over time
r2 = np.empty((6,boot,101,5))
prog = ProgressBar(101)
for indt,t in enumerate(np.linspace(0,500,101)):
    erange = np.arange(t,t+4)

    #Organize data into X and y
    X,y,yrnd = Ds2Xy(Es,Fs,anat,ncomp = ncomp,erange = erange.astype(int),frange = np.arange(130,135))

    #Ridge regression
    for inda,a in enumerate(np.logspace(0,10,5)):
        r2[:,:,indt,inda],yhat,score = Ridge_MLR(X, y, alpha = a, CV = CV, boot = boot)
    prog.animate(indt)
# Out:
# File found; Loading...
# Loaded
# File found; Loading...
# Loaded
#  [                       0%                       ]
#  [                       1%                       ]  1 of 101 complete
#  [*                      2%                       ]  2 of 101 complete
#  [*                      3%                       ]  3 of 101 complete
#  [**                     4%                       ]  4 of 101 complete
#  [**                     5%                       ]  5 of 101 complete
#  [***                    6%                       ]  6 of 101 complete
#  [***                    7%                       ]  7 of 101 complete
#  [****                   8%                       ]  8 of 101 complete
#  [****                   9%                       ]  9 of 101 complete
#  [*****                 10%                       ]  10 of 101 complete
#  [*****                 11%                       ]  11 of 101 complete
#  [******                12%                       ]  12 of 101 complete
#  [******                13%                       ]  13 of 101 complete
#  [*******               14%                       ]  14 of 101 complete
#  [*******               15%                       ]  15 of 101 complete
#  [********              16%                       ]  16 of 101 complete
#  [********              17%                       ]  17 of 101 complete
#  [*********             18%                       ]  18 of 101 complete
#  [*********             19%                       ]  19 of 101 complete
#  [**********            20%                       ]  20 of 101 complete
#  [**********            21%                       ]  21 of 101 complete
#  [***********           22%                       ]  22 of 101 complete
#  [***********           23%                       ]  23 of 101 complete
#  [************          24%                       ]  24 of 101 complete
#  [************          25%                       ]  25 of 101 complete
#  [************          26%                       ]  26 of 101 complete
#  [*************         27%                       ]  27 of 101 complete
#  [*************         28%                       ]  28 of 101 complete
#  [**************        29%                       ]  29 of 101 complete
#  [**************        30%                       ]  30 of 101 complete
#  [***************       31%                       ]  31 of 101 complete
#  [***************       32%                       ]  32 of 101 complete
#  [****************      33%                       ]  33 of 101 complete
#  [****************      34%                       ]  34 of 101 complete
#  [*****************     35%                       ]  35 of 101 complete
#  [*****************     36%                       ]  36 of 101 complete
#  [******************    37%                       ]  37 of 101 complete
#  [******************    38%                       ]  38 of 101 complete
#  [*******************   39%                       ]  39 of 101 complete
#  [*******************   40%                       ]  40 of 101 complete
#  [********************  41%                       ]  41 of 101 complete
#  [********************  42%                       ]  42 of 101 complete
#  [********************* 43%                       ]  43 of 101 complete
#  [********************* 44%                       ]  44 of 101 complete
#  [**********************45%                       ]  45 of 101 complete
#  [**********************46%                       ]  46 of 101 complete
#  [**********************47%                       ]  47 of 101 complete
#  [**********************48%                       ]  48 of 101 complete
#  [**********************49%                       ]  49 of 101 complete
#  [**********************50%                       ]  50 of 101 complete
#  [**********************50%                       ]  51 of 101 complete
#  [**********************51%                       ]  52 of 101 complete
#  [**********************52%                       ]  53 of 101 complete
#  [**********************53%                       ]  54 of 101 complete
#  [**********************54%*                      ]  55 of 101 complete
#  [**********************55%*                      ]  56 of 101 complete
#  [**********************56%**                     ]  57 of 101 complete
#  [**********************57%**                     ]  58 of 101 complete
#  [**********************58%***                    ]  59 of 101 complete
#  [**********************59%***                    ]  60 of 101 complete
#  [**********************60%****                   ]  61 of 101 complete
#  [**********************61%****                   ]  62 of 101 complete
#  [**********************62%*****                  ]  63 of 101 complete
#  [**********************63%*****                  ]  64 of 101 complete
#  [**********************64%******                 ]  65 of 101 complete
#  [**********************65%******                 ]  66 of 101 complete
#  [**********************66%*******                ]  67 of 101 complete
#  [**********************67%*******                ]  68 of 101 complete
#  [**********************68%********               ]  69 of 101 complete
#  [**********************69%********               ]  70 of 101 complete
#  [**********************70%*********              ]  71 of 101 complete
#  [**********************71%*********              ]  72 of 101 complete
#  [**********************72%**********             ]  73 of 101 complete
#  [**********************73%**********             ]  74 of 101 complete
#  [**********************74%***********            ]  75 of 101 complete
#  [**********************75%***********            ]  76 of 101 complete
#  [**********************76%***********            ]  77 of 101 complete
#  [**********************77%************           ]  78 of 101 complete
#  [**********************78%************           ]  79 of 101 complete
#  [**********************79%*************          ]  80 of 101 complete
#  [**********************80%*************          ]  81 of 101 complete
#  [**********************81%**************         ]  82 of 101 complete
#  [**********************82%**************         ]  83 of 101 complete
#  [**********************83%***************        ]  84 of 101 complete
#  [**********************84%***************        ]  85 of 101 complete
#  [**********************85%****************       ]  86 of 101 complete
#  [**********************86%****************       ]  87 of 101 complete
#  [**********************87%*****************      ]  88 of 101 complete
#  [**********************88%*****************      ]  89 of 101 complete
#  [**********************89%******************     ]  90 of 101 complete
#  [**********************90%******************     ]  91 of 101 complete
#  [**********************91%*******************    ]  92 of 101 complete
#  [**********************92%*******************    ]  93 of 101 complete
#  [**********************93%********************   ]  94 of 101 complete
#  [**********************94%********************   ]  95 of 101 complete
#  [**********************95%*********************  ]  96 of 101 complete
#  [**********************96%*********************  ]  97 of 101 complete
#  [**********************97%********************** ]  98 of 101 complete
#  [**********************98%********************** ]  99 of 101 complete
#  [**********************99%***********************]  100 of 101 complete

# %%
#Ridge -10:10, splitCV, no repeats
plt.pcolor(np.mean(r2[:,:,:100,3],axis = 1))
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x146812320>

# %%
plt.plot(np.mean(r2[2,:,:,3],axis = 0))

# %%
sns.set_palette('Set1',n_colors=9)
mid = np.arange(130,135)
labels = tokens
align_window=window
tt = np.linspace(align_window[0],align_window[1],Fs[0].shape[1])
sns.set_context('talk')
sns.set_style('dark')
fig, axes = plt.subplots(figsize=(12,12))
canvas = FigureCanvas(fig)
for cnt,f in enumerate(Fs):
    ppl.scatter(np.nanmean(f[1,mid,:],axis = 0),np.nanmean(f[2,mid,:],axis = 0), alpha = 1, s=60)
plt.xlabel('F1')
plt.ylabel('F2')
ppl.legend(labels, bbox_to_anchor=(1, 1))

# %%
#Ridge -10:10, splitCV, no repeats
plt.pcolor(np.mean(r2[:,:,:,3],axis = 1))
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x1465c0b48>

# %%
plot(np.mean(r2[2,:,:,3],axis = 0))

# %%
plt.plot(Fs[0][1,:,7])

# %%
Fs[0][1,:,1]
# Out:
# array([  256.2,   251.3,   293.5,   277.5,   286.1,   322.7,   341.1,
#          314.2,   373.1,   544.4,   329.5,   588.8,   613.2,   387.8,
#          372.8,   314. ,   462.6,   294.1,   266.2,   333.8,   291. ,
#          256.2,   455.9,   402.1,   239.7,   341.3,   333.7,   417.1,
#          390.7,   266.8,   322.4,   404.3,   214.5,   415. ,   472.2,
#          427.5,   409. ,   420.2,   301.5,   347.7,   359.9,   566.3,
#          884.2,   694. ,   421.8,   226. ,   464. ,   664.3,   297.4,
#          309.1,   861.9,   516.4,   314.1,   370.9,   467.8,   504.2,
#          375.3,   218. ,   200. ,   315.2,   240.6,   203.9,   200.4,
#          245.3,   247.5,   265. ,   247.8,   267.5,   352.9,   507.2,
#          886.9,   267.3,   648.5,   733.9,   882.1,   289. ,   371.2,
#          329.2,   308.9,   327.5,   297.5,   397.3,   795.3,   273.8,
#          289.4,   263. ,   266.3,   265.6,   289.5,   537. ,   589.4,
#          349.3,   315.7,   340.7,   768.2,   656. ,   256.3,   407.1,
#          200. ,   222.9,   246.3,   467.2,   409. ,   415. ,   502.7,
#          609.2,   628.5,   637.5,   653.4,   660.9,   670.3,   684.6,
#          691.3,   685.8,   718.3,   685.6,   689.4,   692. ,   695.8,
#          698. ,   714. ,   694.5,   693.3,   703.9,   691.7,   704.4,
#          699.6,   698.5,   693.8,   684.4,   703.6,   684.9,   652.1,
#          616. ,   651. ,   680.4,   707.8,   475.4,   966.6,   550.6,
#          583.3,   862.2,   843.8,   683.7,   789.7,   858.5,   773.3,
#          665.7,   648.4,   598.2,   679.4,   792.1,   655.3,   748.4,
#          664.4,   658.4,   238.7,   726.1,   574.6,   541.4,   567.5,
#          746.2,   449. ,   887.2,   371.6,   365.4,   408.9,   305.4,
#          844.5,  1154. ,   300. ,   247.7,   200.4,   285.6,   242.4,
#          238.6,   554. ,   357.2,   305.3,   335.8,   469.1,   370.5,
#          530.7,   679.2,   631.6,  1055.6,  1047.3,   518.5,   642.9,
#          910.4,  1023.8,   749.5,   802.7,   680.1,   391.8,   399.1,
#          469.9,   344.1,   353.7,   347.7])

# %%
y
# Out:
#             0         1         2         3         4         5
# 0   -0.195939  1.158736  0.653742  1.059388  1.169245 -1.151349
# 1   -0.195939 -0.955398 -1.171070 -1.242073 -1.258941       NaN
# 2   -0.195939 -0.346781 -0.427558 -0.518969 -0.514465 -0.534676
# 3   -0.195939 -0.358585 -0.062114  0.271251  0.337477  0.560194
# 4   -0.195939 -0.703920 -0.648276 -0.578000 -0.516914  0.939922
# 5   -0.195939  1.506703  0.521105  1.148297  1.291519 -1.453858
# 6   -0.195939 -0.955398 -1.171070 -1.242073 -1.258941       NaN
# 7   -0.195939  1.222723  0.571405  0.608688  0.745761 -1.259992
# 8   -0.195939 -0.492495 -0.676605 -0.397548 -0.315841 -0.798656
# 9   -0.195939  0.703336  0.718533  0.778126  0.760784 -0.676520
# 10  -0.195939 -0.204271  0.384634  0.868103  0.953831  0.926641
# 11  -0.195939 -0.714032 -0.540649 -0.541383 -0.540290  1.856780
# 12  -0.195939  0.117704 -0.175648 -0.061956 -0.038421 -1.040462
# 13  -0.195939 -0.421010 -0.657999 -0.705664 -0.742680 -0.984561
# 14  -0.195939 -0.955398 -1.171070 -1.242073 -1.258941       NaN
# 15  -0.195939 -0.955398 -1.171070 -1.242073 -1.258941       NaN
# 16  -0.195939 -0.849909 -0.947635 -0.999813 -1.012948  1.007362
# 17  -0.195939 -0.518979 -0.545883 -0.252334 -0.213742 -0.171898
# 18  -0.195939 -0.045146 -0.311071 -0.290118 -0.239216 -1.010909
# 19  -0.195939  0.828105  0.590582  0.667081  0.650898 -0.937016
# 20  -0.195939 -0.955398 -1.171070 -1.242073 -1.258941       NaN
# 21  -0.195939 -0.253117 -0.276658 -0.171280  0.081049 -0.445333
# 22  -0.195939 -0.872244 -0.899616 -0.978953 -0.995440  2.979324
# 23  -0.195939 -0.955398 -1.171070 -1.242073 -1.258941       NaN
# 24  -0.195939 -0.655478 -0.330427 -0.284034 -0.280142  2.185347
# 25  -0.195939 -0.741070 -0.713698 -0.739435 -0.757758  1.034700
# 26  -0.195939 -0.955398 -1.171070 -1.242073 -1.258941       NaN
# 27  -0.195939  0.838415  0.344432  0.420902  0.533707 -1.182826
# 28   3.558338  0.035695  1.014473  1.589041  1.625613  1.157186
# 29  -0.195939 -0.955398 -1.171070 -1.242073 -1.258941       NaN
# ..        ...       ...       ...       ...       ...       ...
# 276 -0.195939 -0.660264 -0.675370 -0.550834 -0.534071  0.253047
# 277 -0.195939 -0.316966  0.535414  0.670495  0.626380  1.961788
# 278 -0.195939 -0.556723 -0.510941 -0.285806 -0.215923  0.212162
# 279 -0.195939 -0.770892 -0.822510 -0.798924 -0.775540  0.613552
# 280 -0.195939  0.887732  0.668097  0.528719  0.622310 -0.919639
# 281 -0.195939 -0.855446 -0.988001 -1.011279 -1.009704  0.514486
# 282 -0.195939 -0.321876 -0.553340 -0.546247 -0.547118 -0.958820
# 283 -0.195939 -0.613030 -0.628446 -0.545211 -0.525061  0.090216
# 284  5.456529 -0.079477  0.129597  0.493554  0.894057 -0.081804
# 285 -0.195939 -0.955398 -1.171070 -1.242073 -1.258941       NaN
# 286  2.606440 -0.352521 -0.074354  0.375350  0.565288  0.493121
# 287 -0.195939 -0.746475 -0.973867 -1.012959 -1.022611 -1.012440
# 288 -0.195939 -0.516857 -0.578741 -0.566566 -0.557355 -0.312710
# 289 -0.195939  1.847926  1.845463  1.432891  1.271451 -0.785111
# 290 -0.195939  2.120951  1.975118  1.435275  1.300461 -0.876889
# 291 -0.195939 -0.764990 -0.960726 -1.005533 -1.009307 -0.735834
# 292 -0.195939  1.572102  1.763619  1.378181  1.214752 -0.638815
# 293 -0.195939 -0.416614 -0.544734 -0.594674 -0.560634 -0.636412
# 294 -0.195939  2.323677  1.599990  1.278197  1.131936 -1.182441
# 295 -0.195939 -0.459894 -0.537797 -0.606213 -0.558982 -0.437666
# 296 -0.195939  2.690813  1.537907  1.078232  1.114964 -1.358100
# 297 -0.195939  2.625497  1.605633  1.195864  1.203332 -1.302255
# 298 -0.195939  0.736522  0.355725  0.544796  0.611504 -1.083824
# 299 -0.195939 -0.419341 -0.556657 -0.604886 -0.554778 -0.664501
# 300 -0.195939  2.519887  1.711006  1.353850  1.227623 -1.209564
# 301 -0.195939  1.471287  1.890195  1.870094  1.481458 -0.466113
# 302 -0.195939  1.219218  1.787560  1.845450  1.561377 -0.295767
# 303 -0.195939  1.850856  1.836811  1.690226  1.446445 -0.792347
# 304 -0.195939  1.475846  1.682657  1.550552  1.373245 -0.617022
# 305 -0.195939  1.399962  1.936413  1.802372  1.451336 -0.366648
#
# [306 rows x 6 columns]

# %%
forms = ['F0','F1','F2','F3','F4']
Fall = np.concatenate(Fs,axis=2)
dat = dict(zip(forms,np.nanmean(Fall[:,frange,:],axis = 1)))
Fmid = pd.DataFrame.from_dict(dat)
Fmid = Fmid.fillna(Fmid.median(),inplace=True)
F2_1 = pd.Series(Fmid['F2']/Fmid['F1'],name = 'F2/F1')

# %%
Fmid.drop(badT,inplace = True)

# %%
Fmid
# Out:
#             F0           F1           F2           F3           F4
# 0     0.000000   711.643333  1354.162517  2413.873636  3350.571282
# 1     0.000000     0.000000     0.000000     0.000000     0.000000
# 2     0.000000   204.867902   551.748368   758.423124  1027.276503
# 3     0.000000   200.894476   822.938019  1587.241702  2202.843333
# 4     0.000000    84.650793   387.956853   696.509604  1023.898228
# 5     0.000000   828.772960  1255.735221  2507.125431  3519.293706
# 6     0.000000     0.000000     0.000000     0.000000     0.000000
# 7     0.000000   733.181841  1293.061888  1941.160536  2766.220000
# 8     0.000000   155.819021   366.934615   885.775082  1301.350839
# 9     0.000000   558.350000  1402.243077  2118.874569  2786.950093
# 10    0.000000   252.838601  1154.462354  2213.245967  3053.329231
# 11    0.000000    81.246970   467.825385   734.915221   991.642051
# 12    0.000000   361.219347   738.686247  1237.759254  1684.153823
# 13    0.000000   179.881702   380.741492   562.609534   712.370023
# 14    0.000000     0.000000     0.000000     0.000000     0.000000
# 15    0.000000     0.000000     0.000000     0.000000     0.000000
# 16    0.000000    35.509021   165.807832   254.092751   339.437016
# 17    0.000000   146.903963   463.941166  1038.082634  1442.234965
# 18    0.000000   306.402075   638.190862   998.452587  1407.084009
# 19    0.000000   600.348811  1307.292354  2002.404779  2635.321375
# 20    0.000000     0.000000     0.000000     0.000000     0.000000
# 21    0.000000   236.396410   663.728578  1123.095291  1849.006946
# 22    0.000000    27.990816   201.441795   275.971888   363.595991
# 23    0.000000     0.000000     0.000000     0.000000     0.000000
# 24    0.000000   100.956690   623.827040  1004.834172  1350.611096
# 25    0.000000    72.145548   339.408228   527.189161   691.564685
# 26    0.000000     0.000000     0.000000     0.000000     0.000000
# 27    0.000000   603.819138  1124.629207  1744.201865  2473.614266
# 28   59.521795   333.614079  1621.855082  2969.397762  3980.297925
# 29    0.000000     0.000000     0.000000     0.000000     0.000000
# ..         ...          ...          ...          ...          ...
# 276   0.000000    99.345734   367.850653   725.001865  1000.223566
# 277   0.000000   214.904103  1266.353124  2005.986200  2601.490793
# 278   0.000000   134.198881   489.870723  1002.975035  1439.225361
# 279   0.000000    62.107133   258.660886   464.794266   667.028625
# 280   0.000000   620.420093  1364.815594  1857.285431  2595.873776
# 281   0.000000    33.645361   135.852937   242.066760   343.913333
# 282   0.000000   213.251329   458.407319   729.812821   982.219580
# 283   0.000000   115.245268   402.672611   730.899627  1012.656270
# 284  89.616457   294.845571   965.203310  1820.402657  2970.849324
# 285   0.000000     0.000000     0.000000     0.000000     0.000000
# 286  44.430023   202.935664   813.855035  1696.424662  2517.191608
# 287   0.000000    70.326061   146.340956   240.304662   326.103776
# 288   0.000000   147.618438   439.557646   708.501841   968.094242
# 289   0.000000   943.632890  2238.518928  2805.620326  3491.601445
# 290   0.000000  1035.536434  2334.733753  2808.120839  3531.632168
# 291   0.000000    64.093683   156.093054   248.093730   344.461608
# 292   0.000000   850.787179  2177.783636  2748.238228  3413.365501
# 293   0.000000   181.361305   464.794009   679.021002   963.570233
# 294   0.000000  1103.776224  2056.357599  2643.370909  3299.089604
# 295   0.000000   166.792634   469.941422   666.917855   965.849720
# 296   0.000000  1227.358765  2010.286946  2433.638904  3275.671329
# 297   0.000000  1205.372611  2060.545082  2557.015711  3397.607459
# 298   0.000000   569.520886  1133.009114  1874.147063  2580.963170
# 299   0.000000   180.443263   455.945501   668.310117   971.650093
# 300   0.000000  1169.823007  2138.740606  2722.719231  3431.125245
# 301   0.000000   816.851469  2271.714056  3264.177925  3781.383590
# 302   0.000000   732.002238  2195.549720  3238.330373  3891.661072
# 303   0.000000   944.618974  2232.098275  3075.525035  3733.070490
# 304   0.000000   818.386340  2117.703473  2929.028834  3632.064336
# 305   0.000000   792.842821  2306.011492  3193.148322  3739.819580
#
# [306 rows x 5 columns]

# %%
badT
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
# 5      False
# 6       True
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14      True
# 15      True
# 16     False
# 17     False
# 18     False
# 19     False
# 20      True
# 21     False
# 22     False
# 23      True
# 24     False
# 25     False
# 26      True
# 27     False
# 28     False
# 29      True
#        ...
# 276    False
# 277    False
# 278    False
# 279    False
# 280    False
# 281    False
# 282    False
# 283    False
# 284    False
# 285     True
# 286    False
# 287    False
# 288    False
# 289    False
# 290    False
# 291    False
# 292    False
# 293    False
# 294    False
# 295    False
# 296    False
# 297    False
# 298    False
# 299    False
# 300    False
# 301    False
# 302    False
# 303    False
# 304    False
# 305    False
# dtype: bool

# %%
Fmid = pd.DataFrame.from_dict(dat)

# %%
badT = sum(Fmid == 0,axis=1) == 5

# %%
badT
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
# 5      False
# 6       True
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14      True
# 15      True
# 16     False
# 17     False
# 18     False
# 19     False
# 20      True
# 21     False
# 22     False
# 23      True
# 24     False
# 25     False
# 26      True
# 27     False
# 28     False
# 29      True
#        ...
# 276    False
# 277    False
# 278    False
# 279    False
# 280    False
# 281    False
# 282    False
# 283    False
# 284    False
# 285     True
# 286    False
# 287    False
# 288    False
# 289    False
# 290    False
# 291    False
# 292    False
# 293    False
# 294    False
# 295    False
# 296    False
# 297    False
# 298    False
# 299    False
# 300    False
# 301    False
# 302    False
# 303    False
# 304    False
# 305    False
# dtype: bool
