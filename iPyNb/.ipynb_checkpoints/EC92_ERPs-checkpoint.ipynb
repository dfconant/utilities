# %%
#Intitialize
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import scipy as sp
import scipy.stats as stats
import numpy as np
from sklearn.cross_validation import train_test_split, LeaveOneOut, LeaveOneLabelOut, ShuffleSplit
from sklearn.decomposition import PCA
from sklearn.lda import LDA
from sklearn.linear_model import Lars, Ridge
import pandas as pd
import pdb
import prettyplotlib as ppl
from BDutils import ProgressBar, moving_average
from scipy.signal import savgol_filter
import seaborn as sns
import matplotlib.gridspec as gridspec
from ECoGstats import makeD_multi, process_kin, shuffle_df, smooth_formants, Ridge_MLR, Ds2Xy, smooth_derivative,ClusterSeparability
from ecog_viz import plotERPs, LDA_proj_scatter, gestural_score, separability_timecourse,feature_correlations,vowel_svm,R2viz,plotkhat
from __future__ import division
from matplotlib.backends.backend_agg import (FigureCanvasAgg as FigureCanvas)
from scipy.stats import mstats
save_pth = '/Users/david_conant/Dropbox/Vowels/Figs/EC92/'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
subj = 'EC92'
pth = '/Users/david_conant/Dropbox/Vowels/'+subj + '/'
save_pth = pth + 'Figs' + subj + '/'
blocks = [35,36,37,39,45,46]
tokens = ['AAA','AEE','AHH','EHH','ERR','IHH','IYY','UHH','UWW']
window = np.array([-1,1])
[D,anat,start_times,stop_times] = makeD_multi(pth,blocks,tokens,align_window=window)
Ds = [D[d] for d in tokens]
[Ds,anat] = correct_EC34(Ds,anat)
Dall = np.concatenate(Ds,axis=2)
fig_filename = save_pth + 'EC92_ERPs_all.png'
ax = plotERPs([Dall],align_window = np.array([-1,1]), anatomy = anat,labels = tokens, fig_filename = fig_filename)
# Out:
# File found; Loading...
# Loaded
#  [                       0%                       ]
#  [                       1%                       ]  2 of 256 complete
#  [                       1%                       ]  3 of 256 complete
#  [*                      2%                       ]  4 of 256 complete
#  [*                      2%                       ]  5 of 256 complete
#  [*                      2%                       ]  6 of 256 complete
#  [*                      3%                       ]  7 of 256 complete
#  [*                      3%                       ]  8 of 256 complete
#  [**                     4%                       ]  9 of 256 complete
#  [**                     4%                       ]  10 of 256 complete
#  [**                     4%                       ]  11 of 256 complete
#  [**                     5%                       ]  12 of 256 complete
#  [**                     5%                       ]  13 of 256 complete
#  [**                     5%                       ]  14 of 256 complete
#  [***                    6%                       ]  15 of 256 complete
#  [***                    6%                       ]  16 of 256 complete
#  [***                    7%                       ]  17 of 256 complete
#  [***                    7%                       ]  18 of 256 complete
#  [***                    7%                       ]  19 of 256 complete
#  [****                   8%                       ]  20 of 256 complete
#  [****                   8%                       ]  21 of 256 complete
#  [****                   9%                       ]  22 of 256 complete
#  [****                   9%                       ]  23 of 256 complete
#  [****                   9%                       ]  24 of 256 complete
#  [*****                 10%                       ]  25 of 256 complete
#  [*****                 10%                       ]  26 of 256 complete
#  [*****                 11%                       ]  27 of 256 complete
#  [*****                 11%                       ]  28 of 256 complete
#  [*****                 11%                       ]  29 of 256 complete
#  [******                12%                       ]  30 of 256 complete
#  [******                12%                       ]  31 of 256 complete
#  [******                13%                       ]  32 of 256 complete
#  [******                13%                       ]  33 of 256 complete
#  [******                13%                       ]  34 of 256 complete
#  [*******               14%                       ]  35 of 256 complete
#  [*******               14%                       ]  36 of 256 complete
#  [*******               14%                       ]  37 of 256 complete
#  [*******               15%                       ]  38 of 256 complete
#  [*******               15%                       ]  39 of 256 complete
#  [********              16%                       ]  40 of 256 complete
#  [********              16%                       ]  41 of 256 complete
#  [********              16%                       ]  42 of 256 complete
#  [********              17%                       ]  43 of 256 complete
#  [********              17%                       ]  44 of 256 complete
#  [*********             18%                       ]  45 of 256 complete
#  [*********             18%                       ]  46 of 256 complete
#  [*********             18%                       ]  47 of 256 complete
#  [*********             19%                       ]  48 of 256 complete
#  [*********             19%                       ]  49 of 256 complete
#  [**********            20%                       ]  50 of 256 complete
#  [**********            20%                       ]  51 of 256 complete
#  [**********            20%                       ]  52 of 256 complete
#  [**********            21%                       ]  53 of 256 complete
#  [**********            21%                       ]  54 of 256 complete
#  [**********            21%                       ]  55 of 256 complete
#  [***********           22%                       ]  56 of 256 complete
#  [***********           22%                       ]  57 of 256 complete
#  [***********           23%                       ]  58 of 256 complete
#  [***********           23%                       ]  59 of 256 complete
#  [***********           23%                       ]  60 of 256 complete
#  [************          24%                       ]  61 of 256 complete
#  [************          24%                       ]  62 of 256 complete
#  [************          25%                       ]  63 of 256 complete
#  [************          25%                       ]  64 of 256 complete
#  [************          25%                       ]  65 of 256 complete
#  [************          26%                       ]  66 of 256 complete
#  [************          26%                       ]  67 of 256 complete
#  [*************         27%                       ]  68 of 256 complete
#  [*************         27%                       ]  69 of 256 complete
#  [*************         27%                       ]  70 of 256 complete
#  [*************         28%                       ]  71 of 256 complete
#  [*************         28%                       ]  72 of 256 complete
#  [**************        29%                       ]  73 of 256 complete
#  [**************        29%                       ]  74 of 256 complete
#  [**************        29%                       ]  75 of 256 complete
#  [**************        30%                       ]  76 of 256 complete
#  [**************        30%                       ]  77 of 256 complete
#  [**************        30%                       ]  78 of 256 complete
#  [***************       31%                       ]  79 of 256 complete
#  [***************       31%                       ]  80 of 256 complete
#  [***************       32%                       ]  81 of 256 complete
#  [***************       32%                       ]  82 of 256 complete
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-b3747268a99e> in <module>()
#       9 Dall = np.concatenate(Ds,axis=2)
#      10 fig_filename = save_pth + 'EC92_ERPs_all.png'
# ---> 11 ax = plotERPs([Dall],align_window = np.array([-1,1]), anatomy = anat,labels = tokens, fig_filename = fig_filename)
#
# /Users/david_conant/Dropbox/changrepo/python/visualization/ecog_viz.pyc in plotERPs(Ds, align_window, fig_filename, yscale, anatomy, labels, elects, co, alph, sm)
#     105
#     106         if len(elects) is 256:
# --> 107             ax = fig.add_subplot(x,x,channel_order[ielect])
#     108         else:
#     109             ax = fig.add_subplot(x,x,cnt+1)
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/figure.pyc in add_subplot(self, *args, **kwargs)
#     962                     self._axstack.remove(ax)
#     963
# --> 964             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#     965
#     966         self._axstack.add(key, a)
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/axes/_subplots.pyc in __init__(self, fig, *args, **kwargs)
#      76
#      77         # _axes_class is set in the subplot_class_factory
# ---> 78         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      79
#      80     def __reduce__(self):
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in __init__(self, fig, rect, axisbg, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     423
#     424         # this call may differ for non-sep axes, e.g., polar
# --> 425         self._init_axis()
#     426
#     427         if axisbg is None:
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _init_axis(self)
#     483         self.spines['bottom'].register_axis(self.xaxis)
#     484         self.spines['top'].register_axis(self.xaxis)
# --> 485         self.yaxis = maxis.YAxis(self)
#     486         self.spines['left'].register_axis(self.yaxis)
#     487         self.spines['right'].register_axis(self.yaxis)
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/axis.pyc in __init__(self, axes, pickradius)
#     664         self._minor_tick_kw = dict()
#     665
# --> 666         self.cla()
#     667         self._set_scale('linear')
#     668
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/axis.pyc in cla(self)
#     752         self._set_artist_props(self.label)
#     753
# --> 754         self.reset_ticks()
#     755
#     756         self.converter = None
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/axis.pyc in reset_ticks(self)
#     765         cbook.popall(self.minorTicks)
#     766
# --> 767         self.majorTicks.extend([self._get_tick(major=True)])
#     768         self.minorTicks.extend([self._get_tick(major=False)])
#     769         self._lastNumMajorTicks = 1
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_tick(self, major)
#    1962         else:
#    1963             tick_kw = self._minor_tick_kw
# -> 1964         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    1965
#    1966     def _get_label(self):
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/axis.pyc in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     146         self.apply_tickdir(tickdir)
#     147
# --> 148         self.tick1line = self._get_tick1line()
#     149         self.tick2line = self._get_tick2line()
#     150         self.gridline = self._get_gridline()
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_tick1line(self)
#     536                     markersize=self._size,
#     537                     markeredgewidth=self._width,
# --> 538                     zorder=self._zorder,
#     539                     )
#     540         l.set_transform(self.axes.get_yaxis_transform(which='tick1'))
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/lines.pyc in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     325         self.set_color(color)
#     326         self._marker = MarkerStyle()
# --> 327         self.set_marker(marker)
#     328         self.set_markevery(markevery)
#     329         self.set_antialiased(antialiased)
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/lines.pyc in set_marker(self, marker)
#     985
#     986         """
# --> 987         self._marker.set_marker(marker)
#     988
#     989     def set_markeredgecolor(self, ec):
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/markers.pyc in set_marker(self, marker)
#     248
#     249         self._marker = marker
# --> 250         self._recache()
#     251
#     252     def get_path(self):
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/markers.pyc in _recache(self)
#     189         self._capstyle = 'butt'
#     190         self._filled = True
# --> 191         self._marker_function()
#     192
#     193     if six.PY3:
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/markers.pyc in _set_tickleft(self)
#     678
#     679     def _set_tickleft(self):
# --> 680         self._transform = Affine2D().scale(-1.0, 1.0)
#     681         self._snap_threshold = 1.0
#     682         self._filled = False
#
# KeyboardInterrupt:

# %%
tokens = ['AAA','IYY','UWW']

window = np.array([-1,1])
[D,anat,start_times,stop_times] = makeD_multi(pth,blocks,tokens,align_window=window)
Ds = [D[d] for d in tokens]
[Ds,anat] = correct_EC34(Ds,anat)
fig_filename = save_pth + 'EC92_ERPs_cat3.png'
ax = plotERPs(Ds,align_window = np.array([-1,1]), anatomy = anat,labels = tokens, fig_filename=fig_filename)
# Out:
# Processing block 35
# Processing block 36
# Processing block 37
# Processing block 39
# Processing block 45
# Processing block 46
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/numpy/lib/nanfunctions.py:607: RuntimeWarning: Mean of empty slice
#   warnings.warn("Mean of empty slice", RuntimeWarning)
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/numpy/lib/nanfunctions.py:737: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   warnings.warn("Degrees of freedom <= 0 for slice.", RuntimeWarning)
#  [                       0%                       ]
#  [                       1%                       ]  2 of 256 complete
#  [                       1%                       ]  3 of 256 complete
#  [*                      2%                       ]  4 of 256 complete
#  [*                      2%                       ]  5 of 256 complete
#  [*                      2%                       ]  6 of 256 complete
#  [*                      3%                       ]  7 of 256 complete
#  [*                      3%                       ]  8 of 256 complete
#  [**                     4%                       ]  9 of 256 complete
#  [**                     4%                       ]  10 of 256 complete
#  [**                     4%                       ]  11 of 256 complete
#  [**                     5%                       ]  12 of 256 complete
#  [**                     5%                       ]  13 of 256 complete
#  [**                     5%                       ]  14 of 256 complete
#  [***                    6%                       ]  15 of 256 complete
#  [***                    6%                       ]  16 of 256 complete
#  [***                    7%                       ]  17 of 256 complete
#  [***                    7%                       ]  18 of 256 complete
#  [***                    7%                       ]  19 of 256 complete
#  [****                   8%                       ]  20 of 256 complete
#  [****                   8%                       ]  21 of 256 complete
#  [****                   9%                       ]  22 of 256 complete
#  [****                   9%                       ]  23 of 256 complete
#  [****                   9%                       ]  24 of 256 complete
#  [*****                 10%                       ]  25 of 256 complete
#  [*****                 10%                       ]  26 of 256 complete
#  [*****                 11%                       ]  27 of 256 complete
#  [*****                 11%                       ]  28 of 256 complete
#  [*****                 11%                       ]  29 of 256 complete
#  [******                12%                       ]  30 of 256 complete
#  [******                12%                       ]  31 of 256 complete
#  [******                13%                       ]  32 of 256 complete
#  [******                13%                       ]  33 of 256 complete
#  [******                13%                       ]  34 of 256 complete
#  [*******               14%                       ]  35 of 256 complete
#  [*******               14%                       ]  36 of 256 complete
#  [*******               14%                       ]  37 of 256 complete
#  [*******               15%                       ]  38 of 256 complete
#  [*******               15%                       ]  39 of 256 complete
#  [********              16%                       ]  40 of 256 complete
#  [********              16%                       ]  41 of 256 complete
#  [********              16%                       ]  42 of 256 complete
#  [********              17%                       ]  43 of 256 complete
#  [********              17%                       ]  44 of 256 complete
#  [*********             18%                       ]  45 of 256 complete
#  [*********             18%                       ]  46 of 256 complete
#  [*********             18%                       ]  47 of 256 complete
#  [*********             19%                       ]  48 of 256 complete
#  [*********             19%                       ]  49 of 256 complete
#  [**********            20%                       ]  50 of 256 complete
#  [**********            20%                       ]  51 of 256 complete
#  [**********            20%                       ]  52 of 256 complete
#  [**********            21%                       ]  53 of 256 complete
#  [**********            21%                       ]  54 of 256 complete
#  [**********            21%                       ]  55 of 256 complete
#  [***********           22%                       ]  56 of 256 complete
#  [***********           22%                       ]  57 of 256 complete
#  [***********           23%                       ]  58 of 256 complete
#  [***********           23%                       ]  59 of 256 complete
#  [***********           23%                       ]  60 of 256 complete
#  [************          24%                       ]  61 of 256 complete
#  [************          24%                       ]  62 of 256 complete
#  [************          25%                       ]  63 of 256 complete
#  [************          25%                       ]  64 of 256 complete
#  [************          25%                       ]  65 of 256 complete
#  [************          26%                       ]  66 of 256 complete
#  [************          26%                       ]  67 of 256 complete
#  [*************         27%                       ]  68 of 256 complete
#  [*************         27%                       ]  69 of 256 complete
#  [*************         27%                       ]  70 of 256 complete
#  [*************         28%                       ]  71 of 256 complete
#  [*************         28%                       ]  72 of 256 complete
#  [**************        29%                       ]  73 of 256 complete
#  [**************        29%                       ]  74 of 256 complete
#  [**************        29%                       ]  75 of 256 complete
#  [**************        30%                       ]  76 of 256 complete
#  [**************        30%                       ]  77 of 256 complete
#  [**************        30%                       ]  78 of 256 complete
#  [***************       31%                       ]  79 of 256 complete
#  [***************       31%                       ]  80 of 256 complete
#  [***************       32%                       ]  81 of 256 complete
#  [***************       32%                       ]  82 of 256 complete
#  [***************       32%                       ]  83 of 256 complete
#  [****************      33%                       ]  84 of 256 complete
#  [****************      33%                       ]  85 of 256 complete
#  [****************      34%                       ]  86 of 256 complete
#  [****************      34%                       ]  87 of 256 complete
#  [****************      34%                       ]  88 of 256 complete
#  [*****************     35%                       ]  89 of 256 complete
#  [*****************     35%                       ]  90 of 256 complete
#  [*****************     36%                       ]  91 of 256 complete
#  [*****************     36%                       ]  92 of 256 complete
#  [*****************     36%                       ]  93 of 256 complete
#  [******************    37%                       ]  94 of 256 complete
#  [******************    37%                       ]  95 of 256 complete
#  [******************    38%                       ]  96 of 256 complete
#  [******************    38%                       ]  97 of 256 complete
#  [******************    38%                       ]  98 of 256 complete
#  [*******************   39%                       ]  99 of 256 complete
#  [*******************   39%                       ]  100 of 256 complete
#  [*******************   39%                       ]  101 of 256 complete
#  [*******************   40%                       ]  102 of 256 complete
#  [*******************   40%                       ]  103 of 256 complete
#  [********************  41%                       ]  104 of 256 complete
#  [********************  41%                       ]  105 of 256 complete
#  [********************  41%                       ]  106 of 256 complete
#  [********************  42%                       ]  107 of 256 complete
#  [********************  42%                       ]  108 of 256 complete
#  [********************* 43%                       ]  109 of 256 complete
#  [********************* 43%                       ]  110 of 256 complete
#  [********************* 43%                       ]  111 of 256 complete
#  [********************* 44%                       ]  112 of 256 complete
#  [********************* 44%                       ]  113 of 256 complete
#  [**********************45%                       ]  114 of 256 complete
#  [**********************45%                       ]  115 of 256 complete
#  [**********************45%                       ]  116 of 256 complete
#  [**********************46%                       ]  117 of 256 complete
#  [**********************46%                       ]  118 of 256 complete
#  [**********************46%                       ]  119 of 256 complete
#  [**********************47%                       ]  120 of 256 complete
#  [**********************47%                       ]  121 of 256 complete
#  [**********************48%                       ]  122 of 256 complete
#  [**********************48%                       ]  123 of 256 complete
#  [**********************48%                       ]  124 of 256 complete
#  [**********************49%                       ]  125 of 256 complete
#  [**********************49%                       ]  126 of 256 complete
#  [**********************50%                       ]  127 of 256 complete
#  [**********************50%                       ]  128 of 256 complete
#  [**********************50%                       ]  129 of 256 complete
#  [**********************51%                       ]  130 of 256 complete
#  [**********************51%                       ]  131 of 256 complete
#  [**********************52%                       ]  132 of 256 complete
#  [**********************52%                       ]  133 of 256 complete
#  [**********************52%                       ]  134 of 256 complete
#  [**********************53%                       ]  135 of 256 complete
#  [**********************53%                       ]  136 of 256 complete
#  [**********************54%*                      ]  137 of 256 complete
#  [**********************54%*                      ]  138 of 256 complete
#  [**********************54%*                      ]  139 of 256 complete
#  [**********************55%*                      ]  140 of 256 complete
#  [**********************55%*                      ]  141 of 256 complete
#  [**********************55%*                      ]  142 of 256 complete
#  [**********************56%**                     ]  143 of 256 complete
#  [**********************56%**                     ]  144 of 256 complete
#  [**********************57%**                     ]  145 of 256 complete
#  [**********************57%**                     ]  146 of 256 complete
#  [**********************57%**                     ]  147 of 256 complete
#  [**********************58%***                    ]  148 of 256 complete
#  [**********************58%***                    ]  149 of 256 complete
#  [**********************59%***                    ]  150 of 256 complete
#  [**********************59%***                    ]  151 of 256 complete
#  [**********************59%***                    ]  152 of 256 complete
#  [**********************60%****                   ]  153 of 256 complete
#  [**********************60%****                   ]  154 of 256 complete
#  [**********************61%****                   ]  155 of 256 complete
#  [**********************61%****                   ]  156 of 256 complete
#  [**********************61%****                   ]  157 of 256 complete
#  [**********************62%*****                  ]  158 of 256 complete
#  [**********************62%*****                  ]  159 of 256 complete
#  [**********************63%*****                  ]  160 of 256 complete
#  [**********************63%*****                  ]  161 of 256 complete
#  [**********************63%*****                  ]  162 of 256 complete
#  [**********************64%******                 ]  163 of 256 complete
#  [**********************64%******                 ]  164 of 256 complete
#  [**********************64%******                 ]  165 of 256 complete
#  [**********************65%******                 ]  166 of 256 complete
#  [**********************65%******                 ]  167 of 256 complete
#  [**********************66%*******                ]  168 of 256 complete
#  [**********************66%*******                ]  169 of 256 complete
#  [**********************66%*******                ]  170 of 256 complete
#  [**********************67%*******                ]  171 of 256 complete
#  [**********************67%*******                ]  172 of 256 complete
#  [**********************68%********               ]  173 of 256 complete
#  [**********************68%********               ]  174 of 256 complete
#  [**********************68%********               ]  175 of 256 complete
#  [**********************69%********               ]  176 of 256 complete
#  [**********************69%********               ]  177 of 256 complete
#  [**********************70%*********              ]  178 of 256 complete
#  [**********************70%*********              ]  179 of 256 complete
#  [**********************70%*********              ]  180 of 256 complete
#  [**********************71%*********              ]  181 of 256 complete
#  [**********************71%*********              ]  182 of 256 complete
#  [**********************71%*********              ]  183 of 256 complete
#  [**********************72%**********             ]  184 of 256 complete
#  [**********************72%**********             ]  185 of 256 complete
#  [**********************73%**********             ]  186 of 256 complete
#  [**********************73%**********             ]  187 of 256 complete
#  [**********************73%**********             ]  188 of 256 complete
#  [**********************74%***********            ]  189 of 256 complete
#  [**********************74%***********            ]  190 of 256 complete
#  [**********************75%***********            ]  191 of 256 complete
#  [**********************75%***********            ]  192 of 256 complete
#  [**********************75%***********            ]  193 of 256 complete
#  [**********************76%***********            ]  194 of 256 complete
#  [**********************76%***********            ]  195 of 256 complete
#  [**********************77%************           ]  196 of 256 complete
#  [**********************77%************           ]  197 of 256 complete
#  [**********************77%************           ]  198 of 256 complete
#  [**********************78%************           ]  199 of 256 complete
#  [**********************78%************           ]  200 of 256 complete
#  [**********************79%*************          ]  201 of 256 complete
#  [**********************79%*************          ]  202 of 256 complete
#  [**********************79%*************          ]  203 of 256 complete
#  [**********************80%*************          ]  204 of 256 complete
#  [**********************80%*************          ]  205 of 256 complete
#  [**********************80%*************          ]  206 of 256 complete
#  [**********************81%**************         ]  207 of 256 complete
#  [**********************81%**************         ]  208 of 256 complete
#  [**********************82%**************         ]  209 of 256 complete
#  [**********************82%**************         ]  210 of 256 complete
#  [**********************82%**************         ]  211 of 256 complete
#  [**********************83%***************        ]  212 of 256 complete
#  [**********************83%***************        ]  213 of 256 complete
#  [**********************84%***************        ]  214 of 256 complete
#  [**********************84%***************        ]  215 of 256 complete
#  [**********************84%***************        ]  216 of 256 complete
#  [**********************85%****************       ]  217 of 256 complete
#  [**********************85%****************       ]  218 of 256 complete
#  [**********************86%****************       ]  219 of 256 complete
#  [**********************86%****************       ]  220 of 256 complete
#  [**********************86%****************       ]  221 of 256 complete
#  [**********************87%*****************      ]  222 of 256 complete
#  [**********************87%*****************      ]  223 of 256 complete
#  [**********************88%*****************      ]  224 of 256 complete
#  [**********************88%*****************      ]  225 of 256 complete
#  [**********************88%*****************      ]  226 of 256 complete
#  [**********************89%******************     ]  227 of 256 complete
#  [**********************89%******************     ]  228 of 256 complete
#  [**********************89%******************     ]  229 of 256 complete
#  [**********************90%******************     ]  230 of 256 complete
#  [**********************90%******************     ]  231 of 256 complete
#  [**********************91%*******************    ]  232 of 256 complete
#  [**********************91%*******************    ]  233 of 256 complete
#  [**********************91%*******************    ]  234 of 256 complete
#  [**********************92%*******************    ]  235 of 256 complete
#  [**********************92%*******************    ]  236 of 256 complete
#  [**********************93%********************   ]  237 of 256 complete
#  [**********************93%********************   ]  238 of 256 complete
#  [**********************93%********************   ]  239 of 256 complete
#  [**********************94%********************   ]  240 of 256 complete
#  [**********************94%********************   ]  241 of 256 complete
#  [**********************95%*********************  ]  242 of 256 complete
#  [**********************95%*********************  ]  243 of 256 complete
#  [**********************95%*********************  ]  244 of 256 complete
#  [**********************96%*********************  ]  245 of 256 complete
#  [**********************96%*********************  ]  246 of 256 complete
#  [**********************96%*********************  ]  247 of 256 complete
#  [**********************97%********************** ]  248 of 256 complete
#  [**********************97%********************** ]  249 of 256 complete
#  [**********************98%********************** ]  250 of 256 complete
#  [**********************98%********************** ]  251 of 256 complete
#  [**********************98%********************** ]  252 of 256 complete
#  [**********************99%***********************]  253 of 256 complete
#  [**********************99%***********************]  254 of 256 complete
#  [*********************100%***********************]  255 of 256 complete
#  [*********************100%***********************]  256 of 256 complete

# %%
tokens = ['AAA','AEE','AHH','EHH','ERR','IHH','IYY','UHH','UWW']

window = np.array([-1,1])
[D,anat,start_times,stop_times] = makeD_multi(pth,blocks,tokens,align_window=window)
Ds = [D[d] for d in tokens]
[Ds,anat] = correct_EC34(Ds,anat)
[Ds,anat] = correct_EC34(Ds,anat)
fig_filename = save_pth + 'EC92_ERPs_cat9.png'
ax = plotERPs(Ds,align_window = np.array([-1,1]), anatomy = anat,labels = tokens, fig_filename=fig_filename)
# Out:
# File found; Loading...
# Loaded
#  [                       0%                       ]
#  [                       1%                       ]  2 of 256 complete
#  [                       1%                       ]  3 of 256 complete
#  [*                      2%                       ]  4 of 256 complete
#  [*                      2%                       ]  5 of 256 complete
#  [*                      2%                       ]  6 of 256 complete
#  [*                      3%                       ]  7 of 256 complete
#  [*                      3%                       ]  8 of 256 complete
#  [**                     4%                       ]  9 of 256 complete
#  [**                     4%                       ]  10 of 256 complete
#  [**                     4%                       ]  11 of 256 complete
#  [**                     5%                       ]  12 of 256 complete
#  [**                     5%                       ]  13 of 256 complete
#  [**                     5%                       ]  14 of 256 complete
#  [***                    6%                       ]  15 of 256 complete
#  [***                    6%                       ]  16 of 256 complete
#  [***                    7%                       ]  17 of 256 complete
#  [***                    7%                       ]  18 of 256 complete
#  [***                    7%                       ]  19 of 256 complete
#  [****                   8%                       ]  20 of 256 complete
#  [****                   8%                       ]  21 of 256 complete
#  [****                   9%                       ]  22 of 256 complete
#  [****                   9%                       ]  23 of 256 complete
#  [****                   9%                       ]  24 of 256 complete
#  [*****                 10%                       ]  25 of 256 complete
#  [*****                 10%                       ]  26 of 256 complete
#  [*****                 11%                       ]  27 of 256 complete
#  [*****                 11%                       ]  28 of 256 complete
#  [*****                 11%                       ]  29 of 256 complete
#  [******                12%                       ]  30 of 256 complete
#  [******                12%                       ]  31 of 256 complete
#  [******                13%                       ]  32 of 256 complete
#  [******                13%                       ]  33 of 256 complete
#  [******                13%                       ]  34 of 256 complete
#  [*******               14%                       ]  35 of 256 complete
#  [*******               14%                       ]  36 of 256 complete
#  [*******               14%                       ]  37 of 256 complete
#  [*******               15%                       ]  38 of 256 complete
#  [*******               15%                       ]  39 of 256 complete
#  [********              16%                       ]  40 of 256 complete
#  [********              16%                       ]  41 of 256 complete
#  [********              16%                       ]  42 of 256 complete
#  [********              17%                       ]  43 of 256 complete
#  [********              17%                       ]  44 of 256 complete
#  [*********             18%                       ]  45 of 256 complete
#  [*********             18%                       ]  46 of 256 complete
#  [*********             18%                       ]  47 of 256 complete
#  [*********             19%                       ]  48 of 256 complete
#  [*********             19%                       ]  49 of 256 complete
#  [**********            20%                       ]  50 of 256 complete
#  [**********            20%                       ]  51 of 256 complete
#  [**********            20%                       ]  52 of 256 complete
#  [**********            21%                       ]  53 of 256 complete
#  [**********            21%                       ]  54 of 256 complete
#  [**********            21%                       ]  55 of 256 complete
#  [***********           22%                       ]  56 of 256 complete
#  [***********           22%                       ]  57 of 256 complete
#  [***********           23%                       ]  58 of 256 complete
#  [***********           23%                       ]  59 of 256 complete
#  [***********           23%                       ]  60 of 256 complete
#  [************          24%                       ]  61 of 256 complete
#  [************          24%                       ]  62 of 256 complete
#  [************          25%                       ]  63 of 256 complete
#  [************          25%                       ]  64 of 256 complete
#  [************          25%                       ]  65 of 256 complete
#  [************          26%                       ]  66 of 256 complete
#  [************          26%                       ]  67 of 256 complete
#  [*************         27%                       ]  68 of 256 complete
#  [*************         27%                       ]  69 of 256 complete
#  [*************         27%                       ]  70 of 256 complete
#  [*************         28%                       ]  71 of 256 complete
#  [*************         28%                       ]  72 of 256 complete
#  [**************        29%                       ]  73 of 256 complete
#  [**************        29%                       ]  74 of 256 complete
#  [**************        29%                       ]  75 of 256 complete
#  [**************        30%                       ]  76 of 256 complete
#  [**************        30%                       ]  77 of 256 complete
#  [**************        30%                       ]  78 of 256 complete
#  [***************       31%                       ]  79 of 256 complete
#  [***************       31%                       ]  80 of 256 complete
#  [***************       32%                       ]  81 of 256 complete
#  [***************       32%                       ]  82 of 256 complete
#  [***************       32%                       ]  83 of 256 complete
#  [****************      33%                       ]  84 of 256 complete
#  [****************      33%                       ]  85 of 256 complete
#  [****************      34%                       ]  86 of 256 complete
#  [****************      34%                       ]  87 of 256 complete
#  [****************      34%                       ]  88 of 256 complete
#  [*****************     35%                       ]  89 of 256 complete
#  [*****************     35%                       ]  90 of 256 complete
#  [*****************     36%                       ]  91 of 256 complete
#  [*****************     36%                       ]  92 of 256 complete
#  [*****************     36%                       ]  93 of 256 complete
#  [******************    37%                       ]  94 of 256 complete
#  [******************    37%                       ]  95 of 256 complete
#  [******************    38%                       ]  96 of 256 complete
#  [******************    38%                       ]  97 of 256 complete
#  [******************    38%                       ]  98 of 256 complete
#  [*******************   39%                       ]  99 of 256 complete
#  [*******************   39%                       ]  100 of 256 complete
#  [*******************   39%                       ]  101 of 256 complete
#  [*******************   40%                       ]  102 of 256 complete
#  [*******************   40%                       ]  103 of 256 complete
#  [********************  41%                       ]  104 of 256 complete
#  [********************  41%                       ]  105 of 256 complete
#  [********************  41%                       ]  106 of 256 complete
#  [********************  42%                       ]  107 of 256 complete
#  [********************  42%                       ]  108 of 256 complete
#  [********************* 43%                       ]  109 of 256 complete
#  [********************* 43%                       ]  110 of 256 complete
#  [********************* 43%                       ]  111 of 256 complete
#  [********************* 44%                       ]  112 of 256 complete
#  [********************* 44%                       ]  113 of 256 complete
#  [**********************45%                       ]  114 of 256 complete
#  [**********************45%                       ]  115 of 256 complete
#  [**********************45%                       ]  116 of 256 complete
#  [**********************46%                       ]  117 of 256 complete
#  [**********************46%                       ]  118 of 256 complete
#  [**********************46%                       ]  119 of 256 complete
#  [**********************47%                       ]  120 of 256 complete
#  [**********************47%                       ]  121 of 256 complete
#  [**********************48%                       ]  122 of 256 complete
#  [**********************48%                       ]  123 of 256 complete
#  [**********************48%                       ]  124 of 256 complete
#  [**********************49%                       ]  125 of 256 complete
#  [**********************49%                       ]  126 of 256 complete
#  [**********************50%                       ]  127 of 256 complete
#  [**********************50%                       ]  128 of 256 complete
#  [**********************50%                       ]  129 of 256 complete
#  [**********************51%                       ]  130 of 256 complete
#  [**********************51%                       ]  131 of 256 complete
#  [**********************52%                       ]  132 of 256 complete
#  [**********************52%                       ]  133 of 256 complete
#  [**********************52%                       ]  134 of 256 complete
#  [**********************53%                       ]  135 of 256 complete
#  [**********************53%                       ]  136 of 256 complete
#  [**********************54%*                      ]  137 of 256 complete
#  [**********************54%*                      ]  138 of 256 complete
#  [**********************54%*                      ]  139 of 256 complete
#  [**********************55%*                      ]  140 of 256 complete
#  [**********************55%*                      ]  141 of 256 complete
#  [**********************55%*                      ]  142 of 256 complete
#  [**********************56%**                     ]  143 of 256 complete
#  [**********************56%**                     ]  144 of 256 complete
#  [**********************57%**                     ]  145 of 256 complete
#  [**********************57%**                     ]  146 of 256 complete
#  [**********************57%**                     ]  147 of 256 complete
#  [**********************58%***                    ]  148 of 256 complete
#  [**********************58%***                    ]  149 of 256 complete
#  [**********************59%***                    ]  150 of 256 complete
#  [**********************59%***                    ]  151 of 256 complete
#  [**********************59%***                    ]  152 of 256 complete
#  [**********************60%****                   ]  153 of 256 complete
#  [**********************60%****                   ]  154 of 256 complete
#  [**********************61%****                   ]  155 of 256 complete
#  [**********************61%****                   ]  156 of 256 complete
#  [**********************61%****                   ]  157 of 256 complete
#  [**********************62%*****                  ]  158 of 256 complete
#  [**********************62%*****                  ]  159 of 256 complete
#  [**********************63%*****                  ]  160 of 256 complete
#  [**********************63%*****                  ]  161 of 256 complete
#  [**********************63%*****                  ]  162 of 256 complete
#  [**********************64%******                 ]  163 of 256 complete
#  [**********************64%******                 ]  164 of 256 complete
#  [**********************64%******                 ]  165 of 256 complete
#  [**********************65%******                 ]  166 of 256 complete
#  [**********************65%******                 ]  167 of 256 complete
#  [**********************66%*******                ]  168 of 256 complete
#  [**********************66%*******                ]  169 of 256 complete
#  [**********************66%*******                ]  170 of 256 complete
#  [**********************67%*******                ]  171 of 256 complete
#  [**********************67%*******                ]  172 of 256 complete
#  [**********************68%********               ]  173 of 256 complete
#  [**********************68%********               ]  174 of 256 complete
#  [**********************68%********               ]  175 of 256 complete
#  [**********************69%********               ]  176 of 256 complete
#  [**********************69%********               ]  177 of 256 complete
#  [**********************70%*********              ]  178 of 256 complete
#  [**********************70%*********              ]  179 of 256 complete
#  [**********************70%*********              ]  180 of 256 complete
#  [**********************71%*********              ]  181 of 256 complete
#  [**********************71%*********              ]  182 of 256 complete
#  [**********************71%*********              ]  183 of 256 complete
#  [**********************72%**********             ]  184 of 256 complete
#  [**********************72%**********             ]  185 of 256 complete
#  [**********************73%**********             ]  186 of 256 complete
#  [**********************73%**********             ]  187 of 256 complete
#  [**********************73%**********             ]  188 of 256 complete
#  [**********************74%***********            ]  189 of 256 complete
#  [**********************74%***********            ]  190 of 256 complete
#  [**********************75%***********            ]  191 of 256 complete
#  [**********************75%***********            ]  192 of 256 complete
#  [**********************75%***********            ]  193 of 256 complete
#  [**********************76%***********            ]  194 of 256 complete
#  [**********************76%***********            ]  195 of 256 complete
#  [**********************77%************           ]  196 of 256 complete
#  [**********************77%************           ]  197 of 256 complete
#  [**********************77%************           ]  198 of 256 complete
#  [**********************78%************           ]  199 of 256 complete
#  [**********************78%************           ]  200 of 256 complete
#  [**********************79%*************          ]  201 of 256 complete
#  [**********************79%*************          ]  202 of 256 complete
#  [**********************79%*************          ]  203 of 256 complete
#  [**********************80%*************          ]  204 of 256 complete
#  [**********************80%*************          ]  205 of 256 complete
#  [**********************80%*************          ]  206 of 256 complete
#  [**********************81%**************         ]  207 of 256 complete
#  [**********************81%**************         ]  208 of 256 complete
#  [**********************82%**************         ]  209 of 256 complete
#  [**********************82%**************         ]  210 of 256 complete
#  [**********************82%**************         ]  211 of 256 complete
#  [**********************83%***************        ]  212 of 256 complete
#  [**********************83%***************        ]  213 of 256 complete
#  [**********************84%***************        ]  214 of 256 complete
#  [**********************84%***************        ]  215 of 256 complete
#  [**********************84%***************        ]  216 of 256 complete
#  [**********************85%****************       ]  217 of 256 complete
#  [**********************85%****************       ]  218 of 256 complete
#  [**********************86%****************       ]  219 of 256 complete
#  [**********************86%****************       ]  220 of 256 complete
#  [**********************86%****************       ]  221 of 256 complete
#  [**********************87%*****************      ]  222 of 256 complete
#  [**********************87%*****************      ]  223 of 256 complete
#  [**********************88%*****************      ]  224 of 256 complete
#  [**********************88%*****************      ]  225 of 256 complete
#  [**********************88%*****************      ]  226 of 256 complete
#  [**********************89%******************     ]  227 of 256 complete
#  [**********************89%******************     ]  228 of 256 complete
#  [**********************89%******************     ]  229 of 256 complete
#  [**********************90%******************     ]  230 of 256 complete
#  [**********************90%******************     ]  231 of 256 complete
#  [**********************91%*******************    ]  232 of 256 complete
#  [**********************91%*******************    ]  233 of 256 complete
#  [**********************91%*******************    ]  234 of 256 complete
#  [**********************92%*******************    ]  235 of 256 complete
#  [**********************92%*******************    ]  236 of 256 complete
#  [**********************93%********************   ]  237 of 256 complete
#  [**********************93%********************   ]  238 of 256 complete
#  [**********************93%********************   ]  239 of 256 complete
#  [**********************94%********************   ]  240 of 256 complete
#  [**********************94%********************   ]  241 of 256 complete
#  [**********************95%*********************  ]  242 of 256 complete
#  [**********************95%*********************  ]  243 of 256 complete
#  [**********************95%*********************  ]  244 of 256 complete
#  [**********************96%*********************  ]  245 of 256 complete
#  [**********************96%*********************  ]  246 of 256 complete
#  [**********************96%*********************  ]  247 of 256 complete
#  [**********************97%********************** ]  248 of 256 complete
#  [**********************97%********************** ]  249 of 256 complete
#  [**********************98%********************** ]  250 of 256 complete
#  [**********************98%********************** ]  251 of 256 complete
#  [**********************98%********************** ]  252 of 256 complete
#  [**********************99%***********************]  253 of 256 complete
#  [**********************99%***********************]  254 of 256 complete
#  [*********************100%***********************]  255 of 256 complete
#  [*********************100%***********************]  256 of 256 complete

# %%
tokens = ['AAA','IYY','UWW','AEE','AHH','EHH','ERR','IHH','UHH']
window = np.array([-1,2])
[F,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='form')
Fs = [F[d] for d in tokens]

notes = []
for ind,n in enumerate(tokens):
    notes.append([n]*Fs[ind].shape[2])
notes = np.concatenate(notes,axis=0) 

stops = [stop_times[d] for d in tokens]
starts = [start_times[d] for d in tokens]
ffeats = ['F0','F1','F2','F3','F4']
Fs = smooth_formants(Fs,starts,stops,window)
#Gestural Score:
fig_filename = save_pth + subj + '_Form_GS.png'
gestural_score(Fs,ffeats,tokens,fig_filename =None,window=np.array([-1,2]))
# Out:
# File found; Loading...
# Loaded

# %%
CV = 'split'
boot = 10
ncomp = 86
nTP = 200
alphas = np.logspace(-2,15,20)

window = np.array([-1, 2])
[E,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='HG')
Es = [E[d] for d in tokens]
elects = np.concatenate((np.where(anat=='preCG')[0],np.where(anat=='postCG')[0]))

Fr2 = np.empty((Fs[0].shape[0],boot,nTP,len(alphas)))
Fr2null = np.empty((Fs[0].shape[0],boot,nTP,len(alphas)))

prog = ProgressBar(nTP)
for indt,t in enumerate(np.linspace(200,600,nTP)):
    erange = np.arange(t,t+4)   #Try playing with window size

    #Organize data into X and y
    X,y,yrnd = Ds2Xy(Es,Fs,dt1='HG',dt2='form',ncomp = ncomp,erange = erange.astype(int),elects = elects,frange=np.arange(105,115),krange=np.arange(37,42))

    #Ridge regression
    for inda,a in enumerate(alphas):
        Fr2[:,:,indt,inda],yhat,score = Ridge_MLR(X, y, alpha = a, CV = CV, boot = boot)
        Fr2null[:,:,indt,inda],yhat,score = Ridge_MLR(X, yrnd, alpha = a, CV = CV, boot = boot)
    prog.animate(indt)
R2viz(Fr2,Fr2null,ffeats,b=True)
# Out:
# File found; Loading...
# Loaded
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-7fc6714df25b> in <module>()
#      22     #Ridge regression
#      23     for inda,a in enumerate(alphas):
# ---> 24         Fr2[:,:,indt,inda],yhat,score = Ridge_MLR(X, y, alpha = a, CV = CV, boot = boot)
#      25         Fr2null[:,:,indt,inda],yhat,score = Ridge_MLR(X, yrnd, alpha = a, CV = CV, boot = boot)
#      26     prog.animate(indt)
#
# /Users/david_conant/Dropbox/changrepo/python/datautils/ECoGstats.pyc in Ridge_MLR(X, y, alpha, CV, boot, notes, Xtest, ytest)
#     735                     clf = Ridge(alpha = alpha)
#     736
# --> 737                     clf.fit(X_train,y_train[:,c])
#     738                     yhat = clf.predict(X_test)
#     739                     score[c,b] = clf.score(X_test,y_test[:,c])
#
# /Users/david_conant/anaconda/lib/python2.7/site-packages/sklearn/linear_model/ridge.pyc in fit(self, X, y, sample_weight)
#     508         self : returns an instance of self.
#     509         """
# --> 510         return super(Ridge, self).fit(X, y, sample_weight=sample_weight)
#     511
#     512
#
# /Users/david_conant/anaconda/lib/python2.7/site-packages/sklearn/linear_model/ridge.pyc in fit(self, X, y, sample_weight)
#     380     def fit(self, X, y, sample_weight=None):
#     381         X, y = check_X_y(X, y, ['csr', 'csc', 'coo'], dtype=np.float,
# --> 382                          multi_output=True, y_numeric=True)
#     383
#     384         if ((sample_weight is not None) and
#
# /Users/david_conant/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric)
#     437     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     438                     ensure_2d, allow_nd, ensure_min_samples,
# --> 439                     ensure_min_features)
#     440     if multi_output:
#     441         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /Users/david_conant/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features)
#     360             raise ValueError("Found array with %d feature(s) (shape=%s) while"
#     361                              " a minimum of %d is required."
# --> 362                              % (n_features, shape_repr, ensure_min_features))
#     363     return array
#     364
#
# ValueError: Found array with 0 feature(s) (shape=(244, 0)) while a minimum of 1 is required.

# %%
X.shape
# Out:
# (305, 0)

# %%
y.shape
# Out:
# (305, 6)

# %%
anat
# Out:
# array([u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'', u'',
#        u'', u'', u'', u'STG', u'STG', u'STG', u'', u'STG', u'STG', u'STG',
#        u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG',
#        u'STG', u'STG', u'STG', u'STG', u'', u'STG', u'STG', u'STG', u'STG',
#        u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG',
#        u'STG', u'', u'', u'', u'STG', u'STG', u'STG', u'STG', u'STG',
#        u'STG', u'STG', u'STG', u'STG', u'STG', u'', u'', u'', u'', u'',
#        u'', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG',
#        u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG',
#        u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG',
#        u'STG', u'STG', u'', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG',
#        u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG',
#        u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG',
#        u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG',
#        u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG',
#        u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG',
#        u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'', u'STG', u'STG',
#        u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG',
#        u'STG', u'STG', u'STG', u'STG', u'STG', u'', u'STG', u'STG', u'STG',
#        u'STG', u'STG', u'STG', u'STG', u'', u'STG', u'STG', u'STG', u'STG',
#        u'STG', u'STG', u'STG', u'', u'STG', u'STG', u'STG', u'STG', u'STG',
#        u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG',
#        u'STG', u'', u'', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG',
#        u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'',
#        u'', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'STG',
#        u'STG', u'STG', u'STG', u'STG', u'STG', u'STG', u'', u'', u'STG',
#        u'STG', u'STG', u'STG', u'STG', u'STG', u'', u'STG', u'STG', u'STG',
#        u'STG', u'STG', u'STG', u'STG', u'', u'', u'STG', u'STG', u'STG',
#        u'STG', u'STG', u'STG', u'', u'', u'STG', u'STG', u'STG', u'STG',
#        u'STG', u'STG', u'', u''],
#       dtype='<U3')
