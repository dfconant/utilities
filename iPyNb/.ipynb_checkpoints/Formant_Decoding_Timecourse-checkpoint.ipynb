# %%
#Intitialize
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import scipy as sp
import numpy as np
import sklearn as skl
from sklearn.pipeline import make_pipeline
from sklearn.cross_validation import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.cross_validation import train_test_split, LeaveOneOut
import seaborn as sns
from ECoGstats import makeD_multi, smooth_formants, shuffle_df
from sklearn.decomposition import PCA
import pandas as pd
import prettyplotlib as ppl
import pdb
from BDutils import ProgressBar
from scipy.signal import savgol_filter
import matplotlib.gridspec as gridspec

# %%
#def formant_ridge_decode_timecourse(Es,Fs,tokens,anat,alphas = np.tile(np.logspace(-10,10,50),(6,1)), ncomp = 50):
#Trial labels
notes = []
for ind,n in enumerate(tokens):
    notes.append([n]*Fs[ind].shape[2])
notes = np.concatenate(notes,axis=1)
#Feature labels
forms = ['F0','F1','F2','F3','F4']
chans = np.arange(1,256)
#Anatomy
vSMC = np.concatenate((np.where(anat=='preCG')[0],np.where(anat=='postCG')[0]))

#Formants = central 20% of each vowel utterance 
mid = np.arange(105,115)
Fall = np.concatenate(Fs,axis=2)
dat = dict(zip(forms,np.nanmean(Fall[:,mid,:],axis = 1)))
#dat['label'] = notes
Fmid = pd.DataFrame.from_dict(dat)
Fmid = Fmid.fillna(Fmid.median(),inplace=True)
F2_1 = pd.Series(Fmid['F2']/Fmid['F1'],name = 'F2/F1')
y = pd.concat((Fmid,F2_1),axis=1)
#y.apply(np.log10,axis = 0)
y = (y - y.mean())/y.std(ddof=0)


#Rolling average of vSMC HG   
centers = np.round(np.linspace(140,440,num = 75))     #10 ms window. From -650 to 100
half_width = 2
Ebins = [None]*centers.shape[0]
Eall = np.concatenate(Es,axis=2)
Eall = Eall[vSMC,:,:]



boot = 5
r2 = np.empty((boot,len(Ebins),y.shape[1],alphas.shape[1]))
R2 = np.empty((len(Ebins),y.shape[1],alphas.shape[1]))
R2ste = np.empty((len(Ebins),y.shape[1],alphas.shape[1]))

r2null = np.empty((boot,len(Ebins),y.shape[1],alphas.shape[1]))
R2null = np.empty((len(Ebins),y.shape[1],alphas.shape[1]))
R2nullste = np.empty((len(Ebins),y.shape[1],alphas.shape[1]))

Bobs = np.empty((boot,len(Ebins),y.shape[1],alphas.shape[1]),ncomp)
Xind = np.empty((Eall.shape[2],ncomp,len(Ebins)))

prog = ProgressBar(len(centers))
for ind,cent in enumerate(centers.astype(int)):
    erange = np.arange(cent-half_width,cent+half_width)
    X = np.nanmean(Eall[:,erange,:],axis = 1).transpose()
    X = pd.DataFrame(X)
    X = X.fillna(X.median(),inplace=True)
    X = X.dropna(axis =1,how='any')

    #PCA
    clf = PCA(n_components = ncomp) 
    clf.fit(X)
    X = clf.transform(X)
    Xind[:,:,ind] = X.values
    for inda,alph in enumerate(alphas.transpose()):
        for b in range(boot):

            yrnd = shuffle_df(y,10,axis=0)
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
            yrnd_train, yrnd_test = train_test_split(yrnd, test_size=0.2)

            #Ridge Regression
            for c,f in enumerate(y.columns.values):
                clf = Ridge(alpha = alph[c], fit_intercept = False, normalize = True)   
                clf.fit(X_train,y_train.loc[:,f])

                yhat = clf.predict(X_test)
                r = sp.stats.pearsonr(yhat,y_test.loc[:,f])[0]
                r2[b,ind,c,inda] = r**2

                Bobs[b,ind,c,inda,:] = clf.coef_
                
                clfN = Ridge(alpha = alph[c], fit_intercept = False, normalize = True)   
                clfN.fit(X_train,yrnd_train.loc[:,f])

                yhat = clfN.predict(X_test)
                rnull = sp.stats.pearsonr(yhat,yrnd_test.loc[:,f])[0]
                r2null[b,ind,c,inda] = rnull**2

        R2[ind,:,inda] = np.mean(r2[:,ind,:,inda],axis = 0)
        R2ste[ind,:,inda] = np.std(r2[:,ind,:,inda],axis = 0)/boot
        R2null[ind,:,inda] = np.mean(r2[:,ind,:,inda],axis = 0)
        R2nullste[ind,:,inda] = np.std(r2[:,ind,:,inda],axis = 0)/boot
    prog.animate(ind)

#Best performing 
best_times = centers[np.argmax(np.nanmean(R2,axis = 2),axis = 0)]
best_alphas = 0,np.argmax(np.nanmean(R2,axis = 0),axis = 1)

fig = plt.figure(figsize = (10,10))
gs1 = gridspec.GridSpec(10,10)
co = ppl.brewer2mpl.get_map('Dark2','Qualitative',6).mpl_colors
tt = np.linspace(-650,100,75)
forms = ['F0','F1','F2','F3','F4','F2/F1']
sns.set_context('talk')

ax1 = plt.subplot(gs1[6:10,1:10])
ax1.set_ylabel('R2')
ax1.set_xlabel('lag (ms)')
#ax1.set_title('-100 ms')
for ind,f in enumerate(forms):
    sig = savgol_filter(R2[:,ind,best_alphas[1][ind]],11,3)
    ste = savgol_filter(R2ste[:,ind,best_alphas[1][ind]],11,3)
    plt.plot(tt,sig,color = co[ind],label=f)
    plt.fill_between(tt,sig-ste, sig+ste,color = co[ind],alpha=0.5)
plt.legend(loc = 'upper right', bbox_to_anchor=(1.1, 1.1),prop={'size':12})

ax2 = plt.subplot(gs1[1:5,1:5])
plt.pcolor(R2[:,5,:])
plt.colorbar()

ax3 = plt.subplot(gs1[1:5,6:10])
plt.pcolor(R2null[:,5,:])
plt.colorbar()

return R2,R2ste,r2,R2null,R2nullste,r2null,Bobs,best_alphas,best_times
# Out:
#  [                       0%                       ]
#  [                       1%                       ]  1 of 75 complete
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-148-fcb9a5e16680> in <module>()
#      58         for b in range(boot):
#      59
# ---> 60             yrnd = shuffle_df(y,10,axis=0)
#      61             X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
#      62             yrnd_train, yrnd_test = train_test_split(yrnd, test_size=0.2)
#
# /Users/david_conant/Dropbox/changrepo/python/datautils/ECoGstats.py in shuffle_df(df, n, axis)
#     397     df = df.copy()
#     398     for _ in range(n):
# --> 399         df.apply(np.random.shuffle, axis=axis)
#     400     return df
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/frame.pyc in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    3687                     if reduce is None:
#    3688                         reduce = True
# -> 3689                     return self._apply_standard(f, axis, reduce=reduce)
#    3690             else:
#    3691                 return self._apply_broadcast(f, axis)
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/frame.pyc in _apply_standard(self, func, axis, ignore_failures, reduce)
#    3739                 labels = self._get_agg_axis(axis)
#    3740                 result = lib.reduce(values, func, axis=axis, dummy=dummy,
# -> 3741                                     labels=labels)
#    3742                 return Series(result, index=labels)
#    3743             except Exception:
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.reduce (pandas/lib.c:40138)()
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.Reducer.get_result (pandas/lib.c:29941)()
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/numpy/random/mtrand.so in mtrand.RandomState.shuffle (numpy/random/mtrand/mtrand.c:21136)()
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     512     def __getitem__(self, key):
#     513         try:
# --> 514             result = self.index.get_value(self, key)
#     515
#     516             if not np.isscalar(result):
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/index.pyc in get_value(self, series, key)
#    1450         know what you're doing
#    1451         """
# -> 1452         s = _values_from_object(series)
#    1453         k = _values_from_object(key)
#    1454
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.values_from_object (pandas/lib.c:4055)()
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/series.pyc in get_values(self)
#     310         return self._data.values
#     311
# --> 312     def get_values(self):
#     313         """ same as values (but handles sparseness conversions); is a view """
#     314         return self._data.get_values()
#
# KeyboardInterrupt:

# %%
yrnd_test
# Out:
#           F0        F1        F2        F3        F4     F2/F1
# 23  1.734431  0.998003 -0.813188 -0.359560 -0.441335 -0.361545
# 18  1.440779 -0.171249 -0.830945  1.212530  0.585084  1.102537
# 41  0.036292 -0.670943  1.206763  0.842767 -1.750533 -1.030847
# 25 -1.609935  1.488069 -0.730524  0.793985 -0.576907 -1.061815
# 12 -0.793148 -0.699346  1.479586  1.099172  1.052651 -1.015948
# 15  0.036292 -0.847071 -0.381954 -0.358924  0.475451 -0.336121
# 32  0.036292 -0.565073 -0.685600  0.624772  1.290107 -0.996283
# 43  1.182491  0.359567 -0.867235 -0.847470 -0.630546  0.997940
# 44  0.036292 -0.590653  1.397862  1.671788 -1.547990  1.143866
# 29 -1.721279 -0.541930 -0.751841  1.655944  1.089276  1.526543
# 56  0.036292  1.629120  1.320976 -1.122166 -1.574293 -0.073669
# 46  0.036292 -0.662909  1.241478  0.953991  1.068394  0.023772

# %%
y_test
# Out:
#           F0        F1        F2        F3        F4     F2/F1
# 21  0.036292 -0.684076  1.486563  1.540604  1.290107  1.214205
# 26  0.036292 -1.160641  1.315230  1.671788  1.052651  1.927239
# 8  -1.620405  1.476711 -0.871141 -0.304074 -0.425452 -1.069374
# 24  0.036292 -1.181679  1.241478  1.326607  1.169130  1.907814
# 42  0.036292 -0.919390 -0.494005 -0.411157  0.592088  0.025491
# 30 -0.797472 -0.619301  1.479586  1.702459  1.089276  1.121453
# 53  1.440779 -0.506296 -0.607648 -1.072536 -0.006186 -0.361545
# 45  0.036292 -0.783810 -0.468855 -1.560369 -0.441335 -0.073669
# 2   0.036292  1.289030 -0.824001 -0.314421 -1.427324 -1.024254
# 50 -0.838666 -0.593695 -0.866337 -1.424244  0.736506 -0.481182
# 25  0.036292 -1.113113  1.485625  1.002557  0.726106  1.972614
# 46 -1.721279 -0.679508 -0.381954 -1.296703  0.472169 -0.094037

# %%
#Larger window
pth = '/Users/david_conant/Documents/EC41/'
blocks = [19,20,22,27]
tokens = ['AAA','IYY','UWW']
window = np.array([-1, 1])
[E,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='HG')
Es = [E[d] for d in tokens]

window = np.array([-1, 1])
[F,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='form')
Fs = [F[d] for d in tokens]
stops = [stop_times[d] for d in tokens]
starts = [start_times[d] for d in tokens]
Fs = smooth_formants(Fs,starts,stops,window)
[R2,R2ste,snsR2,R2null,R2nullste,r2null,best_alphas,best_times] = formant_ridge_decode_timecourse(Es,Fs,
                        tokens,anat,alphas = np.tile(np.logspace(-100,100,50),(6,1)))
# Out:
# File found; Loading...
# Loaded
# File found; Loading...
# Loaded
#  [                       0%                       ]
#  [                       1%                       ]  1 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [**********            20%                       ]  15 of 75 complete
#  [**********            21%                       ]  16 of 75 complete
#  [***********           23%                       ]  17 of 75 complete
#  [************          24%                       ]  18 of 75 complete
#  [************          25%                       ]  19 of 75 complete
#  [*************         27%                       ]  20 of 75 complete
#  [*************         28%                       ]  21 of 75 complete
#  [**************        29%                       ]  22 of 75 complete
#  [***************       31%                       ]  23 of 75 complete
#  [***************       32%                       ]  24 of 75 complete
#  [****************      33%                       ]  25 of 75 complete
#  [*****************     35%                       ]  26 of 75 complete
#  [*****************     36%                       ]  27 of 75 complete
#  [******************    37%                       ]  28 of 75 complete
#  [*******************   39%                       ]  29 of 75 complete
#  [*******************   40%                       ]  30 of 75 complete
#  [********************  41%                       ]  31 of 75 complete
#  [********************* 43%                       ]  32 of 75 complete
#  [********************* 44%                       ]  33 of 75 complete
#  [**********************45%                       ]  34 of 75 complete
#  [**********************47%                       ]  35 of 75 complete
#  [**********************48%                       ]  36 of 75 complete
#  [**********************49%                       ]  37 of 75 complete
#  [**********************51%                       ]  38 of 75 complete
#  [**********************52%                       ]  39 of 75 complete
#  [**********************53%                       ]  40 of 75 complete
#  [**********************55%*                      ]  41 of 75 complete
#  [**********************56%**                     ]  42 of 75 complete
#  [**********************57%**                     ]  43 of 75 complete
#  [**********************59%***                    ]  44 of 75 complete
#  [**********************60%****                   ]  45 of 75 complete
#  [**********************61%****                   ]  46 of 75 complete
#  [**********************63%*****                  ]  47 of 75 complete
#  [**********************64%******                 ]  48 of 75 complete
#  [**********************65%******                 ]  49 of 75 complete
#  [**********************67%*******                ]  50 of 75 complete
#  [**********************68%********               ]  51 of 75 complete
#  [**********************69%********               ]  52 of 75 complete
#  [**********************71%*********              ]  53 of 75 complete
#  [**********************72%**********             ]  54 of 75 complete
#  [**********************73%**********             ]  55 of 75 complete
#  [**********************75%***********            ]  56 of 75 complete
#  [**********************76%***********            ]  57 of 75 complete
#  [**********************77%************           ]  58 of 75 complete
#  [**********************79%*************          ]  59 of 75 complete
#  [**********************80%*************          ]  60 of 75 complete
#  [**********************81%**************         ]  61 of 75 complete
#  [**********************83%***************        ]  62 of 75 complete
#  [**********************84%***************        ]  63 of 75 complete
#  [**********************85%****************       ]  64 of 75 complete
#  [**********************87%*****************      ]  65 of 75 complete
#  [**********************88%*****************      ]  66 of 75 complete
#  [**********************89%******************     ]  67 of 75 complete
#  [**********************91%*******************    ]  68 of 75 complete
#  [**********************92%*******************    ]  69 of 75 complete
#  [**********************93%********************   ]  70 of 75 complete
#  [**********************95%*********************  ]  71 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************99%***********************]  74 of 75 complete

# %%
#def formant_boats_decode_timecourse(Es,Fs,tokens,anat,alphas = np.tile(np.logspace(-10,10,50),(6,1)), ncomp = 50):
alphas = np.tile(np.logspace(-10,10,50),(6,1))
ncomp = 50
#Trial labels
notes = []
for ind,n in enumerate(tokens):
    notes.append([n]*Fs[ind].shape[2])
notes = np.concatenate(notes,axis=1)
#Feature labels
forms = ['F0','F1','F2','F3','F4']
chans = np.arange(1,256)
#Anatomy
vSMC = np.concatenate((np.where(anat=='preCG')[0],np.where(anat=='postCG')[0]))

#Formants = central 20% of each vowel utterance 
mid = np.arange(105,115)
Fall = np.concatenate(Fs,axis=2)
dat = dict(zip(forms,np.nanmean(Fall[:,mid,:],axis = 1)))
#dat['label'] = notes
Fmid = pd.DataFrame.from_dict(dat)
Fmid = Fmid.fillna(Fmid.median(),inplace=True)
F2_1 = pd.Series(Fmid['F2']/Fmid['F1'],name = 'F2/F1')
y = pd.concat((Fmid,F2_1),axis=1)
#y.apply(np.log10,axis = 0)
y = (y - y.mean())/y.std(ddof=0)


#Rolling average of vSMC HG   
centers = np.round(np.linspace(140,440,num = 75))     #10 ms window. From -650 to 100
half_width = 2
Ebins = [None]*centers.shape[0]
Eall = np.concatenate(Es,axis=2)
Eall = Eall[vSMC,:,:]



boot = 5
boat_boot = 200
r2 = np.empty((boot,len(Ebins),y.shape[1],alphas.shape[1]))
R2 = np.empty((len(Ebins),y.shape[1],alphas.shape[1]))
R2ste = np.empty((len(Ebins),y.shape[1],alphas.shape[1]))
prog = ProgressBar(len(centers))
for ind,cent in enumerate(centers.astype(int)):
    erange = np.arange(cent-half_width,cent+half_width)
    X = np.nanmean(Eall[:,erange,:],axis = 1).transpose()
    X = pd.DataFrame(X)
    X = X.fillna(X.median(),inplace=True)
    X = X.dropna(axis =1,how='any')

    #PCA
    clf = PCA(n_components = ncomp) 
    clf.fit(X)
    X = clf.transform(X)

    for inda,alph in enumerate(alphas.transpose()):
        



        #BoATS Regression

        #Find sig weigths
        Brnd = np.empty((y.shape[1],ncomp,boat_boot))
        Bobs = np.empty((y.shape[1],ncomp,boat_boot))
        sigB = np.empty((y.shape[1],ncomp))               
        for bb in range(boat_boot):

            yrnd = shuffle_df(y,10,axis=0)
            X_train, X_test, y_train, y_test = train_test_split(
            X, y, test_size=0.2)
            yrnd_train, yrnd_test = train_test_split(
            yrnd, test_size=0.2)

            for c,f in enumerate(y.columns.values):

                clf = LinearRegression(fit_intercept = False, normalize = True, n_jobs=-1)   
                clf.fit(X_train,yrnd_train.loc[:,f])
                Brnd[c,:,bb] = clf.coef_

                clf = LinearRegression(fit_intercept = False, normalize = True, n_jobs=-1)   
                clf.fit(X_train,y_train.loc[:,f])
                Bobs[c,:,bb] = clf.coef_

        sigB = [None]*6
        for c,f in enumerate(y.columns.values): 
            sigB[c] = np.where(np.median(np.abs(Bobs[c,:,:]),axis = 1) 
                   > 2* np.nanstd(np.median(np.abs(Brnd[c,:,:]),axis = 1),axis=0))[0]
        for b in range(boot):
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
            for c,f in enumerate(y.columns.values):
                X_train_r = X_train[:,sigB[c]]
                X_test_r = X_test[:,sigB[c]]
                
                clf = LinearRegression(fit_intercept = False, normalize = True, n_jobs=-1)   
                clf.fit(X_train_r,y_train.loc[:,f])
                yhat = clf.predict(X_test_r)
            
                r = sp.stats.pearsonr(yhat,y_test.loc[:,f])[0]
                r2[b,ind,c] = r**2 

        R2[ind,:] = np.mean(r2[:,ind,:],axis = 0)
        R2ste[ind,:] = np.std(r2[:,ind,:],axis = 0)/boot
        prog.animate(ind)

#Best performing 
best_times = centers[np.argmax(R2,axis = 0)]

fig = plt.figure(figsize = (10,10))
gs1 = gridspec.GridSpec(10,10)
co = ppl.brewer2mpl.get_map('Dark2','Qualitative',6).mpl_colors
tt = np.linspace(-650,100,75)
forms = ['F0','F1','F2','F3','F4','F2/F1']
sns.set_context('talk')
ax1 = plt.subplot(gs1[6:10,1:10])
ax1.set_ylabel('R2')
ax1.set_xlabel('lag (ms)')
#ax1.set_title('-100 ms')
for ind,f in enumerate(forms):
    sig = savgol_filter(R2[:,ind],11,3)
    ste = savgol_filter(R2ste[:,ind],11,3)
    plt.plot(tt,sig,color = co[ind],label=f)
    plt.fill_between(tt,sig-ste, sig+ste,color = co[ind],alpha=0.5)
plt.legend(loc = 'upper right', bbox_to_anchor=(1.1, 1.1),prop={'size':12})

ax2 = plt.subplot(gs1[1:5,1:5])
plt.pcolor(R2[:,5,:])
plt.colorbar()
return R2,R2ste,r2,best_alphas,best_times
# Out:
#  [                       0%                       ]
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [                       1%                       ]  1 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
# ...
#  [**********************95%*********************  ]  71 of 75 complete
#  [**********************95%*********************  ]  71 of 75 complete
#  [**********************95%*********************  ]  71 of 75 complete
#  [**********************95%*********************  ]  71 of 75 complete
#  [**********************95%*********************  ]  71 of 75 complete
#  [**********************95%*********************  ]  71 of 75 complete
#  [**********************95%*********************  ]  71 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
#  [*********************100%***********************]  75 of 75 complete
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-142-a526bd867d1f> in <module>()
#     120     ste = savgol_filter(R2ste[:,ind],11,3)
#     121     plt.plot(tt,sig,color = co[ind],label=f)
# --> 122     plt.fill_between(tt,sig-ste, sig+ste,color = co[ind],alpha=0.5)
#     123 plt.legend(loc = 'upper right', bbox_to_anchor=(1.1, 1.1),prop={'size':12})
#     124
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/pyplot.pyc in fill_between(x, y1, y2, where, interpolate, hold, **kwargs)
#    2824     try:
#    2825         ret = ax.fill_between(x, y1, y2=y2, where=where,
# -> 2826                               interpolate=interpolate, **kwargs)
#    2827         draw_if_interactive()
#    2828     finally:
#
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in fill_between(self, x, y1, y2, where, interpolate, **kwargs)
#    4343
#    4344         if not (x.shape == y1.shape == y2.shape == where.shape):
# -> 4345             raise ValueError("Argument dimensions are incompatible")
#    4346
#    4347         mask = reduce(ma.mask_or, [ma.getmask(a) for a in (x, y1, y2)])
#
# ValueError: Argument dimensions are incompatible

# %%
#w/pca
pth = '/Users/david_conant/Documents/EC41/'
blocks = [19,20,22,27]
tokens = ['AAA','IYY','UWW']
window = np.array([-1, 1])
[E,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='HG')
Es = [E[d] for d in tokens]

window = np.array([-1, 1])
[F,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='form')
Fs = [F[d] for d in tokens]
stops = [stop_times[d] for d in tokens]
starts = [start_times[d] for d in tokens]
Fs = smooth_formants(Fs,starts,stops,window)
[R2,R2ste,snsR2,best_alphas,best_times] = formant_ridge_decode_timecourse(Es,Fs,tokens,anat,alphas = np.tile(np.logspace(-100,100,50),(6,1)))

# %%
pth = '/Users/david_conant/Documents/EC50/'
blocks = [21,22,25,76]
tokens = ['AAA','IYY','UWW']
window = np.array([-1, 1])
[E,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='HG')
Es = [E[d] for d in tokens]

window = np.array([-1, 1])
[F,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='form')
Fs = [F[d] for d in tokens]
stops = [stop_times[d] for d in tokens]
starts = [start_times[d] for d in tokens]
Fs = smooth_formants(Fs,starts,stops,window)
[R2,R2ste,snsR2,best_alphas,best_times] = formant_ridge_decode_timecourse(Es,Fs,tokens,anat,alphas = np.tile(np.logspace(-100,100,50),(6,1)), ncomp = 40)

# %%
pth = '/Users/david_conant/Documents/EC56/'
blocks = [75,77]
tokens = ['AAA','IYY','UWW']
window = np.array([-1, 1])
[E,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='HG')
Es = [E[d] for d in tokens]

window = np.array([-1, 1])
[F,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='form')
Fs = [F[d] for d in tokens]
stops = [stop_times[d] for d in tokens]
starts = [start_times[d] for d in tokens]
Fs = smooth_formants(Fs,starts,stops,window)
[R2,R2ste,snsR2,best_alphas,best_times] = formant_ridge_decode_timecourse(Es,Fs,tokens,anat,alphas = np.tile(np.logspace(-100,100,50),(6,1)))
# Out:
# File found; Loading...
# Loaded
# File found; Loading...
# Loaded
#  [                       0%                       ]
#  [                       1%                       ]  1 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [**********            20%                       ]  15 of 75 complete
#  [**********            21%                       ]  16 of 75 complete
#  [***********           23%                       ]  17 of 75 complete
#  [************          24%                       ]  18 of 75 complete
#  [************          25%                       ]  19 of 75 complete
#  [*************         27%                       ]  20 of 75 complete
#  [*************         28%                       ]  21 of 75 complete
#  [**************        29%                       ]  22 of 75 complete
#  [***************       31%                       ]  23 of 75 complete
#  [***************       32%                       ]  24 of 75 complete
#  [****************      33%                       ]  25 of 75 complete
#  [*****************     35%                       ]  26 of 75 complete
#  [*****************     36%                       ]  27 of 75 complete
#  [******************    37%                       ]  28 of 75 complete
#  [*******************   39%                       ]  29 of 75 complete
#  [*******************   40%                       ]  30 of 75 complete
#  [********************  41%                       ]  31 of 75 complete
#  [********************* 43%                       ]  32 of 75 complete
#  [********************* 44%                       ]  33 of 75 complete
#  [**********************45%                       ]  34 of 75 complete
#  [**********************47%                       ]  35 of 75 complete
#  [**********************48%                       ]  36 of 75 complete
#  [**********************49%                       ]  37 of 75 complete
#  [**********************51%                       ]  38 of 75 complete
#  [**********************52%                       ]  39 of 75 complete
#  [**********************53%                       ]  40 of 75 complete
#  [**********************55%*                      ]  41 of 75 complete
#  [**********************56%**                     ]  42 of 75 complete
#  [**********************57%**                     ]  43 of 75 complete
#  [**********************59%***                    ]  44 of 75 complete
#  [**********************60%****                   ]  45 of 75 complete
#  [**********************61%****                   ]  46 of 75 complete
#  [**********************63%*****                  ]  47 of 75 complete
#  [**********************64%******                 ]  48 of 75 complete
#  [**********************65%******                 ]  49 of 75 complete
#  [**********************67%*******                ]  50 of 75 complete
#  [**********************68%********               ]  51 of 75 complete
#  [**********************69%********               ]  52 of 75 complete
#  [**********************71%*********              ]  53 of 75 complete
#  [**********************72%**********             ]  54 of 75 complete
#  [**********************73%**********             ]  55 of 75 complete
#  [**********************75%***********            ]  56 of 75 complete
#  [**********************76%***********            ]  57 of 75 complete
#  [**********************77%************           ]  58 of 75 complete
#  [**********************79%*************          ]  59 of 75 complete
#  [**********************80%*************          ]  60 of 75 complete
#  [**********************81%**************         ]  61 of 75 complete
#  [**********************83%***************        ]  62 of 75 complete
#  [**********************84%***************        ]  63 of 75 complete
#  [**********************85%****************       ]  64 of 75 complete
#  [**********************87%*****************      ]  65 of 75 complete
#  [**********************88%*****************      ]  66 of 75 complete
#  [**********************89%******************     ]  67 of 75 complete
#  [**********************91%*******************    ]  68 of 75 complete
#  [**********************92%*******************    ]  69 of 75 complete
#  [**********************93%********************   ]  70 of 75 complete
#  [**********************95%*********************  ]  71 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************99%***********************]  74 of 75 complete

# %%
pth = '/Users/david_conant/Documents/EC82/'
blocks = [19, 21,38,40,44]
tokens = ['AAA','IYY','UWW']
window = np.array([-1, 1])
[E,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='HG')
Es = [E[d] for d in tokens]

window = np.array([-1, 1])
[F,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='form')
Fs = [F[d] for d in tokens]
stops = [stop_times[d] for d in tokens]
starts = [start_times[d] for d in tokens]
Fs = smooth_formants(Fs,starts,stops,window)
[R2,R2ste,snsR2,best_alphas,best_times] = formant_ridge_decode_timecourse(Es,Fs,tokens,anat,alphas = np.tile(np.logspace(-100,100,50),(6,1)))
# Out:
# File found; Loading...
# Loaded
# File found; Loading...
# Loaded
#  [                       0%                       ]
#  [                       1%                       ]  1 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [**********            20%                       ]  15 of 75 complete
#  [**********            21%                       ]  16 of 75 complete
#  [***********           23%                       ]  17 of 75 complete
#  [************          24%                       ]  18 of 75 complete
#  [************          25%                       ]  19 of 75 complete
#  [*************         27%                       ]  20 of 75 complete
#  [*************         28%                       ]  21 of 75 complete
#  [**************        29%                       ]  22 of 75 complete
#  [***************       31%                       ]  23 of 75 complete
#  [***************       32%                       ]  24 of 75 complete
#  [****************      33%                       ]  25 of 75 complete
#  [*****************     35%                       ]  26 of 75 complete
#  [*****************     36%                       ]  27 of 75 complete
#  [******************    37%                       ]  28 of 75 complete
#  [*******************   39%                       ]  29 of 75 complete
#  [*******************   40%                       ]  30 of 75 complete
#  [********************  41%                       ]  31 of 75 complete
#  [********************* 43%                       ]  32 of 75 complete
#  [********************* 44%                       ]  33 of 75 complete
#  [**********************45%                       ]  34 of 75 complete
#  [**********************47%                       ]  35 of 75 complete
#  [**********************48%                       ]  36 of 75 complete
#  [**********************49%                       ]  37 of 75 complete
#  [**********************51%                       ]  38 of 75 complete
#  [**********************52%                       ]  39 of 75 complete
#  [**********************53%                       ]  40 of 75 complete
#  [**********************55%*                      ]  41 of 75 complete
#  [**********************56%**                     ]  42 of 75 complete
#  [**********************57%**                     ]  43 of 75 complete
#  [**********************59%***                    ]  44 of 75 complete
#  [**********************60%****                   ]  45 of 75 complete
#  [**********************61%****                   ]  46 of 75 complete
#  [**********************63%*****                  ]  47 of 75 complete
#  [**********************64%******                 ]  48 of 75 complete
#  [**********************65%******                 ]  49 of 75 complete
#  [**********************67%*******                ]  50 of 75 complete
#  [**********************68%********               ]  51 of 75 complete
#  [**********************69%********               ]  52 of 75 complete
#  [**********************71%*********              ]  53 of 75 complete
#  [**********************72%**********             ]  54 of 75 complete
#  [**********************73%**********             ]  55 of 75 complete
#  [**********************75%***********            ]  56 of 75 complete
#  [**********************76%***********            ]  57 of 75 complete
#  [**********************77%************           ]  58 of 75 complete
#  [**********************79%*************          ]  59 of 75 complete
#  [**********************80%*************          ]  60 of 75 complete
#  [**********************81%**************         ]  61 of 75 complete
#  [**********************83%***************        ]  62 of 75 complete
#  [**********************84%***************        ]  63 of 75 complete
#  [**********************85%****************       ]  64 of 75 complete
#  [**********************87%*****************      ]  65 of 75 complete
#  [**********************88%*****************      ]  66 of 75 complete
#  [**********************89%******************     ]  67 of 75 complete
#  [**********************91%*******************    ]  68 of 75 complete
#  [**********************92%*******************    ]  69 of 75 complete
#  [**********************93%********************   ]  70 of 75 complete
#  [**********************95%*********************  ]  71 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************99%***********************]  74 of 75 complete

# %%
pth = '/Users/david_conant/Documents/EC84/'
blocks = [65,78,82,85,93,95]
tokens = ['AAA','IYY','UWW']
window = np.array([-1, 1])
[E,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='HG')
Es = [E[d] for d in tokens]

window = np.array([-1, 1])
[F,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='form')
Fs = [F[d] for d in tokens]
stops = [stop_times[d] for d in tokens]
starts = [start_times[d] for d in tokens]
Fs = smooth_formants(Fs,starts,stops,window)
[R2,R2ste,snsR2,best_alphas,best_times] = formant_ridge_decode_timecourse(Es,Fs,tokens,anat,alphas = np.tile(np.logspace(-100,100,50),(6,1)))
# Out:
# File found; Loading...
# Loaded
# File found; Loading...
# Loaded
#  [                       0%                       ]
#  [                       1%                       ]  1 of 75 complete
#  [*                      3%                       ]  2 of 75 complete
#  [**                     4%                       ]  3 of 75 complete
#  [**                     5%                       ]  4 of 75 complete
#  [***                    7%                       ]  5 of 75 complete
#  [****                   8%                       ]  6 of 75 complete
#  [****                   9%                       ]  7 of 75 complete
#  [*****                 11%                       ]  8 of 75 complete
#  [******                12%                       ]  9 of 75 complete
#  [******                13%                       ]  10 of 75 complete
#  [*******               15%                       ]  11 of 75 complete
#  [********              16%                       ]  12 of 75 complete
#  [********              17%                       ]  13 of 75 complete
#  [*********             19%                       ]  14 of 75 complete
#  [**********            20%                       ]  15 of 75 complete
#  [**********            21%                       ]  16 of 75 complete
#  [***********           23%                       ]  17 of 75 complete
#  [************          24%                       ]  18 of 75 complete
#  [************          25%                       ]  19 of 75 complete
#  [*************         27%                       ]  20 of 75 complete
#  [*************         28%                       ]  21 of 75 complete
#  [**************        29%                       ]  22 of 75 complete
#  [***************       31%                       ]  23 of 75 complete
#  [***************       32%                       ]  24 of 75 complete
#  [****************      33%                       ]  25 of 75 complete
#  [*****************     35%                       ]  26 of 75 complete
#  [*****************     36%                       ]  27 of 75 complete
#  [******************    37%                       ]  28 of 75 complete
#  [*******************   39%                       ]  29 of 75 complete
#  [*******************   40%                       ]  30 of 75 complete
#  [********************  41%                       ]  31 of 75 complete
#  [********************* 43%                       ]  32 of 75 complete
#  [********************* 44%                       ]  33 of 75 complete
#  [**********************45%                       ]  34 of 75 complete
#  [**********************47%                       ]  35 of 75 complete
#  [**********************48%                       ]  36 of 75 complete
#  [**********************49%                       ]  37 of 75 complete
#  [**********************51%                       ]  38 of 75 complete
#  [**********************52%                       ]  39 of 75 complete
#  [**********************53%                       ]  40 of 75 complete
#  [**********************55%*                      ]  41 of 75 complete
#  [**********************56%**                     ]  42 of 75 complete
#  [**********************57%**                     ]  43 of 75 complete
#  [**********************59%***                    ]  44 of 75 complete
#  [**********************60%****                   ]  45 of 75 complete
#  [**********************61%****                   ]  46 of 75 complete
#  [**********************63%*****                  ]  47 of 75 complete
#  [**********************64%******                 ]  48 of 75 complete
#  [**********************65%******                 ]  49 of 75 complete
#  [**********************67%*******                ]  50 of 75 complete
#  [**********************68%********               ]  51 of 75 complete
#  [**********************69%********               ]  52 of 75 complete
#  [**********************71%*********              ]  53 of 75 complete
#  [**********************72%**********             ]  54 of 75 complete
#  [**********************73%**********             ]  55 of 75 complete
#  [**********************75%***********            ]  56 of 75 complete
#  [**********************76%***********            ]  57 of 75 complete
#  [**********************77%************           ]  58 of 75 complete
#  [**********************79%*************          ]  59 of 75 complete
#  [**********************80%*************          ]  60 of 75 complete
#  [**********************81%**************         ]  61 of 75 complete
#  [**********************83%***************        ]  62 of 75 complete
#  [**********************84%***************        ]  63 of 75 complete
#  [**********************85%****************       ]  64 of 75 complete
#  [**********************87%*****************      ]  65 of 75 complete
#  [**********************88%*****************      ]  66 of 75 complete
#  [**********************89%******************     ]  67 of 75 complete
#  [**********************91%*******************    ]  68 of 75 complete
#  [**********************92%*******************    ]  69 of 75 complete
#  [**********************93%********************   ]  70 of 75 complete
#  [**********************95%*********************  ]  71 of 75 complete
#  [**********************96%*********************  ]  72 of 75 complete
#  [**********************97%********************** ]  73 of 75 complete
#  [**********************99%***********************]  74 of 75 complete
