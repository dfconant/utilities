# %%
# %load_ext autoreload
# %autoreload 2
from ECoGstats import makeD_multi, smooth_formants, smooth_warp_formants, process_kin, normalize_contour_length, SemiPartialCorrelation
import seaborn as sns
import prettyplotlib as ppl
from matplotlib.backends.backend_agg import (FigureCanvasAgg as FigureCanvas)
from scipy.signal import savgol_filter
import pandas as pd
from BDutils import ProgressBar, resample_array, smart_toeplitz, smooth_derivative
from ecog_viz import plotWeights, gestural_score
from sklearn.cross_validation import train_test_split
from sklearn.decomposition import PCA
from sklearn.lda import LDA
from sklearn.linear_model import Ridge
import scipy as sp

import scipy.stats as stats
import matplotlib.gridspec as gridspec
import numpy as np
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Create dataframes

pth = '/Users/david_conant/Dropbox/Vowels/EC41/'
blocks = [19,20,22,27]
tokens = ['AAA','IYY','UWW','AEE','AHH','EHH','ERR','IHH','UHH']
kfeats = ['FrontTongueX','MidTongueX', 'BackTongueX','FrontTongueY','MidTongueY',
         'BackTongueY','LipOpening','LipWidth','JawX','JawY']
lag = 0
fs = 100
#Load in Dmatrices

#Electrodes
window = np.array([-.5,0.5])   #TODO: try wider window for more timepoints
[E,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='HG')
Es = [E[d] for d in tokens]
vSMC = np.concatenate((np.where(anat=='preCG')[0],np.where(anat=='postCG')[0]))
Eall = np.concatenate(Es,axis=2)
Eall = resample_array(Eall,[Eall.shape[0],np.diff(window)*fs,Eall.shape[2]])

#Kinematics
#window = np.array([0.25,0.75])
[K,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,dtype='kin',align_window = window)
Ks = [K[d] for d in tokens]
stops = [stop_times[d] for d in tokens]
starts = [start_times[d] for d in tokens]
Ks = process_kin(Ks,stops,starts,window,numTongue=6,wrt_start=True,norm_length=False)
Kall = np.concatenate(Ks,axis=2)
Kall = resample_array(Kall,[Kall.shape[0],np.diff(window)*fs,Kall.shape[2]])


gestural_score(Ks,kfeats,tokens)
# Out:
# File found; Loading...
# Loaded
# File found; Loading...
# Loaded

# %%
#lags = np.linspace(0,.1,20).astype(int)
lags = [0,0]
Rs = np.empty((10,256,len(lags)))
Rp = np.empty((10,256,len(lags)))
prog = ProgressBar(len(lags))
groups = [range(6),range(6,8),range(8,10)]
for ilag, lag in enumerate(lags):
    prog.animate(ilag)
    #Lag by removing data
    trange = np.arange(Eall.shape[1] - lag*fs)
    Klagged = Kall[:,trange,:]
    Elagged = Eall[:,trange + lag*fs,:]    #behavior-leading lag

    #Reshape across trials
    Kinematics = np.reshape(Klagged,(Klagged.shape[0],-1),order='F').transpose()
    Kinematics = pd.DataFrame(Kinematics,columns = kfeats)
    Kinematics.fillna(Kinematics.median(),inplace=True)
    #Kinematics = pd.Series(dict(enumerate(Eall.transpose())))
    hat,tilde = SemiPartialCorrelation(Kinematics,groups)
    Kinematics = tilde
    HG = np.reshape(Elagged,(Elagged.shape[0],-1),order='F').transpose()
    HG = pd.DataFrame(HG,columns = range(256))
    vsmcHG = HG.iloc[:,vSMC]
    vsmcHG.fillna(vsmcHG.median(),inplace=True)
    vsmcHG.dropna(axis =1,how='any',inplace=True)
    inner = Kinematics.shape[1]
    outer = vsmcHG.shape[1]
    for o in range(outer):
        elect = vsmcHG.columns.values[o]
        for i in range(inner):
            Rs[i,elect,ilag] = sp.stats.spearmanr(vsmcHG.loc[:,elect],Kinematics.iloc[:,i])[0]
            Rp[i,elect,ilag] = sp.stats.pearsonr(vsmcHG.loc[:,elect],Kinematics.iloc[:,i])[0]
# Out:
#  [                       0%                       ]
# FrontTongueX    0.954245
# MidTongueX      0.968246
# BackTongueX     0.975087
# FrontTongueY    0.987701
# MidTongueY      0.992534
# BackTongueY     0.991079
# LipOpening      0.262208
# LipWidth        0.804006
# JawX            0.648443
# JawY            0.329562
# dtype: float64
# FrontTongueX    0.045755
# MidTongueX      0.031754
# BackTongueX     0.024913
# FrontTongueY    0.012299
# MidTongueY      0.007466
# BackTongueY     0.008921
# LipOpening      0.737792
# LipWidth        0.195994
# JawX            0.351557
# JawY            0.670438
# dtype: float64
#  [**********************50%                       ]  1 of 2 complete
# FrontTongueX    0.954245
# MidTongueX      0.968246
# BackTongueX     0.975087
# FrontTongueY    0.987701
# MidTongueY      0.992534
# BackTongueY     0.991079
# LipOpening      0.262208
# LipWidth        0.804006
# JawX            0.648443
# JawY            0.329562
# dtype: float64
# ...

# %%
Rp[abs(Rp) > 1] = 0
Rs[abs(Rs) > 1] = 0

# %%
plt.pcolor(Rs[:,vSMC,0])
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x12f9903f8>

# %%
plt.pcolor(Rp[:,vSMC,0])
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x1422ac2d8>

# %%
lips = np.nanmean(Rs[6:8,:,0],axis=0)
tonguey = np.nanmean(Rs[3:6,:,0],axis=0)
tonguex = np.nanmean(Rs[0:3,:,0],axis=0)
jaw = np.nanmean(Rs[8:,:,0],axis=0)
tongue2 = sp.stats.mstats.zscore((np.square(tonguex)+np.square(tonguey))/2)
jaw2 = sp.stats.mstats.zscore(np.square(jaw))
lips2 = sp.stats.mstats.zscore(np.square(lips))
artics = sp.stats.mstats.zscore(np.concatenate((tongue2,lips2,jaw2),axis=1),axis=1)

# %%
# Out:
# (array([ 223.,   12.,    9.,    7.,    3.,    1.,    0.,    0.,    0.,    1.]),
#  array([ 0.        ,  0.00034111,  0.00068222,  0.00102333,  0.00136443,
#          0.00170554,  0.00204665,  0.00238776,  0.00272887,  0.00306998,
#          0.00341109]),
#  <a list of 10 Patch objects>)

# %%
sp.stats.pearsonr(vsmcHG.loc[:,elect],Kinematics.iloc[:,i])[0]
# Out:
# 0.018045266160263349

# %%
lips.shape
# Out:
# (256,)

# %%
plt.hist(jaw[vSMC])
# Out:
# (array([  2.,   2.,  10.,  14.,  19.,  12.,  12.,  11.,   2.,   2.]),
#  array([-0.03985842, -0.031809  , -0.02375959, -0.01571018, -0.00766077,
#          0.00038865,  0.00843806,  0.01648747,  0.02453688,  0.03258629,
#          0.04063571]),
#  <a list of 10 Patch objects>)

# %%
sns.set_style('dark')
plotWeights([lips])
# Out:
#  [                       0%                       ]
#  [                       1%                       ]  2 of 256 complete
#  [                       1%                       ]  3 of 256 complete
#  [*                      2%                       ]  4 of 256 complete
#  [*                      2%                       ]  5 of 256 complete
#  [*                      2%                       ]  6 of 256 complete
#  [*                      3%                       ]  7 of 256 complete
#  [*                      3%                       ]  8 of 256 complete
#  [**                     4%                       ]  9 of 256 complete
#  [**                     4%                       ]  10 of 256 complete
#  [**                     4%                       ]  11 of 256 complete
#  [**                     5%                       ]  12 of 256 complete
#  [**                     5%                       ]  13 of 256 complete
# ...

# %%
plotWeights([tonguex])
# Out:
#  [                       0%                       ]
#  [                       1%                       ]  2 of 256 complete
#  [                       1%                       ]  3 of 256 complete
#  [*                      2%                       ]  4 of 256 complete
#  [*                      2%                       ]  5 of 256 complete
#  [*                      2%                       ]  6 of 256 complete
#  [*                      3%                       ]  7 of 256 complete
#  [*                      3%                       ]  8 of 256 complete
#  [**                     4%                       ]  9 of 256 complete
#  [**                     4%                       ]  10 of 256 complete
#  [**                     4%                       ]  11 of 256 complete
#  [**                     5%                       ]  12 of 256 complete
#  [**                     5%                       ]  13 of 256 complete
# ...

# %%
plotWeights([tonguey])
# Out:
#  [                       0%                       ]
#  [                       1%                       ]  2 of 256 complete
#  [                       1%                       ]  3 of 256 complete
#  [*                      2%                       ]  4 of 256 complete
#  [*                      2%                       ]  5 of 256 complete
#  [*                      2%                       ]  6 of 256 complete
#  [*                      3%                       ]  7 of 256 complete
#  [*                      3%                       ]  8 of 256 complete
#  [**                     4%                       ]  9 of 256 complete
#  [**                     4%                       ]  10 of 256 complete
#  [**                     4%                       ]  11 of 256 complete
#  [**                     5%                       ]  12 of 256 complete
#  [**                     5%                       ]  13 of 256 complete
# ...

# %%
plotWeights([jaw])
# Out:
#  [                       0%                       ]
#  [                       1%                       ]  2 of 256 complete
#  [                       1%                       ]  3 of 256 complete
#  [*                      2%                       ]  4 of 256 complete
#  [*                      2%                       ]  5 of 256 complete
#  [*                      2%                       ]  6 of 256 complete
#  [*                      3%                       ]  7 of 256 complete
#  [*                      3%                       ]  8 of 256 complete
#  [**                     4%                       ]  9 of 256 complete
#  [**                     4%                       ]  10 of 256 complete
#  [**                     4%                       ]  11 of 256 complete
#  [**                     5%                       ]  12 of 256 complete
#  [**                     5%                       ]  13 of 256 complete
# ...

# %%
np.var(tilde)/np.var(hat)
# Out:
# FrontTongueX    0.029137
# MidTongueX      0.009180
# BackTongueX     0.033341
# FrontTongueY    0.024580
# MidTongueY      0.012484
# BackTongueY     0.123287
# LipOpening      0.354332
# LipWidth        4.056379
# JawX            1.690534
# JawY            0.469158
# dtype: float64

# %%
nums = np.char.array(range(256))
pre = np.char.array(['e']*len(nums))
pre+nums
# Out:
# chararray(['e0', 'e1', 'e2', 'e3', 'e4', 'e5', 'e6', 'e7', 'e8', 'e9', 'e10',
#        'e11', 'e12', 'e13', 'e14', 'e15', 'e16', 'e17', 'e18', 'e19',
#        'e20', 'e21', 'e22', 'e23', 'e24', 'e25', 'e26', 'e27', 'e28',
#        'e29', 'e30', 'e31', 'e32', 'e33', 'e34', 'e35', 'e36', 'e37',
#        'e38', 'e39', 'e40', 'e41', 'e42', 'e43', 'e44', 'e45', 'e46',
#        'e47', 'e48', 'e49', 'e50', 'e51', 'e52', 'e53', 'e54', 'e55',
#        'e56', 'e57', 'e58', 'e59', 'e60', 'e61', 'e62', 'e63', 'e64',
#        'e65', 'e66', 'e67', 'e68', 'e69', 'e70', 'e71', 'e72', 'e73',
#        'e74', 'e75', 'e76', 'e77', 'e78', 'e79', 'e80', 'e81', 'e82',
#        'e83', 'e84', 'e85', 'e86', 'e87', 'e88', 'e89', 'e90', 'e91',
#        'e92', 'e93', 'e94', 'e95', 'e96', 'e97', 'e98', 'e99', 'e100',
#        'e101', 'e102', 'e103', 'e104', 'e105', 'e106', 'e107', 'e108',
#        'e109', 'e110', 'e111', 'e112', 'e113', 'e114', 'e115', 'e116',
# ...

# %%
tonguex
# Out:
# array([  0.00000000e+000,   8.92677493e-315,   2.05126260e-313,
#          1.60000866e-314,   0.00000000e+000,   3.72200445e-314,
#          7.39697259e-315,   0.00000000e+000,   3.57226240e-002,
#         -1.68133378e-002,   8.92676099e-315,   0.00000000e+000,
#          7.58892303e-315,   7.07331934e-315,   8.92680305e-315,
#          2.82932773e-314,   3.54181571e-313,   5.71022003e-314,
#          3.53665965e-313,   8.92676077e-315,   1.60044528e-314,
#          1.23052908e-001,   1.52484879e-001,   4.68168440e-002,
#          2.90963561e-002,   1.28980833e-001,   2.12381802e-003,
#          7.94110664e-002,   3.45845952e-323,   3.72200453e-314,
#          7.16525768e-315,   9.38065930e-314,   1.66787775e-314,
#          7.07331931e-315,   3.72200386e-314,   8.97748133e-002,
#          1.57118483e-001,   7.69358631e-002,   1.30548276e-001,
#          1.32452717e-002,   1.22933882e-002,   7.62989883e-002,
#          1.87485167e-001,   9.19660822e-002,   1.26957461e-001,
# ...

# %%
tongue2 = (np.square(tonguex)+np.square(tonguey))/2

# %%
blockpath = '/Users/david_conant/Dropbox/Vowels/EC41/EC41_B20'
patient_dir = '/Users/david_conant/Dropbox/Vowels/EC41'
subject = 'EC41'
#vis brain
anatomy = imaging.load_anatomy(patient_dir)

regdata_load = sp.io.loadmat(os.path.expanduser(patient_dir + '/'+ subject + '_elec_pos2D.mat'))
electrode_positions = regdata_load['xy']
brain_img = 1-mpimg.imread(os.path.expanduser(patient_dir + '/'+ subject + '_brain2D.png'))
vb = VisEcog.VisBrain(brain_img,electrode_positions,anatomy)
#do visualization. 
vb.showAct(np.square(tonguex)) #lots of optional arguments
