# %% [markdown]
# ##Behavioral Characterization

# %% [markdown]
# TODO:
#     -Fix edge effects
#     -Develop metric for K^ v K~

# %%
#Intitialize
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import scipy as sp
import scipy.stats as stats
import numpy as np
from sklearn.cross_validation import train_test_split, LeaveOneOut, LeaveOneLabelOut, ShuffleSplit
from sklearn.decomposition import PCA
from sklearn.lda import LDA
from sklearn.linear_model import Lars, Ridge
import pandas as pd
import pdb
import prettyplotlib as ppl
from BDutils import ProgressBar, moving_average
from scipy.signal import savgol_filter
import seaborn as sns
import matplotlib.gridspec as gridspec
from ECoGstats import makeD_multi, process_kin, shuffle_df, smooth_formants, Ridge_MLR, Ds2Xy, smooth_derivative,ClusterSeparability
from ecog_viz import LDA_proj_scatter, gestural_score, separability_timecourse,feature_correlations,vowel_svm
from __future__ import division
from matplotlib.backends.backend_agg import (FigureCanvasAgg as FigureCanvas)
from scipy.stats import mstats

# %%
subj = 'EC41'
blocks = [19,20,22,27]
pth = '/Users/david_conant/Dropbox/Vowels/'+subj + '/'
tokens = ['AAA','IYY','UWW','AEE','AHH','EHH','ERR','IHH','UHH']
window = np.array([-1,2])
[K,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,dtype= 'kin',align_window = window)
Ks = [K[d].copy() for d in tokens]
notes = []
for ind,n in enumerate(tokens):
    notes.append([n]*Ks[ind].shape[2])
notes = np.concatenate(notes,axis=0) 

stops = [stop_times[d] for d in tokens]
starts = [start_times[d] for d in tokens]
Ks = process_kin(Ks,stops,starts,window, norm_length=True,velocity = True,wrt_start=True)
Kall = np.concatenate(Ks,axis=2)
feats = ['Front Tongue X','Mid Tongue X', 'Back Tongue X','Front Tongue Y','Mid Tongue Y',
         'Back Tongue Y','Lip Opening','Lip Width','Jaw X','Jaw Y']
sns.set_palette('Set1')

#Gestural Score:
#fig_filename = save_pth + subj + '_Kin_hvdGS_legend.png'
gestural_score(Ks,feats,tokens,fig_filename =None,window=np.array([-1,2]))
# Out:
# File found; Loading...
# Loaded
# >
#  /Users/david_conant/Dropbox/changrepo/python/datautils/BDutils.py(177)smooth_derivative()
# -> data = np.diff(data)
# (Pdb) data
# array([ 45.8749058 ,  45.94489254,  45.94489254,  46.00882279,
#         45.94489254,  46.05625743,  46.16183154,  46.39457303,
#         50.31992887,  52.01030585,  52.17219271,  52.17219271,
#         52.17219271,  52.11706187,  52.11706187,  52.11706187,
#         52.18093068,  52.62848757,  53.46219743,  53.51271694,
#         53.9598784 ,  55.28190505,  57.43726283,  57.79200103,
#         58.59805419,  59.45998396,  59.51445389,  59.64831297,
#         60.08685156,  60.90516261,  61.7477916 ,  61.7477916 ,
#         61.7477916 ,  61.7477916 ,  61.33545125,  61.05961323,
#         61.03607988,  61.02801903,  61.02801903,  61.02801903,
#         61.02801903,  61.02801903,  61.02801903,  61.01644075,
#         61.05094245,  61.09370122,  61.20353526,  62.91855311,
#         63.59390113,  63.68137656,  63.71494998,  63.7583213 ,
#         63.71494998,  63.71494998,  63.70906113,  63.70906113,
#         63.7068651 ,  63.7068651 ,  63.70663636,  63.70593415,
#         63.70437019,  63.6822448 ,  63.6822448 ,  63.68061092,
#         63.68061092,  63.66857051,  63.68061092,  63.66428495,
#         63.69258959,  63.64763156,  63.61066883,  63.50435414,
#         61.67938931,  59.93346572,  59.65829312,  58.52548592,
#         58.17739178,  56.42953857,  55.98853364,  55.64406671,
#         55.44319809,  55.44319809,  55.22093318,  55.22093318,
#         55.22093318,  54.84533226,  54.84533226,  54.07210043,
#         53.69619149,  53.46666852])
# (Pdb) data = np.diff(data)
# (Pdb) data
# array([  6.99867402e-02,   0.00000000e+00,   6.39302497e-02,
#         -6.39302497e-02,   1.11364882e-01,   1.05574119e-01,
#          2.32741484e-01,   3.92535584e+00,   1.69037698e+00,
#          1.61886862e-01,   0.00000000e+00,   0.00000000e+00,
#         -5.51308412e-02,   0.00000000e+00,   0.00000000e+00,
#          6.38688066e-02,   4.47556892e-01,   8.33709860e-01,
#          5.05195134e-02,   4.47161452e-01,   1.32202666e+00,
#          2.15535778e+00,   3.54738191e-01,   8.06053163e-01,
#          8.61929775e-01,   5.44699219e-02,   1.33859087e-01,
#          4.38538588e-01,   8.18311052e-01,   8.42628983e-01,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#         -4.12340349e-01,  -2.75838021e-01,  -2.35333492e-02,
#         -8.06084449e-03,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#         -1.15782797e-02,   3.45017000e-02,   4.27587714e-02,
#          1.09834032e-01,   1.71501786e+00,   6.75348011e-01,
#          8.74754327e-02,   3.35734172e-02,   4.33713206e-02,
#         -4.33713206e-02,   0.00000000e+00,  -5.88884681e-03,
#          0.00000000e+00,  -2.19603229e-03,   0.00000000e+00,
#         -2.28737658e-04,  -7.02207616e-04,  -1.56395799e-03,
#         -2.21253905e-02,   0.00000000e+00,  -1.63387843e-03,
#          0.00000000e+00,  -1.20404165e-02,   1.20404165e-02,
#         -1.63259777e-02,   2.83046433e-02,  -4.49580275e-02,
#         -3.69627347e-02,  -1.06314687e-01,  -1.82496483e+00,
#         -1.74592359e+00,  -2.75172603e-01,  -1.13280720e+00,
#         -3.48094136e-01,  -1.74785321e+00,  -4.41004933e-01,
#         -3.44466929e-01,  -2.00868618e-01,   0.00000000e+00,
#         -2.22264908e-01,   0.00000000e+00,   0.00000000e+00,
#         -3.75600917e-01,   0.00000000e+00,  -7.73231837e-01,
#         -3.75908937e-01,  -2.29522975e-01])
# (Pdb) out = hanning_smooth(data,width)
# (Pdb) out
# array([  8.59693026e-02,   8.44551800e-02,   6.13204679e-02,
#          9.39346285e-02,   2.16765717e-01,   1.32901029e+00,
#          3.70637442e+00,   5.43455993e+00,   4.81399438e+00,
#          2.41100856e+00,   5.30226682e-01,  -8.76415450e-04,
#         -5.51308412e-02,  -2.53809293e-02,   1.46008118e-01,
#          6.07963941e-01,   1.13337077e+00,   1.33502473e+00,
#          1.45356888e+00,   2.22383799e+00,   3.37523051e+00,
#          3.72623507e+00,   3.12178551e+00,   2.27101106e+00,
#          1.62947141e+00,   1.11245951e+00,   9.23675677e-01,
#          1.37694092e+00,   1.81265150e+00,   1.56599692e+00,
#          8.36549500e-01,   1.07572159e-01,  -3.78214767e-01,
#         -6.25102202e-01,  -6.04758506e-01,  -3.39542585e-01,
#         -9.46703616e-02,  -1.19289707e-02,  -2.01521112e-03,
#          0.00000000e+00,  -2.89456992e-03,  -5.82847691e-05,
#          2.49876882e-02,   8.53455768e-02,   5.76870465e-01,
#          1.60562893e+00,   2.33646294e+00,   2.06306984e+00,
#          1.05876380e+00,   2.89702655e-01,   5.78917512e-02,
#         -3.92168756e-03,  -2.61022954e-02,  -1.72806850e-02,
#         -6.06365932e-03,  -3.72542841e-03,  -1.99412937e-03,
#         -1.69539094e-03,  -7.57807697e-03,  -1.87418410e-02,
#         -2.38823805e-02,  -1.82104412e-02,  -1.01753302e-02,
#         -7.24561706e-03,  -7.50006814e-03,  -2.15821830e-03,
#         -3.16793809e-04,  -2.38889401e-02,  -8.21117624e-02,
#         -5.99582318e-01,  -1.95048077e+00,  -3.29217737e+00,
#         -3.63080714e+00,  -2.97748544e+00,  -2.47370145e+00,
#         -2.68763383e+00,  -2.70899605e+00,  -2.14748573e+00,
#         -1.26283540e+00,  -6.25036275e-01,  -4.03466877e-01,
#         -2.72482063e-01,  -2.60598910e-01,  -3.37266915e-01,
#         -5.68908876e-01,  -9.55601799e-01,  -1.20644451e+00,
#         -1.12797505e+00,  -7.04762637e-01])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-eb7cf046e39c> in <module>()
#      13 stops = [stop_times[d] for d in tokens]
#      14 starts = [start_times[d] for d in tokens]
# ---> 15 Ks = process_kin(Ks,stops,starts,window, norm_length=True,velocity = True,wrt_start=True)
#      16 Kall = np.concatenate(Ks,axis=2)
#      17 feats = ['Front Tongue X','Mid Tongue X', 'Back Tongue X','Front Tongue Y','Mid Tongue Y',
#
# /Users/david_conant/Dropbox/changrepo/python/datautils/ECoGstats.pyc in process_kin(ds, stops, starts, window, numTongue, wrt_start, norm_length, warp_time, polar, velocity)
#     584         for iD,D in enumerate(Ds):
#     585             for n in range(D.shape[2]):
# --> 586                 D[:,:-1,n] = np.array([smooth_derivative(D[f,:,n],7) for f in range(D.shape[0])])
#     587                 np.delete(D,[D.shape[1]-1],1)
#     588
#
# /Users/david_conant/Dropbox/changrepo/python/datautils/BDutils.py in smooth_derivative(data, width)
#     175     data= sp.signal.medfilt(data,width)
#     176     pdb.set_trace()
# --> 177     data = np.diff(data)
#     178     out = hanning_smooth(data,width)
#     179     return out
#
# /Users/david_conant/Dropbox/changrepo/python/datautils/BDutils.py in smooth_derivative(data, width)
#     175     data= sp.signal.medfilt(data,width)
#     176     pdb.set_trace()
# --> 177     data = np.diff(data)
#     178     out = hanning_smooth(data,width)
#     179     return out
#
# /Users/david_conant/anaconda/lib/python2.7/bdb.pyc in trace_dispatch(self, frame, event, arg)
#      47             return # None
#      48         if event == 'line':
# ---> 49             return self.dispatch_line(frame)
#      50         if event == 'call':
#      51             return self.dispatch_call(frame, arg)
#
# /Users/david_conant/anaconda/lib/python2.7/bdb.pyc in dispatch_line(self, frame)
#      65     def dispatch_line(self, frame):
#      66         if self.stop_here(frame) or self.break_here(frame):
# ---> 67             self.user_line(frame)
#      68             if self.quitting: raise BdbQuit
#      69         return self.trace_dispatch
#
# /Users/david_conant/anaconda/lib/python2.7/pdb.pyc in user_line(self, frame)
#     156             self._wait_for_mainpyfile = 0
#     157         if self.bp_commands(frame):
# --> 158             self.interaction(frame, None)
#     159
#     160     def bp_commands(self,frame):
#
# /Users/david_conant/anaconda/lib/python2.7/pdb.pyc in interaction(self, frame, traceback)
#     208         self.setup(frame, traceback)
#     209         self.print_stack_entry(self.stack[self.curindex])
# --> 210         self.cmdloop()
#     211         self.forget()
#     212
#
# /Users/david_conant/anaconda/lib/python2.7/cmd.pyc in cmdloop(self, intro)
#     128                     if self.use_rawinput:
#     129                         try:
# --> 130                             line = raw_input(self.prompt)
#     131                         except EOFError:
#     132                             line = 'EOF'
#
# /Users/david_conant/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/ipkernel.pyc in <lambda>(prompt)
#     361         # raw_input in the user namespace.
#     362         if content.get('allow_stdin', False):
# --> 363             raw_input = lambda prompt='': self._raw_input(prompt, ident, parent)
#     364             input = lambda prompt='': eval(raw_input(prompt))
#     365         else:
#
# /Users/david_conant/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/ipkernel.pyc in _raw_input(self, prompt, ident, parent)
#     763             except KeyboardInterrupt:
#     764                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 765                 raise KeyboardInterrupt
#     766             else:
#     767                 break
#
# KeyboardInterrupt:

# %%
#Cluster Separability:
Ks = [K[d].copy() for d in tokens]
Ks = process_kin(Ks,stops,starts,window, norm_length=True,velocity = True,wrt_start=True)
separability_timecourse(Ks,tokens,LD=3)

# %%
#Feature correlations:
feature_correlations(Ks,feats,tokens,fig_filename =None,window=np.array([-1,2]))

# %%
#LDA Scatter
Ks = [K[d].copy() for d in tokens]
Ks = process_kin(Ks,stops,starts,window,numTongue=5, norm_length=True, velocity = False, wrt_start=True)
mid = np.arange(37,42)
X = pd.DataFrame(np.nanmean(Kall[0:7,mid,:],axis=1).transpose(),index=notes)
X = X.fillna(X.median(),inplace=True)
#fig_filename = save_pth + subj + '_Kin_LD1LD2.png'
d_proj = LDA_proj_scatter(X,sc = True)
# Out:
# File found; Loading...
# Loaded
# <function matplotlib.pyplot.show>

# %%
#Classification
Ks = [K[d].copy() for d in tokens]
Ks = process_kin(Ks,stops,starts,window,numTongue=50, norm_length=True, velocity = True, wrt_start=True)
#fig_filename = save_pth + subj + '_HG_SVMC.png'
[p,vow_perf] = vowel_svm(Ks,tokens,anat,ncomp = 30,penalty = .001,boot = 100,dt = 'kin',fig_filename=None)
# Out:
# File found; Loading...
# Loaded

# %%
Ks = [K[d].copy() for d in tokens]

KV = process_kin(Ks,stops,starts,window, norm_length=True,velocity = True,wrt_start=True)

# %%
sns.tsplot(KV[0][4,:,:].transpose(),err_style='unit_traces')

# %%
KV[1].shape
# Out:
# (10, 90, 19)

# %%
KV[1][4,:,:]
# Out:
# array([[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        ...,
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan]])
