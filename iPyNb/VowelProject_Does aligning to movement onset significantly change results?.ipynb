# %% [markdown]
# Because it is likely that the activity we see in vSMC is related to movement, not acoustics, aligning to the onset of the acoustics is causing some degree of noise. In the worst case, if the onset of movement is highly variable wrt the onset of acoustics, the results we're seeing could be really smeared in time (e.g. sharp peaks become slow rising hills). To assess the degree to which this is true, I manually defined the onset of movement for one subject and examined the variability of movement onset, and the effect of aligning to movement onset on ERPs.
#
# One note on defining the onset of movement: it's more complicated than it seems. The main issue I'm having right now is that for several of the mid-vowels, the movement is very subtle (i.e. the tongue doesn't move much from starting position). I'm trying a few ways of best identifying the onset, but for now, I marked some trials (about 1/4) as 'poor_alignment' and set their onset at the acoustic onset. This skews the results a bit, but is an easier comparison to the acoustically aligned data.

# %%
#Intitialize
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from __future__ import division
import sys
import ecog_viz as ev
import numpy as np
import seaborn as sns
import pandas as pd
from brain_utils import brainBaseline
from brain.dataformat.brainformat import *
from IPython.display import Image
import scipy as sp
sns.set_style('darkgrid')

# %%
onset = sp.io.loadmat('/Users/david_conant/Documents/EC41/onset.mat')['onset']
poor_align = sp.io.loadmat('/Users/david_conant/Documents/EC41/poor_align.mat')['poor_align']
good_onset = np.delete(onset,poor_align-1)
good_onset = good_onset.astype(float)-30
sns.distplot(good_onset)
print('Median movement onset = ' + str(median(good_onset)/30) + ' seconds before acoustic onset')
print('STD = ' + str(std(good_onset)/30) + ' seconds')
# Out:
# Median movement onset = -0.1 seconds before acoustic onset
# STD = 0.0966373018867 seconds

# %% [markdown]
# There is a pretty substantial spread of movement onsets, does correcting for that spread result in any differences?

# %% [markdown]
# ####Acoustic Aligned

# %%
sns.set_style('dark')
pth = '/Users/david_conant/Documents/EC41/EC41.prod.vow.B19_20_22_27.align1_1.neural.h5'
f = BrainDataFile(pth , 'r')
i = f.data().internal()
e = i.ecog_data_processed(0)
e_z = brainBaseline(e)
#e_z = e.ecog_data()
notes = np.array(e.dims(axis = 'channels', get_hdf = False)[1]['dataset'])
anat = np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset'])
#Slice data
tokens = ['IYY','AAA','UWW']
Ds = [];
for v in tokens:
    filt = np.where(notes == v)
    anno_data =  e_z[:,:,filt[0]]
    Ds.append(anno_data[:,0:300,:]) 
ax = ev.plotERPs(Ds,align_window = np.array([-.5,1]), anatomy = anat,labels = tokens)
# Out:
#  [                       0%                       ]
#  [                       1%                       ]  2 of 256 complete
#  [                       1%                       ]  3 of 256 complete
#  [*                      2%                       ]  4 of 256 complete
#  [*                      2%                       ]  5 of 256 complete
#  [*                      2%                       ]  6 of 256 complete
#  [*                      3%                       ]  7 of 256 complete
#  [*                      3%                       ]  8 of 256 complete
#  [**                     4%                       ]  9 of 256 complete
#  [**                     4%                       ]  10 of 256 complete
#  [**                     4%                       ]  11 of 256 complete
#  [**                     5%                       ]  12 of 256 complete
#  [**                     5%                       ]  13 of 256 complete
# ...

# %%
ax = ev.plotERPs(Ds,align_window = np.array([-1,1]), anatomy = anat,labels = tokens,
                 yscale = 'independent',elects = [90,25,53,55,59,58,67,73,37,26,102,135,4,25])
# Out:
#  [                       0%                       ]
#  [*******               14%                       ]  2 of 14 complete
#  [**********            21%                       ]  3 of 14 complete
#  [**************        29%                       ]  4 of 14 complete
#  [*****************     36%                       ]  5 of 14 complete
#  [********************* 43%                       ]  6 of 14 complete
#  [**********************50%                       ]  7 of 14 complete
#  [**********************57%**                     ]  8 of 14 complete
#  [**********************64%******                 ]  9 of 14 complete
#  [**********************71%*********              ]  10 of 14 complete
#  [**********************79%*************          ]  11 of 14 complete
#  [**********************86%****************       ]  12 of 14 complete
#  [**********************93%********************   ]  13 of 14 complete
#  [*********************100%***********************]  14 of 14 complete

# %% [markdown]
# ####Movement Aligned

# %%
pth = '/Users/david_conant/Documents/EC41/mov_onset_neuralY.h5'
f = BrainDataFile(pth , 'r')
i = f.data().internal()
e = i.ecog_data_processed(0)
e_z = brainBaseline(e)
#e_z = e.ecog_data()
notes = np.array(e.dims(axis = 'channels', get_hdf = False)[1]['dataset'])
anat = np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset'])
#Slice data
tokens = ['IYY','AAA','UWW']
Ds = [];
for v in tokens:
    filt = np.where(notes == v)
    anno_data =  e_z[:,:,filt[0]]
    Ds.append(anno_data[:,0:300,:]) 
ax = ev.plotERPs(Ds,align_window = np.array([-.5,1]), anatomy = anat,labels = tokens)
# Out:
#  [                       0%                       ]
#  [                       1%                       ]  2 of 256 complete
#  [                       1%                       ]  3 of 256 complete
#  [*                      2%                       ]  4 of 256 complete
#  [*                      2%                       ]  5 of 256 complete
#  [*                      2%                       ]  6 of 256 complete
#  [*                      3%                       ]  7 of 256 complete
#  [*                      3%                       ]  8 of 256 complete
#  [**                     4%                       ]  9 of 256 complete
#  [**                     4%                       ]  10 of 256 complete
#  [**                     4%                       ]  11 of 256 complete
#  [**                     5%                       ]  12 of 256 complete
#  [**                     5%                       ]  13 of 256 complete
# ...

# %%
ax = ev.plotERPs(Ds,align_window = np.array([-1,1]), anatomy = anat,labels = tokens,
                 yscale = 'independent',elects = [90,25,53,55,59,58,67,73,37,26,102,135,4,25])
# Out:
#  [                       0%                       ]
#  [*******               14%                       ]  2 of 14 complete
#  [**********            21%                       ]  3 of 14 complete
#  [**************        29%                       ]  4 of 14 complete
#  [*****************     36%                       ]  5 of 14 complete
#  [********************* 43%                       ]  6 of 14 complete
#  [**********************50%                       ]  7 of 14 complete
#  [**********************57%**                     ]  8 of 14 complete
#  [**********************64%******                 ]  9 of 14 complete
#  [**********************71%*********              ]  10 of 14 complete
#  [**********************79%*************          ]  11 of 14 complete
#  [**********************86%****************       ]  12 of 14 complete
#  [**********************93%********************   ]  13 of 14 complete
#  [*********************100%***********************]  14 of 14 complete

# %% [markdown]
# Mostly the difference is that everything is moved forward in time. There are a couple of electrodes that show additional structure (68 and 27) but for the most part, no major changes. Interestingly, there is a lot of activity prior to movement onset (assuming that activity isn't due to the 1/4 of trials I wasn't able to realign), which bodes well for future analyses on movement planning.

# %% [markdown]
# Conclusions:
#
#     -At least preliminarily, there aren't major differences aside from timing between acoustic and movement onset alignment

# %% [markdown]
# Future Directions:
#
#     -Define onsets with greater confidence, build pipeline
#     -Perform on other subjects with kinematic tracking.
