# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import h5py
import CoartBehavior as cb
import CoartEncoding as ce
import matplotlib.pyplot as plt
import scipy as sp
import numpy as np
from scipy import stats
from scipy import signal
import mat2py
import DCstats
import Dtransform as dt
from sklearn import preprocessing
import pandas as pd
import VowelBehavior as vb
import seaborn as sns

# %%
dataFile = '/Users/david_conant/Dropbox/EC56/EC56.prod.hVd.B77.align1_2.kin.Scaled.Transformed.mat'
[meta, K] = mat2py.loadNorm(dataFile,['meta','kinY'],['list','nparray'])
notes = meta[0]['notes'][0]
labs = meta[0]['labs'][0][0]
k = vb.unpackY(K,1,0)

#K = pd.Panel(k,items = ['T1','T2','T3'],major_axis = np.arange(K.shape[1]),minor_axis = notes)
# Out:
# /Users/david_conant/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/numpy/lib/nanfunctions.py:607: RuntimeWarning: Mean of empty slice
#   warnings.warn("Mean of empty slice", RuntimeWarning)

# %%
vb.gestural_score(k,meta[0]['labs'],['AAA','UWW','IYY'])

# %%
comparisons = [1,7,9]

import collections

numComp = len(comparisons)
countComp = dict(collections.Counter(labs)).values()
numFeats = k.shape[0]
dict(cnt).values()
fig, axes = plt.subplots(figsize=(15,10))
for f in range(numFeats):
    D = np.empty((max(countComp),k.shape[1],numComp))
    itr = 0;
    for c in comparisons:
        D[range(countComp[c-1]),:,itr] = k[f,:,np.where(c == labs)[0]]
        itr += 1
    ax = fig.add_subplot(3,1,f)    
    sns.tsplot(D)

# %%
D.shape
# Out:
# (10, 76, 3)

# %%
plt.plot(np.nanmean(D,axis = 0)[:,0])

# %%
D[range(countComp[c-1]),k,c-1] = k[f,:,np.where(c == labs)[0]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-67-3af693fb7395> in <module>()
# ----> 1 D[range(countComp[c-1]),k,c-1] = k[f,:,np.where(c == labs)[0]]
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %%
D[range(countComp[c-1]),k,c-1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-68-8cf3af015687> in <module>()
# ----> 1 D[range(countComp[c-1]),k,c-1]
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %%
np.where(c == labs)[0]
# Out:
# array([ 1, 10, 24, 33, 35, 52, 59, 63, 73])

# %%
np.where(comparisons[1] == notes)[0]
# Out:
# array([], dtype=int64)
