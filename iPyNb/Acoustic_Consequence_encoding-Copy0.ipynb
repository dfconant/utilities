# %%
# %load_ext autoreload
# %autoreload 2
from ECoGstats import makeD_multi, smooth_formants, LARS_MLR,Ds2Xy,Ridge_MLR,process_kin, normalize_contour_length, shuffle_df,subtract_baseline,SemiPartialCorrelation
import seaborn as sns
import prettyplotlib as ppl
from matplotlib.backends.backend_agg import (FigureCanvasAgg as FigureCanvas)
from scipy.signal import savgol_filter
import pandas as pd
from BDutils import ProgressBar, resample_array, smart_toeplitz, smooth_derivative,seq_labels,procrustes_mean
from ecog_viz import gestural_score,R2viz, plotkhat, set_style_black

from sklearn.cross_validation import train_test_split
from sklearn.decomposition import PCA
from sklearn.lda import LDA
from sklearn.linear_model import Lars
import scipy as sp
import itertools

import scipy.stats as stats
import matplotlib.gridspec as gridspec
import numpy as np
import matplotlib.pyplot as plt
import VisEcog
import imaging
import os
import matplotlib.image as mpimg
import brewer2mpl
import re
set_style_black()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pth = '/Users/david_conant/Dropbox/Vowels/EC41/'
blocks = [19,20,22,27]
tokens = ['AAA','IYY','UWW','AEE','AHH','EHH','ERR','IHH','UHH']
#tokens = ['HAWED','HEED','WHOOD','HAD','HUD','HEAD','HEARD','HID','HOOD']
kfeats = ['kFrontTongueX','kFMidTongueX','kMidTongueX','kBMidTongueX','kBackTongueX','kFrontTongueY','kFMidTongueY','kMidTongueY',
          'kBMidTongueY','kBackTongueY','kLipOpening','kLipWidth','kJawX','kJawY']
efeats = seq_labels('e',256)
fs = 100
#Load in Dmatrices

#Electrodes
window = np.array([-1,2])   #TODO: try wider window for more timepoints
[E,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='HG')
Es = [E[d] for d in tokens]
vSMC = np.concatenate((np.where(anat=='preCG')[0],np.where(anat=='postCG')[0]))
vSMC_logic = np.zeros(256,dtype=bool)
vSMC_logic[vSMC] = True
Eall = np.concatenate(Es,axis=2)
#Eall = subtract_baseline(Eall)
#Eall = resample_array(Eall,[Eall.shape[0],np.diff(window)[0]*fs,Eall.shape[2]])

#Kinematics
#window = np.array([0.25,0.75])
[K,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,dtype='kin',align_window = window)
Ks = [K[d] for d in tokens]
stops = [stop_times[d] for d in tokens]
starts = [start_times[d] for d in tokens]
#Ks,meanTng,Z,d = procrustes_tongue(Ks[:],scale=True,viz=False)
Ks = process_kin(Ks,stops,starts,window,numTongue=6,wrt_start=False,norm_length=True)
Kall = np.concatenate(Ks,axis=2)
#Kall = resample_array(Kall,[Kall.shape[0],np.diff(window)[0]*fs,Kall.shape[2]])
# Out:
# File found; Loading...
# Loaded
# File found; Loading...
# Loaded

# %% [markdown]
# ###Average Tongue shapes, w/ variance plotted below

# %%
pth = '/Users/david_conant/Dropbox/Vowels/EC41/'
blocks = [19,20,22,27]
tokens = ['AAA','IYY','UWW','AEE','AHH','EHH','ERR','IHH','UHH']
#tokens = ['HAWED','HEED','WHOOD','HAD','HUD','HEAD','HEARD','HID','HOOD']
kfeats = ['kFrontTongueX','kFMidTongueX','kMidTongueX','kBMidTongueX','kBackTongueX','kFrontTongueY','kFMidTongueY','kMidTongueY',
          'kBMidTongueY','kBackTongueY','kLipOpening','kLipWidth','kJawX','kJawY']
efeats = seq_labels('e',256)
fs = 100
#Load in Dmatrices

#Electrodes
window = np.array([-1,2])   #TODO: try wider window for more timepoints
[E,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='HG')
Es = [E[d] for d in tokens]
vSMC = np.concatenate((np.where(anat=='preCG')[0],np.where(anat=='postCG')[0]))
vSMC_logic = np.zeros(256,dtype=bool)
vSMC_logic[vSMC] = True
Eall = np.concatenate(Es,axis=2)
#Eall = subtract_baseline(Eall)
#Eall = resample_array(Eall,[Eall.shape[0],np.diff(window)[0]*fs,Eall.shape[2]])

#Kinematics
#window = np.array([0.25,0.75])
[K,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,dtype='kin',align_window = window)
Ks = [K[d] for d in tokens]
stops = [stop_times[d] for d in tokens]
starts = [start_times[d] for d in tokens]
#Ks,meanTng,Z,d = procrustes_tongue(Ks[:],scale=True,viz=False)
#Ks = process_kin(Ks,stops,starts,window,numTongue=200,wrt_start=False,norm_length=True)
Kall = np.concatenate(Ks,axis=2)
#Kall = resample_array(Kall,[Kall.shape[0],np.diff(window)[0]*fs,Kall.shape[2]])

# %%
fig,axes = plt.subplots(figsize=(18,11))
krange = range(37,50)
for vi,v in enumerate(tokens):
    ax = plt.subplot(3,3,vi)
    for t in range(Ks[vi].shape[2]):
        midTng = np.swapaxes(np.concatenate((Ks[vi][0:100,krange,t,np.newaxis], Ks[vi][100:200,krange,t,np.newaxis]),axis=2),1,2)
        meanTng = procrustes_mean(midTng)
        plt.plot(meanTng[:,0],-meanTng[:,1])

# %%
fig,axes = plt.subplots(figsize=(18,11))
krange = range(37,50)

for vi,v in enumerate(tokens):
    ax = plt.subplot(3,3,vi)
    meanTng = np.empty((100,2,Ks[vi].shape[2]))
    for t in range(Ks[vi].shape[2]):
        midTng = np.swapaxes(np.concatenate((Ks[vi][0:100,krange,t,np.newaxis], Ks[vi][100:200,krange,t,np.newaxis]),axis=2),1,2)
        meanTng[:,:,t] = procrustes_mean(midTng)
    tngVar = np.nanvar(meanTng,axis=2)
    plt.plot(tngVar[:,1])

# %%
pth = '/Users/david_conant/Dropbox/Vowels/EC92/'
blocks = [35,36,37,45,46]
tokens = ['AAA','IYY','UWW','AEE','AHH','EHH','ERR','IHH','UHH']
#tokens = ['HAWED','HEED','WHOOD','HAD','HUD','HEAD','HEARD','HID','HOOD']
kfeats = ['kFrontTongueX','kFMidTongueX','kMidTongueX','kBMidTongueX','kBackTongueX','kFrontTongueY','kFMidTongueY','kMidTongueY',
          'kBMidTongueY','kBackTongueY','kLipOpening','kLipWidth','kJawX','kJawY']
efeats = seq_labels('e',256)
fs = 100
#Load in Dmatrices

#Electrodes
window = np.array([-1,2])   #TODO: try wider window for more timepoints
[E,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='HG')
Es = [E[d] for d in tokens]
vSMC = np.concatenate((np.where(anat=='preCG')[0],np.where(anat=='postCG')[0]))
vSMC_logic = np.zeros(256,dtype=bool)
vSMC_logic[vSMC] = True
Eall = np.concatenate(Es,axis=2)
#Eall = subtract_baseline(Eall)
#Eall = resample_array(Eall,[Eall.shape[0],np.diff(window)[0]*fs,Eall.shape[2]])

#Kinematics
#window = np.array([0.25,0.75])
[K,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,dtype='kin',align_window = window)
Ks = [K[d] for d in tokens]
stops = [stop_times[d] for d in tokens]
starts = [start_times[d] for d in tokens]
Ks,meanTng,Z,d = procrustes_tongue(Ks[:],scale=False,viz=False)
#Ks = process_kin(Ks,stops,starts,window,numTongue=200,wrt_start=False,norm_length=False)
Kall = np.concatenate(Ks,axis=2)
#Kall = resample_array(Kall,[Kall.shape[0],np.diff(window)[0]*fs,Kall.shape[2]])
# Out:
# File found; Loading...
# Loaded
# File found; Loading...
# Loaded

# %%
fig,axes = plt.subplots(figsize=(18,11))
krange = range(37,50)
for vi,v in enumerate(tokens):
    ax = plt.subplot(3,3,vi)
    for t in range(Ks[vi].shape[2]):
        midTng = np.swapaxes(np.concatenate((Ks[vi][0:100,krange,t,np.newaxis], Ks[vi][100:200,krange,t,np.newaxis]),axis=2),1,2)
        meanTng = procrustes_mean(midTng)
        plt.plot(meanTng[:,0],-meanTng[:,1])

# %% [markdown]
# ###Decomposition of K into K<sup>hat</sup> and K<sup>tilde</sup>

# %%
#Kinematic Mapping/Decomposition
elects = [21,25,35,37,43,53,55,58,59,67,72,73,86,90,102]
pth = '/Users/david_conant/Dropbox/Vowels/EC41/'
window = np.array([-1,2])

[F,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='form')
Fs = [F[d] for d in tokens]
Fs = smooth_formants(Fs,starts,stops,window)

CV = 'LOO'
boot = 1
ncomp = 8
nTP = 1
alphas = np.logspace(-3,3,20)
Kr2 = np.empty((Ks[0].shape[0],nTP,len(alphas)))
Kr2null = np.empty((Ks[0].shape[0],nTP,len(alphas)))


prog = ProgressBar(nTP)
prog.animate(0)
for indt,t in enumerate(np.linspace(0,396,nTP)):
    erange = np.arange(t,t+4)   #Try playing with window size

    #Organize data into X and y
    X,y,yrnd = Ds2Xy(Fs,Ks,dt1='form',dt2='kin',ncomp = ncomp,erange = erange.astype(int),elects = elects,frange=np.arange(105,115),krange=np.arange(37,42))
    if indt is 0:
        Korig = np.empty((y.shape[0],y.shape[1],nTP,len(alphas)))
        Khat = np.empty((y.shape[0],y.shape[1],nTP,len(alphas)))
        Ktilde = np.empty((y.shape[0],y.shape[1],nTP,len(alphas)))
    #Ridge regressionnan
    for inda,a in enumerate(alphas):
        Kr2[:,indt,inda],coefs,yhat,score = Ridge_MLR(X, y, alpha = a, CV = CV, boot = boot)
        Korig[:,:,indt,inda] = squeeze(y)
        Khat[:,:,indt,inda] = squeeze(yhat)
        Ktilde[:,:,indt,inda] = y - squeeze(yhat)
        Kr2null[:,indt,inda],coefs,yhat,score = Ridge_MLR(X, yrnd, alpha = a, CV = CV, boot = boot)
    prog.animate(indt+1)
R2viz(Kr2,Kr2null,kfeats,b=False)
# Out:
# File found; Loading...
# Loaded
#  [                       0%                       ]
#  [*********************100%***********************]  1 of 1 complete

# %%
notes = []
for ind,n in enumerate(tokens):
    notes.append([n]*Ks[ind].shape[2])
notes = np.concatenate(notes,axis=0) 
plotkhat(Korig,Khat,kfeats,notes)

# %%
Kr2[:,indt,inda].shape
# Out:
# (14,)

# %%
pth = '/Users/david_conant/Dropbox/Vowels/EC92/'
blocks = [35,36,37,45,46]
tokens = ['AAA','IYY','UWW','AEE','AHH','EHH','ERR','IHH','UHH']
#tokens = ['HAWED','HEED','WHOOD','HAD','HUD','HEAD','HEARD','HID','HOOD']
kfeats = ['kFrontTongueX','kFMidTongueX','kMidTongueX','kBMidTongueX','kBackTongueX','kFrontTongueY','kFMidTongueY','kMidTongueY',
          'kBMidTongueY','kBackTongueY','kLipOpening','kLipWidth','kJawX','kJawY']
efeats = seq_labels('e',256)
fs = 100
#Load in Dmatrices

#Electrodes
window = np.array([-1,2])   #TODO: try wider window for more timepoints
[E,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='HG')
Es = [E[d] for d in tokens]
vSMC = np.concatenate((np.where(anat=='preCG')[0],np.where(anat=='postCG')[0]))
vSMC_logic = np.zeros(256,dtype=bool)
vSMC_logic[vSMC] = True
Eall = np.concatenate(Es,axis=2)
#Eall = subtract_baseline(Eall)
#Eall = resample_array(Eall,[Eall.shape[0],np.diff(window)[0]*fs,Eall.shape[2]])

#Kinematics
#window = np.array([0.25,0.75])
[K,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,dtype='kin',align_window = window)
Ks = [K[d] for d in tokens]
stops = [stop_times[d] for d in tokens]
starts = [start_times[d] for d in tokens]
Ks = process_kin(Ks,stops,starts,window,numTongue=10,wrt_start=False,norm_length=False)
Kall = np.concatenate(Ks,axis=2)
#Kall = resample_array(Kall,[Kall.shape[0],np.diff(window)[0]*fs,Kall.shape[2]])
# Out:
# File found; Loading...
# Loaded
# File found; Loading...
# Loaded

# %%
#Kinematic Mapping/Decomposition
#elects = [21,25,35,37,43,53,55,58,59,67,72,73,86,90,102]
pth = '/Users/david_conant/Dropbox/Vowels/EC92/'
window = np.array([-1,2])

[F,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='form')
Fs = [F[d] for d in tokens]
Fs = smooth_formants(Fs,starts,stops,window)

CV = 'LOO'
boot = 1
ncomp = 8
nTP = 1
alphas = np.logspace(-3,3,20)
Kr2 = np.empty((Ks[0].shape[0],nTP,len(alphas)))
Kr2null = np.empty((Ks[0].shape[0],nTP,len(alphas)))


prog = ProgressBar(nTP)
prog.animate(0)
for indt,t in enumerate(np.linspace(0,396,nTP)):
    erange = np.arange(t,t+4)   #Try playing with window size

    #Organize data into X and y
    X,y,yrnd = Ds2Xy(Fs,Ks,dt1='form',dt2='kin',ncomp = ncomp,erange = erange.astype(int),elects = elects,frange=np.arange(105,115),krange=np.arange(37,42))
    if indt is 0:
        Korig = np.empty((y.shape[0],y.shape[1],nTP,len(alphas)))
        Khat = np.empty((y.shape[0],y.shape[1],nTP,len(alphas)))
        Ktilde = np.empty((y.shape[0],y.shape[1],nTP,len(alphas)))
    #Ridge regressionnan
    for inda,a in enumerate(alphas):
        Kr2[:,indt,inda],coefs,yhat,score = Ridge_MLR(X, y, alpha = a, CV = CV, boot = boot)
        Korig[:,:,indt,inda] = squeeze(y)
        Khat[:,:,indt,inda] = squeeze(yhat)
        Ktilde[:,:,indt,inda] = y - squeeze(yhat)
        Kr2null[:,indt,inda],coefs,yhat,score = Ridge_MLR(X, yrnd, alpha = a, CV = CV, boot = boot)
    prog.animate(indt+1)
R2viz(Kr2,Kr2null,kfeats,b=False)
# Out:
# Processing block 19
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-94-938b613c6d7c> in <module>()
#       4 window = np.array([-1,2])
#       5
# ----> 6 [F,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='form')
#       7 Fs = [F[d] for d in tokens]
#       8 Fs = smooth_formants(Fs,starts,stops,window)
#
# /Users/david_conant/Dropbox/changrepo/python/datautils/ECoGstats.pyc in makeD_multi(pth, blocks, tokens, align_window, dtype)
#     368             elif os.path.isfile(lab_path):
#     369                 parseout = parseLab(lab_path)
# --> 370             datamat = [parseout[key] for key in parseout.keys()]
#     371             df = pd.DataFrame(np.vstack(datamat).T,columns=parseout.keys())
#     372             df = df[df['tier'] == 'word']
#
# UnboundLocalError: local variable 'parseout' referenced before assignment

# %%
notes = []
for ind,n in enumerate(tokens):
    notes.append([n]*Ks[ind].shape[2])
notes = np.concatenate(notes,axis=0) 
plotkhat(Korig,Khat,kfeats,notes)

# %% [markdown]
# ###Neural decoding of K<sup>hat</sup> and K<sup>tilde</sup>

# %%
CV = 'split'
boot = 50
ncomp = 40
nTP = 200
alphas = np.logspace(-2,8,20)
#alphas = range(20)

window = np.array([-1, 2])
[E,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='HG')
Es = [E[d] for d in tokens]
#elects = np.concatenate((np.where(anat=='preCG')[0],np.where(anat=='postCG')[0]))
elects = [21,25,35,37,43,53,55,58,59,67,72,73,86,90,102]
Kr2 = np.empty((Ks[0].shape[0],boot,nTP,len(alphas)))
Kr2null = np.empty((Ks[0].shape[0],boot,nTP,len(alphas)))

prog = ProgressBar(nTP)
for indt,t in enumerate(np.linspace(200,600,nTP)):
    erange = np.arange(t,t+4)   #Try playing with window size

    #Organize data into X and y
    X,y,yrnd = Ds2Xy(Es,Ks,dt1='HG',dt2='kin',ncomp = ncomp,erange = erange.astype(int),elects = elects,frange=np.arange(105,115),krange=np.arange(37,42))
    y= Korig[:,:,0,0]
    #Ridge regression
    for inda,a in enumerate(alphas):
        Kr2[:,:,indt,inda],coefs,yhat,score = Ridge_MLR(X, y, alpha = a, CV = CV, boot = boot)
        Kr2null[:,:,indt,inda],coefs,yhat,score = Ridge_MLR(X, yrnd, alpha = a, CV = CV, boot = boot)
    prog.animate(indt)
R2viz(Kr2,Kr2null,kfeats,b=True)
# Out:
# File found; Loading...
# Loaded
#  [                       0%                       ]
#  [                       1%                       ]  1 of 200 complete
#  [                       1%                       ]  2 of 200 complete
#  [*                      2%                       ]  3 of 200 complete
#  [*                      2%                       ]  4 of 200 complete
#  [*                      3%                       ]  5 of 200 complete
#  [*                      3%                       ]  6 of 200 complete
#  [**                     4%                       ]  7 of 200 complete
#  [**                     4%                       ]  8 of 200 complete
#  [**                     5%                       ]  9 of 200 complete
#  [**                     5%                       ]  10 of 200 complete
#  [***                    6%                       ]  11 of 200 complete
#  [***                    6%                       ]  12 of 200 complete
#  [***                    7%                       ]  13 of 200 complete
#  [***                    7%                       ]  14 of 200 complete
#  [****                   8%                       ]  15 of 200 complete
#  [****                   8%                       ]  16 of 200 complete
#  [****                   9%                       ]  17 of 200 complete
#  [****                   9%                       ]  18 of 200 complete
#  [*****                 10%                       ]  19 of 200 complete
#  [*****                 10%                       ]  20 of 200 complete
#  [*****                 11%                       ]  21 of 200 complete
#  [*****                 11%                       ]  22 of 200 complete
#  [******                12%                       ]  23 of 200 complete
#  [******                12%                       ]  24 of 200 complete
#  [******                13%                       ]  25 of 200 complete
#  [******                13%                       ]  26 of 200 complete
#  [*******               14%                       ]  27 of 200 complete
#  [*******               14%                       ]  28 of 200 complete
#  [*******               14%                       ]  29 of 200 complete
#  [*******               15%                       ]  30 of 200 complete
#  [********              16%                       ]  31 of 200 complete
#  [********              16%                       ]  32 of 200 complete
#  [********              17%                       ]  33 of 200 complete
#  [********              17%                       ]  34 of 200 complete
#  [*********             18%                       ]  35 of 200 complete
#  [*********             18%                       ]  36 of 200 complete
#  [*********             19%                       ]  37 of 200 complete
#  [*********             19%                       ]  38 of 200 complete
#  [**********            20%                       ]  39 of 200 complete
#  [**********            20%                       ]  40 of 200 complete
#  [**********            21%                       ]  41 of 200 complete
#  [**********            21%                       ]  42 of 200 complete
#  [***********           22%                       ]  43 of 200 complete
#  [***********           22%                       ]  44 of 200 complete
#  [***********           23%                       ]  45 of 200 complete
#  [***********           23%                       ]  46 of 200 complete
#  [************          24%                       ]  47 of 200 complete
#  [************          24%                       ]  48 of 200 complete
#  [************          25%                       ]  49 of 200 complete
#  [************          25%                       ]  50 of 200 complete
#  [************          26%                       ]  51 of 200 complete
#  [************          26%                       ]  52 of 200 complete
#  [*************         27%                       ]  53 of 200 complete
#  [*************         27%                       ]  54 of 200 complete
#  [*************         28%                       ]  55 of 200 complete
#  [*************         28%                       ]  56 of 200 complete
#  [*************         28%                       ]  57 of 200 complete
#  [**************        29%                       ]  58 of 200 complete
#  [**************        30%                       ]  59 of 200 complete
#  [**************        30%                       ]  60 of 200 complete
#  [***************       31%                       ]  61 of 200 complete
#  [***************       31%                       ]  62 of 200 complete
#  [***************       32%                       ]  63 of 200 complete
#  [***************       32%                       ]  64 of 200 complete
#  [****************      33%                       ]  65 of 200 complete
#  [****************      33%                       ]  66 of 200 complete
#  [****************      34%                       ]  67 of 200 complete
#  [****************      34%                       ]  68 of 200 complete
#  [*****************     35%                       ]  69 of 200 complete
#  [*****************     35%                       ]  70 of 200 complete
#  [*****************     36%                       ]  71 of 200 complete
#  [*****************     36%                       ]  72 of 200 complete
#  [******************    37%                       ]  73 of 200 complete
#  [******************    37%                       ]  74 of 200 complete
#  [******************    38%                       ]  75 of 200 complete
#  [******************    38%                       ]  76 of 200 complete
#  [*******************   39%                       ]  77 of 200 complete
#  [*******************   39%                       ]  78 of 200 complete
#  [*******************   40%                       ]  79 of 200 complete
#  [*******************   40%                       ]  80 of 200 complete
#  [********************  41%                       ]  81 of 200 complete
#  [********************  41%                       ]  82 of 200 complete
#  [********************  42%                       ]  83 of 200 complete
#  [********************  42%                       ]  84 of 200 complete
#  [********************* 43%                       ]  85 of 200 complete
#  [********************* 43%                       ]  86 of 200 complete
#  [********************* 44%                       ]  87 of 200 complete
#  [********************* 44%                       ]  88 of 200 complete
#  [**********************45%                       ]  89 of 200 complete
#  [**********************45%                       ]  90 of 200 complete
#  [**********************46%                       ]  91 of 200 complete
#  [**********************46%                       ]  92 of 200 complete
#  [**********************47%                       ]  93 of 200 complete
#  [**********************47%                       ]  94 of 200 complete
#  [**********************48%                       ]  95 of 200 complete
#  [**********************48%                       ]  96 of 200 complete
#  [**********************49%                       ]  97 of 200 complete
#  [**********************49%                       ]  98 of 200 complete
#  [**********************50%                       ]  99 of 200 complete
#  [**********************50%                       ]  100 of 200 complete
#  [**********************51%                       ]  101 of 200 complete
#  [**********************51%                       ]  102 of 200 complete
#  [**********************52%                       ]  103 of 200 complete
#  [**********************52%                       ]  104 of 200 complete
#  [**********************53%                       ]  105 of 200 complete
#  [**********************53%                       ]  106 of 200 complete
#  [**********************54%*                      ]  107 of 200 complete
#  [**********************54%*                      ]  108 of 200 complete
#  [**********************55%*                      ]  109 of 200 complete
#  [**********************55%*                      ]  110 of 200 complete
#  [**********************56%**                     ]  111 of 200 complete
#  [**********************56%**                     ]  112 of 200 complete
#  [**********************56%**                     ]  113 of 200 complete
#  [**********************57%**                     ]  114 of 200 complete
#  [**********************57%**                     ]  115 of 200 complete
#  [**********************58%***                    ]  116 of 200 complete
#  [**********************59%***                    ]  117 of 200 complete
#  [**********************59%***                    ]  118 of 200 complete
#  [**********************60%****                   ]  119 of 200 complete
#  [**********************60%****                   ]  120 of 200 complete
#  [**********************61%****                   ]  121 of 200 complete
#  [**********************61%****                   ]  122 of 200 complete
#  [**********************62%*****                  ]  123 of 200 complete
#  [**********************62%*****                  ]  124 of 200 complete
#  [**********************63%*****                  ]  125 of 200 complete
#  [**********************63%*****                  ]  126 of 200 complete
#  [**********************64%******                 ]  127 of 200 complete
#  [**********************64%******                 ]  128 of 200 complete
#  [**********************65%******                 ]  129 of 200 complete
#  [**********************65%******                 ]  130 of 200 complete
#  [**********************66%*******                ]  131 of 200 complete
#  [**********************66%*******                ]  132 of 200 complete
#  [**********************67%*******                ]  133 of 200 complete
#  [**********************67%*******                ]  134 of 200 complete
#  [**********************68%********               ]  135 of 200 complete
#  [**********************68%********               ]  136 of 200 complete
#  [**********************69%********               ]  137 of 200 complete
#  [**********************69%********               ]  138 of 200 complete
#  [**********************70%*********              ]  139 of 200 complete
#  [**********************70%*********              ]  140 of 200 complete
#  [**********************71%*********              ]  141 of 200 complete
#  [**********************71%*********              ]  142 of 200 complete
#  [**********************72%**********             ]  143 of 200 complete
#  [**********************72%**********             ]  144 of 200 complete
#  [**********************73%**********             ]  145 of 200 complete
#  [**********************73%**********             ]  146 of 200 complete
#  [**********************74%***********            ]  147 of 200 complete
#  [**********************74%***********            ]  148 of 200 complete
#  [**********************75%***********            ]  149 of 200 complete
#  [**********************75%***********            ]  150 of 200 complete
#  [**********************76%***********            ]  151 of 200 complete
#  [**********************76%***********            ]  152 of 200 complete
#  [**********************77%************           ]  153 of 200 complete
#  [**********************77%************           ]  154 of 200 complete
#  [**********************78%************           ]  155 of 200 complete
#  [**********************78%************           ]  156 of 200 complete
#  [**********************79%*************          ]  157 of 200 complete
#  [**********************79%*************          ]  158 of 200 complete
#  [**********************80%*************          ]  159 of 200 complete
#  [**********************80%*************          ]  160 of 200 complete
#  [**********************81%**************         ]  161 of 200 complete
#  [**********************81%**************         ]  162 of 200 complete
#  [**********************82%**************         ]  163 of 200 complete
#  [**********************82%**************         ]  164 of 200 complete
#  [**********************83%***************        ]  165 of 200 complete
#  [**********************83%***************        ]  166 of 200 complete
#  [**********************84%***************        ]  167 of 200 complete
#  [**********************84%***************        ]  168 of 200 complete
#  [**********************85%****************       ]  169 of 200 complete
#  [**********************85%****************       ]  170 of 200 complete
#  [**********************86%****************       ]  171 of 200 complete
#  [**********************86%****************       ]  172 of 200 complete
#  [**********************87%*****************      ]  173 of 200 complete
#  [**********************87%*****************      ]  174 of 200 complete
#  [**********************88%*****************      ]  175 of 200 complete
#  [**********************88%*****************      ]  176 of 200 complete
#  [**********************89%******************     ]  177 of 200 complete
#  [**********************89%******************     ]  178 of 200 complete
#  [**********************90%******************     ]  179 of 200 complete
#  [**********************90%******************     ]  180 of 200 complete
#  [**********************91%*******************    ]  181 of 200 complete
#  [**********************91%*******************    ]  182 of 200 complete
#  [**********************92%*******************    ]  183 of 200 complete
#  [**********************92%*******************    ]  184 of 200 complete
#  [**********************93%********************   ]  185 of 200 complete
#  [**********************93%********************   ]  186 of 200 complete
#  [**********************94%********************   ]  187 of 200 complete
#  [**********************94%********************   ]  188 of 200 complete
#  [**********************95%*********************  ]  189 of 200 complete
#  [**********************95%*********************  ]  190 of 200 complete
#  [**********************96%*********************  ]  191 of 200 complete
#  [**********************96%*********************  ]  192 of 200 complete
#  [**********************97%********************** ]  193 of 200 complete
#  [**********************97%********************** ]  194 of 200 complete
#  [**********************98%********************** ]  195 of 200 complete
#  [**********************98%********************** ]  196 of 200 complete
#  [**********************99%***********************]  197 of 200 complete
#  [**********************99%***********************]  198 of 200 complete
#  [*********************100%***********************]  199 of 200 complete

# %%
y.shape
# Out:
# (174, 10)

# %%
CV = 'split'
boot = 50
ncomp = 40
nTP = 200
alphas = np.logspace(-2,8,20)

window = np.array([-1, 2])
[E,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='HG')
Es = [E[d] for d in tokens]
#elects = np.concatenate((np.where(anat=='preCG')[0],np.where(anat=='postCG')[0]))
elects = [21,25,35,37,43,53,55,58,59,67,72,73,86,90,102]
Kr2 = np.empty((Ks[0].shape[0],boot,nTP,len(alphas)))
Kr2null = np.empty((Ks[0].shape[0],boot,nTP,len(alphas)))

prog = ProgressBar(nTP)
for indt,t in enumerate(np.linspace(200,600,nTP)):
    erange = np.arange(t,t+4)   #Try playing with window size

    #Organize data into X and y
    X,y,yrnd = Ds2Xy(Es,Ks,dt1='HG',dt2='kin',ncomp = ncomp,erange = erange.astype(int),elects = elects,frange=np.arange(105,115),krange=np.arange(37,42))
    y= Khat[:,:,0,0]
    #Ridge regression
    for inda,a in enumerate(alphas):
        Kr2[:,:,indt,inda],coefs,yhat,score = Ridge_MLR(X, y, alpha = a, CV = CV, boot = boot)
        Kr2null[:,:,indt,inda],coefs,yhat,score = Ridge_MLR(X, yrnd, alpha = a, CV = CV, boot = boot)
    prog.animate(indt)
R2viz(Kr2,Kr2null,kfeats,b=True)
# Out:
# File found; Loading...
# Loaded
#  [                       0%                       ]
#  [                       1%                       ]  1 of 200 complete
#  [                       1%                       ]  2 of 200 complete
#  [*                      2%                       ]  3 of 200 complete
#  [*                      2%                       ]  4 of 200 complete
#  [*                      3%                       ]  5 of 200 complete
#  [*                      3%                       ]  6 of 200 complete
#  [**                     4%                       ]  7 of 200 complete
#  [**                     4%                       ]  8 of 200 complete
#  [**                     5%                       ]  9 of 200 complete
#  [**                     5%                       ]  10 of 200 complete
#  [***                    6%                       ]  11 of 200 complete
#  [***                    6%                       ]  12 of 200 complete
#  [***                    7%                       ]  13 of 200 complete
#  [***                    7%                       ]  14 of 200 complete
#  [****                   8%                       ]  15 of 200 complete
#  [****                   8%                       ]  16 of 200 complete
#  [****                   9%                       ]  17 of 200 complete
#  [****                   9%                       ]  18 of 200 complete
#  [*****                 10%                       ]  19 of 200 complete
#  [*****                 10%                       ]  20 of 200 complete
#  [*****                 11%                       ]  21 of 200 complete
#  [*****                 11%                       ]  22 of 200 complete
#  [******                12%                       ]  23 of 200 complete
#  [******                12%                       ]  24 of 200 complete
#  [******                13%                       ]  25 of 200 complete
#  [******                13%                       ]  26 of 200 complete
#  [*******               14%                       ]  27 of 200 complete
#  [*******               14%                       ]  28 of 200 complete
#  [*******               14%                       ]  29 of 200 complete
#  [*******               15%                       ]  30 of 200 complete
#  [********              16%                       ]  31 of 200 complete
#  [********              16%                       ]  32 of 200 complete
#  [********              17%                       ]  33 of 200 complete
#  [********              17%                       ]  34 of 200 complete
#  [*********             18%                       ]  35 of 200 complete
#  [*********             18%                       ]  36 of 200 complete
#  [*********             19%                       ]  37 of 200 complete
#  [*********             19%                       ]  38 of 200 complete
#  [**********            20%                       ]  39 of 200 complete
#  [**********            20%                       ]  40 of 200 complete
#  [**********            21%                       ]  41 of 200 complete
#  [**********            21%                       ]  42 of 200 complete
#  [***********           22%                       ]  43 of 200 complete
#  [***********           22%                       ]  44 of 200 complete
#  [***********           23%                       ]  45 of 200 complete
#  [***********           23%                       ]  46 of 200 complete
#  [************          24%                       ]  47 of 200 complete
#  [************          24%                       ]  48 of 200 complete
#  [************          25%                       ]  49 of 200 complete
#  [************          25%                       ]  50 of 200 complete
#  [************          26%                       ]  51 of 200 complete
#  [************          26%                       ]  52 of 200 complete
#  [*************         27%                       ]  53 of 200 complete
#  [*************         27%                       ]  54 of 200 complete
#  [*************         28%                       ]  55 of 200 complete
#  [*************         28%                       ]  56 of 200 complete
#  [*************         28%                       ]  57 of 200 complete
#  [**************        29%                       ]  58 of 200 complete
#  [**************        30%                       ]  59 of 200 complete
#  [**************        30%                       ]  60 of 200 complete
#  [***************       31%                       ]  61 of 200 complete
#  [***************       31%                       ]  62 of 200 complete
#  [***************       32%                       ]  63 of 200 complete
#  [***************       32%                       ]  64 of 200 complete
#  [****************      33%                       ]  65 of 200 complete
#  [****************      33%                       ]  66 of 200 complete
#  [****************      34%                       ]  67 of 200 complete
#  [****************      34%                       ]  68 of 200 complete
#  [*****************     35%                       ]  69 of 200 complete
#  [*****************     35%                       ]  70 of 200 complete
#  [*****************     36%                       ]  71 of 200 complete
#  [*****************     36%                       ]  72 of 200 complete
#  [******************    37%                       ]  73 of 200 complete
#  [******************    37%                       ]  74 of 200 complete
#  [******************    38%                       ]  75 of 200 complete
#  [******************    38%                       ]  76 of 200 complete
#  [*******************   39%                       ]  77 of 200 complete
#  [*******************   39%                       ]  78 of 200 complete
#  [*******************   40%                       ]  79 of 200 complete
#  [*******************   40%                       ]  80 of 200 complete
#  [********************  41%                       ]  81 of 200 complete
#  [********************  41%                       ]  82 of 200 complete
#  [********************  42%                       ]  83 of 200 complete
#  [********************  42%                       ]  84 of 200 complete
#  [********************* 43%                       ]  85 of 200 complete
#  [********************* 43%                       ]  86 of 200 complete
#  [********************* 44%                       ]  87 of 200 complete
#  [********************* 44%                       ]  88 of 200 complete
#  [**********************45%                       ]  89 of 200 complete
#  [**********************45%                       ]  90 of 200 complete
#  [**********************46%                       ]  91 of 200 complete
#  [**********************46%                       ]  92 of 200 complete
#  [**********************47%                       ]  93 of 200 complete
#  [**********************47%                       ]  94 of 200 complete
#  [**********************48%                       ]  95 of 200 complete
#  [**********************48%                       ]  96 of 200 complete
#  [**********************49%                       ]  97 of 200 complete
#  [**********************49%                       ]  98 of 200 complete
#  [**********************50%                       ]  99 of 200 complete
#  [**********************50%                       ]  100 of 200 complete
#  [**********************51%                       ]  101 of 200 complete
#  [**********************51%                       ]  102 of 200 complete
#  [**********************52%                       ]  103 of 200 complete
#  [**********************52%                       ]  104 of 200 complete
#  [**********************53%                       ]  105 of 200 complete
#  [**********************53%                       ]  106 of 200 complete
#  [**********************54%*                      ]  107 of 200 complete
#  [**********************54%*                      ]  108 of 200 complete
#  [**********************55%*                      ]  109 of 200 complete
#  [**********************55%*                      ]  110 of 200 complete
#  [**********************56%**                     ]  111 of 200 complete
#  [**********************56%**                     ]  112 of 200 complete
#  [**********************56%**                     ]  113 of 200 complete
#  [**********************57%**                     ]  114 of 200 complete
#  [**********************57%**                     ]  115 of 200 complete
#  [**********************58%***                    ]  116 of 200 complete
#  [**********************59%***                    ]  117 of 200 complete
#  [**********************59%***                    ]  118 of 200 complete
#  [**********************60%****                   ]  119 of 200 complete
#  [**********************60%****                   ]  120 of 200 complete
#  [**********************61%****                   ]  121 of 200 complete
#  [**********************61%****                   ]  122 of 200 complete
#  [**********************62%*****                  ]  123 of 200 complete
#  [**********************62%*****                  ]  124 of 200 complete
#  [**********************63%*****                  ]  125 of 200 complete
#  [**********************63%*****                  ]  126 of 200 complete
#  [**********************64%******                 ]  127 of 200 complete
#  [**********************64%******                 ]  128 of 200 complete
#  [**********************65%******                 ]  129 of 200 complete
#  [**********************65%******                 ]  130 of 200 complete
#  [**********************66%*******                ]  131 of 200 complete
#  [**********************66%*******                ]  132 of 200 complete
#  [**********************67%*******                ]  133 of 200 complete
#  [**********************67%*******                ]  134 of 200 complete
#  [**********************68%********               ]  135 of 200 complete
#  [**********************68%********               ]  136 of 200 complete
#  [**********************69%********               ]  137 of 200 complete
#  [**********************69%********               ]  138 of 200 complete
#  [**********************70%*********              ]  139 of 200 complete
#  [**********************70%*********              ]  140 of 200 complete
#  [**********************71%*********              ]  141 of 200 complete
#  [**********************71%*********              ]  142 of 200 complete
#  [**********************72%**********             ]  143 of 200 complete
#  [**********************72%**********             ]  144 of 200 complete
#  [**********************73%**********             ]  145 of 200 complete
#  [**********************73%**********             ]  146 of 200 complete
#  [**********************74%***********            ]  147 of 200 complete
#  [**********************74%***********            ]  148 of 200 complete
#  [**********************75%***********            ]  149 of 200 complete
#  [**********************75%***********            ]  150 of 200 complete
#  [**********************76%***********            ]  151 of 200 complete
#  [**********************76%***********            ]  152 of 200 complete
#  [**********************77%************           ]  153 of 200 complete
#  [**********************77%************           ]  154 of 200 complete
#  [**********************78%************           ]  155 of 200 complete
#  [**********************78%************           ]  156 of 200 complete
#  [**********************79%*************          ]  157 of 200 complete
#  [**********************79%*************          ]  158 of 200 complete
#  [**********************80%*************          ]  159 of 200 complete
#  [**********************80%*************          ]  160 of 200 complete
#  [**********************81%**************         ]  161 of 200 complete
#  [**********************81%**************         ]  162 of 200 complete
#  [**********************82%**************         ]  163 of 200 complete
#  [**********************82%**************         ]  164 of 200 complete
#  [**********************83%***************        ]  165 of 200 complete
#  [**********************83%***************        ]  166 of 200 complete
#  [**********************84%***************        ]  167 of 200 complete
#  [**********************84%***************        ]  168 of 200 complete
#  [**********************85%****************       ]  169 of 200 complete
#  [**********************85%****************       ]  170 of 200 complete
#  [**********************86%****************       ]  171 of 200 complete
#  [**********************86%****************       ]  172 of 200 complete
#  [**********************87%*****************      ]  173 of 200 complete
#  [**********************87%*****************      ]  174 of 200 complete
#  [**********************88%*****************      ]  175 of 200 complete
#  [**********************88%*****************      ]  176 of 200 complete
#  [**********************89%******************     ]  177 of 200 complete
#  [**********************89%******************     ]  178 of 200 complete
#  [**********************90%******************     ]  179 of 200 complete
#  [**********************90%******************     ]  180 of 200 complete
#  [**********************91%*******************    ]  181 of 200 complete
#  [**********************91%*******************    ]  182 of 200 complete
#  [**********************92%*******************    ]  183 of 200 complete
#  [**********************92%*******************    ]  184 of 200 complete
#  [**********************93%********************   ]  185 of 200 complete
#  [**********************93%********************   ]  186 of 200 complete
#  [**********************94%********************   ]  187 of 200 complete
#  [**********************94%********************   ]  188 of 200 complete
#  [**********************95%*********************  ]  189 of 200 complete
#  [**********************95%*********************  ]  190 of 200 complete
#  [**********************96%*********************  ]  191 of 200 complete
#  [**********************96%*********************  ]  192 of 200 complete
#  [**********************97%********************** ]  193 of 200 complete
#  [**********************97%********************** ]  194 of 200 complete
#  [**********************98%********************** ]  195 of 200 complete
#  [**********************98%********************** ]  196 of 200 complete
#  [**********************99%***********************]  197 of 200 complete
#  [**********************99%***********************]  198 of 200 complete
#  [*********************100%***********************]  199 of 200 complete

# %%
CV = 'split'
boot = 50
ncomp = 40
nTP = 200
alphas = np.logspace(-2,8,20)

window = np.array([-1, 2])
[E,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='HG')
Es = [E[d] for d in tokens]
#elects = np.concatenate((np.where(anat=='preCG')[0],np.where(anat=='postCG')[0]))
elects = [21,25,35,37,43,53,55,58,59,67,72,73,86,90,102]
Kr2 = np.empty((Kt[0].shape[0],boot,nTP,len(alphas)))
Kr2null = np.empty((Kt[0].shape[0],boot,nTP,len(alphas)))

prog = ProgressBar(nTP)
for indt,t in enumerate(np.linspace(200,600,nTP)):
    erange = np.arange(t,t+4)   #Try playing with window size

    #Organize data into X and y
    X,y,yrnd = Ds2Xy(Es,Ks,dt1='HG',dt2='kin',ncomp = ncomp,erange = erange.astype(int),elects = elects,frange=np.arange(105,115),krange=np.arange(37,42))
    y= Ktilde[:,:,0,0]
    #Ridge regression
    for inda,a in enumerate(alphas):
        Kr2[:,:,indt,inda],coefs,yhat,score = Ridge_MLR(X, y, alpha = a, CV = CV, boot = boot)
        Kr2null[:,:,indt,inda],coefs,yhat,score = Ridge_MLR(X, yrnd, alpha = a, CV = CV, boot = boot)
    prog.animate(indt)
R2viz(Kr2,Kr2null,kfeats,b=True)
# Out:
# File found; Loading...
# Loaded
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-c0f4a4fe00ae> in <module>()
#      10 #elects = np.concatenate((np.where(anat=='preCG')[0],np.where(anat=='postCG')[0]))
#      11 elects = [21,25,35,37,43,53,55,58,59,67,72,73,86,90,102]
# ---> 12 Kr2 = np.empty((Kt[0].shape[0],boot,nTP,len(alphas)))
#      13 Kr2null = np.empty((Kt[0].shape[0],boot,nTP,len(alphas)))
#      14
#
# NameError: name 'Kt' is not defined
