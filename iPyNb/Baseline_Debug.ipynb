# %%
#Intitialize
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from __future__ import division
import sys
import ecog_viz as ev
import numpy as np
import seaborn as sns
from brain_utils import brainBaseline_silence
from brain_utils import brainBaseline_whole
sys.path.append("/Users/david_conant/Dropbox/changrepo/python/brain")
from brain.dataformat.brainformat import *
from IPython.display import Image
sns.set_style('dark')
sns.set_context('talk')
#Load Data
pth = '/Users/david_conant/Dropbox/EC56/EC56.prod.hVd.B75_77.align1_2.neural.h5'
f = BrainDataFile(pth , 'r')
i = f.data().internal()
e = i.ecog_data_processed(0)
e_z = brainBaseline_silence(e)
notes = np.array(e.dims(axis = 'channels', get_hdf = False)[1]['dataset'])
filt = np.where(notes == 'WHOOD')
b_yes = e_z[:,0:400,filt[0]]
b_no = e.ecog_data()[:,0:400,filt[0]]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
b_yes = reshape(e_z[91,0:400,101:110],[1,400,9])
b_no = reshape(e.ecog_data()[91,0:400,101:110],[1,400,9])

# %%
sns.tsplot(b_yes[:,:,1],err_style='unit_traces')

# %%
sns.tsplot(b_no[:,:,1],err_style='unit_traces')

# %%
b_yes[1,:,:].shape
# Out:
# (400, 20)

# %%
e_z[91,0:400,1:10].shape
# Out:
# (400, 9)

# %%
#Load Data
pth = '/Users/david_conant/Dropbox/EC56/EC56.prod.hVd.B75_77.align1_2.neural.h5'
f = BrainDataFile(pth , 'r')
i = f.data().internal()
e = i.ecog_data_processed(0)
e_z = brainBaseline_whole(e)
notes = np.array(e.dims(axis = 'channels', get_hdf = False)[1]['dataset'])
filt = np.where(notes == 'WHOOD')
b_yes = reshape(e_z[91,0:400,101:110],[1,400,9])
b_no = reshape(e.ecog_data()[91,0:400,101:110],[1,400,9])

# %%
block=np.array(e.dims(axis = 'channels', get_hdf = False)[5]['dataset'])

# %%
np.unique(block).shape
# Out:
# (2,)

# %%
e.ecog_data()[:,:,block ==np.unique(block)[0]].shape
# Out:
# (256, 657, 107)

# %%
#Intitialize
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from __future__ import division
import sys
import ecog_viz as ev
import numpy as np
import seaborn as sns
from brain_utils import brainBaseline
sys.path.append("/Users/david_conant/Dropbox/changrepo/python/brain")
from brain.dataformat.brainformat import *
from IPython.display import Image
sns.set_style('dark')
sns.set_context('talk')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pth = '/Users/david_conant/Dropbox/EC41/EC41.prod.hVd.B19_20_22_27.align1_2.neural.h5'
f = BrainDataFile(pth , 'r')
i = f.data().internal()
e = i.ecog_data_processed(0)

# %%
baseline_mu = np.array(e.dims(axis = 'channels', get_hdf = False)[7]['dataset'])
baseline_std = np.array(e.dims(axis = 'channels', get_hdf = False)[6]['dataset'])

m = np.swapaxes(np.tile(baseline_mu,(e.ecog_data().shape[1],1,1)),0,1).transpose()
s = np.reshape(np.tile(baseline_std,(e.ecog_data().shape[1],1,1)),e.ecog_data().shape, order = 'F')

e_z = np.divide((e.ecog_data() - m),s)

# %%
baseline_mu.shape
# Out:
# (173, 256)

# %%
plot(baseline_mu[:,1])

# %%
m.shape
# Out:
# (256, 635, 173)

# %%
plot(m[:,1,1])

# %%
a = np.tile(baseline_mu,(e.ecog_data().shape[1],1,1))
a.shape
# Out:
# (635, 173, 256)

# %%
new = np.swapaxes(a,0,1).transpose()
new.shape
# Out:
# (256, 635, 173)

# %%
plot(new[:,1,1])
