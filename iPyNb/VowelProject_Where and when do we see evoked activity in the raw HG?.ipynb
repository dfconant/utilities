# %% [markdown]
# ###Where and when do we see evoked activity in the raw HG?

# %% [markdown]
# We've recorded several patients on a task where they speak a range of vowels in an hVd and isolated context. First question, looking at the HG data directly, do we see activity on electrodes evoked by vowel production?

# %%
#Intitialize
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from __future__ import division
import sys
import ecog_viz as ev
import numpy as np
import seaborn as sns
import pandas as pd
from brain_utils import brainBaseline
from brain.dataformat.brainformat import *
from IPython.display import Image
from ECoGstats import run_makeD, makeD_multi
sns.set_style('dark')

# %%
'''
from parseTranscripts import parseTextGrid
import os.path
import cPickle as pickle
def makeD_multi (pth,blocks,tokens,align_window = np.array([-1,1])):
    subject = pth.split("/")[-2]
    fname = pth + subject + str(blocks) + str(tokens) + '.p'

    if not os.path.isfile(fname): 

        D = dict((el,np.array([])) for el in tokens)
        mean_D = dict((el,np.array([])) for el in tokens)
        for iblock, block in enumerate(blocks):
            print 'Processing block ' + str(block)
            blockname = subject + '_B' + str(block)
            blockpath = pth + blockname + '/'
            #####
            #convert parseout to dataframe
            textgrid_path = blockpath + blockname + '_transcription_final.TextGrid'
            parseout = parseTextGrid(textgrid_path)
            datamat = [parseout[key] for key in parseout.keys()]
            df = pd.DataFrame(np.vstack(datamat).T,columns=parseout.keys())
            df = df[df['tier'] == 'word']

            # get rid of superfluous columns
            df = df[['label','start', 'stop']]

            # fix common transcription error
            #df['label'][df['label'] == 'EE1'] = 'IY1'
            #df['label'][df['label'] == 'EE2'] = 'IY2'

            # pull mode from label and get rid of number
            df['mode'] = ['speak' if l[-1] == '2' else 'listen' for l in df['label']]
            df['label'] = df['label'].apply(lambda x: x[:-1]) 

            df['label'] = df['label'].astype('category')
            df['mode'] = df['mode'].astype('category')

            df['mid_times'] = (df['start'] + df['stop'])/2

            #df['order'] = mod(range(df.shape[0]),5) + 1
            df['block'] = block
            df['subject'] = subject

            df.to_pickle(blockpath + 'event_df')
            #####

            for this_label in tokens:
                event_times = df['start'][(df['label'] == this_label) & (df['mode'] == 'speak')]
                D[this_label] = np.dstack((D[this_label],run_makeD(blockpath,event_times,
                        align_window))) if D[this_label].size else run_makeD(blockpath,event_times,align_window)
                mean_D[this_label] = np.vstack((mean_D[this_label],np.transpose(np.nanmean(np.log(D[this_label]),
                        axis=1)))) if mean_D[this_label].size else np.transpose(np.nanmean(np.log(D[this_label]),axis=1))

        #pickle.dump(D,open(fname,'wb'))

    else:
        print 'File found; Loading...'
        D = pickle.load( open(fname,'rb'))
        print 'Loaded'

    anat = ev.load_anatomy(pth)
    return(D, anat)
'''
# Out:
# '\nfrom parseTranscripts import parseTextGrid\nimport os.path\nimport cPickle as pickle\ndef makeD_multi (pth,blocks,tokens,align_window = np.array([-1,1])):\n    subject = pth.split("/")[-2]\n    fname = pth + subject + str(blocks) + str(tokens) + \'.p\'\n\n    if not os.path.isfile(fname): \n\n        D = dict((el,np.array([])) for el in tokens)\n        mean_D = dict((el,np.array([])) for el in tokens)\n        for iblock, block in enumerate(blocks):\n            print \'Processing block \' + str(block)\n            blockname = subject + \'_B\' + str(block)\n            blockpath = pth + blockname + \'/\'\n            #####\n            #convert parseout to dataframe\n            textgrid_path = blockpath + blockname + \'_transcription_final.TextGrid\'\n            parseout = parseTextGrid(textgrid_path)\n            datamat = [parseout[key] for key in parseout.keys()]\n            df = pd.DataFrame(np.vstack(datamat).T,columns=parseout.keys())\n            df = df[df[\'tier\'] ==
# ...

# %%
pth = '/Users/david_conant/Documents/EC41/'
blocks = [19,20,22,27]
tokens = ['ALL','AAA','AEE','AHH','EHH','ERR','IHH','IYY','UHH','UWW']
#tokens = ['HAWED','HAD','HUD','HEAD','HEARD','HID','HEED','HOOD','WHOOD']
[D,anat] = makeD_multi(pth,blocks,tokens)
Ds = [D[d] for d in tokens]
Dall = np.concatenate(Ds,axis=2)
fig_filename = '/Users/david_conant/Dropbox/NeuroSpeech/Lab Meetings/Vowels1/EC41_ERPs_all.png'
ax = ev.plotERPs([Dall],align_window = np.array([-1,1]), anatomy = anat,labels = tokens, fig_filename = fig_filename)
# Out:
# Processing block 19
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-5064af547410> in <module>()
#       3 tokens = ['ALL','AAA','AEE','AHH','EHH','ERR','IHH','IYY','UHH','UWW']
#       4 #tokens = ['HAWED','HAD','HUD','HEAD','HEARD','HID','HEED','HOOD','WHOOD']
# ----> 5 [D,anat] = makeD_multi(pth,blocks,tokens)
#       6 Ds = [D[d] for d in tokens]
#       7 Dall = np.concatenate(Ds,axis=2)
#
# /Users/david_conant/Dropbox/changrepo/python/datautils/ECoGstats.pyc in makeD_multi(pth, blocks, tokens, align_window, dtype)
#     358                 start_times[this_label] = np.hstack((start_times[this_label],start.astype(float))) if start_times[this_label].size else start.astype(float)
#     359                 D[this_label] = np.dstack((D[this_label],run_makeD(blockpath,event_times,
# ...

# %%
pth = '/Users/david_conant/Documents/EC41/'
blocks = [19,20,22,27]
tokens = ['AAA','AEE','AHH','EHH','ERR','IHH','IYY','UHH','UWW']
#tokens = ['HAWED','HAD','HUD','HEAD','HEARD','HID','HEED','HOOD','WHOOD']
window = np.array([-1,1])
[D,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='HG')
Ds = [D[d] for d in tokens]
Dall = np.concatenate(Ds,axis=2)
fig_filename = '/Users/david_conant/Dropbox/NeuroSpeech/Lab Meetings/Vowels1/EC41_ERPs_all.png'
ax = ev.plotERPs([Dall],align_window = np.array([-1,1]), anatomy = anat,labels = tokens, fig_filename=fig_filename)
# Out:
# File found; Loading...
# Loaded
#  [                       0%                       ]
#  [                       1%                       ]  2 of 256 complete
#  [                       1%                       ]  3 of 256 complete
#  [*                      2%                       ]  4 of 256 complete
#  [*                      2%                       ]  5 of 256 complete
#  [*                      2%                       ]  6 of 256 complete
#  [*                      3%                       ]  7 of 256 complete
#  [*                      3%                       ]  8 of 256 complete
#  [**                     4%                       ]  9 of 256 complete
#  [**                     4%                       ]  10 of 256 complete
#  [**                     4%                       ]  11 of 256 complete
#  [**                     5%                       ]  12 of 256 complete
#  [**                     5%                       ]  13 of 256 complete
# ...

# %% [markdown]
# To orient you, the background colors denote the anatomy: purple is precentral, blue is postcentral, orange is STG, and green is other. Front of the brain is to the right. The data shown is for the isolated context, aligned to the onset of the vowel, with 1 sec before and 1 sec after.
#
# We can see robust activation locked to onset of the vowel from several electrodes primarily in ventral and dorsal precentral gyrus, ventral postcentral, as well as a few more anterior electrodes (~broca's).

# %%
pth = '/Users/david_conant/Documents/EC50/'
blocks = [21,22,25,76]
tokens = ['AAA','AEE','AHH','EHH','ERR','IHH','IYY','UHH','UWW']

window = np.array([-1,1])
[D,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='HG')
Ds = [D[d] for d in tokens]
Dall = np.concatenate(Ds,axis=2)
fig_filename = '/Users/david_conant/Dropbox/NeuroSpeech/Lab Meetings/Vowels1/EC50_ERPs_all.png'
ax = ev.plotERPs([Dall],align_window = np.array([-1,1]), anatomy = anat,labels = tokens, fig_filename=fig_filename)
# Out:
# File found; Loading...
# Loaded
#  [                       0%                       ]
#  [                       1%                       ]  2 of 256 complete
#  [                       1%                       ]  3 of 256 complete
#  [*                      2%                       ]  4 of 256 complete
#  [*                      2%                       ]  5 of 256 complete
#  [*                      2%                       ]  6 of 256 complete
#  [*                      3%                       ]  7 of 256 complete
#  [*                      3%                       ]  8 of 256 complete
#  [**                     4%                       ]  9 of 256 complete
#  [**                     4%                       ]  10 of 256 complete
#  [**                     4%                       ]  11 of 256 complete
#  [**                     5%                       ]  12 of 256 complete
#  [**                     5%                       ]  13 of 256 complete
# ...

# %% [markdown]
# EC50 doesn't show the same dorsal/ventral split, active electrodes are more evenly spaced across the vSMC. But still, robust activation within vSMC around acoustic onset.

# %%
pth = '/Users/david_conant/Documents/EC56/'
blocks = [75,77]
tokens = ['AAA','AEE','AHH','EHH','ERR','IHH','IYY','UHH','UWW']

window = np.array([-1,1])
[D,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='HG')
Ds = [D[d] for d in tokens]
Dall = np.concatenate(Ds,axis=2)
fig_filename = '/Users/david_conant/Dropbox/NeuroSpeech/Lab Meetings/Vowels1/EC56_ERPs_all.png'
ax = ev.plotERPs([Dall],align_window = np.array([-1,1]), anatomy = anat,labels = tokens, fig_filename=fig_filename)
# Out:
# File found; Loading...
# Loaded
#  [                       0%                       ]
#  [                       1%                       ]  2 of 256 complete
#  [                       1%                       ]  3 of 256 complete
#  [*                      2%                       ]  4 of 256 complete
#  [*                      2%                       ]  5 of 256 complete
#  [*                      2%                       ]  6 of 256 complete
#  [*                      3%                       ]  7 of 256 complete
#  [*                      3%                       ]  8 of 256 complete
#  [**                     4%                       ]  9 of 256 complete
#  [**                     4%                       ]  10 of 256 complete
#  [**                     4%                       ]  11 of 256 complete
#  [**                     5%                       ]  12 of 256 complete
#  [**                     5%                       ]  13 of 256 complete
# ...

# %% [markdown]
# EC56 has sparser active electrodes, and exhibits the same dorsal/ventral split as EC50. There are also a couple rather posterior electrodes (181,182,166,186) that have motor-like responses.

# %%
pth = '/Users/david_conant/Documents/EC82/'
blocks = [19,21,38,40,44]
tokens = ['AAA','AEE','AHH','EHH','ERR','IHH','IYY','UHH','UWW']
#tokens = ['HAWED','HAD','HUD','HEAD','HEARD','HID','HEED','HOOD','WHOOD']

window = np.array([-1,1])
[D,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='HG')
Ds = [D[d] for d in tokens]
Dall = np.concatenate(Ds,axis=2)
Dall = np.delete(Dall,89,2)
fig_filename = '/Users/david_conant/Dropbox/NeuroSpeech/Lab Meetings/Vowels1/EC82_ERPs_all.png'
ax = ev.plotERPs([Dall],align_window = np.array([-1,1]), anatomy = anat,labels = tokens, fig_filename=fig_filename)
# Out:
# File found; Loading...
# Loaded
#  [                       0%                       ]
#  [                       1%                       ]  2 of 256 complete
#  [                       1%                       ]  3 of 256 complete
#  [*                      2%                       ]  4 of 256 complete
#  [*                      2%                       ]  5 of 256 complete
#  [*                      2%                       ]  6 of 256 complete
#  [*                      3%                       ]  7 of 256 complete
#  [*                      3%                       ]  8 of 256 complete
#  [**                     4%                       ]  9 of 256 complete
#  [**                     4%                       ]  10 of 256 complete
#  [**                     4%                       ]  11 of 256 complete
#  [**                     5%                       ]  12 of 256 complete
#  [**                     5%                       ]  13 of 256 complete
# ...

# %% [markdown]
# EC82 is a little messy. He had a lot of artifacts, and therefore many trials got rejected, leaving him with not so many (~10/vowel). Evenso, he also has plenty of active electrodes in vSMC with reasonable dynamics. 111 and 137 are interesting, as they show activity either entirely before or after the acoustic onset. Not typical for a motor execution response.

# %%
pth = '/Users/david_conant/Documents/EC84/'
blocks = [65,78,82,85,93,95]
tokens = ['AAA','AEE','AHH','EHH','ERR','IHH','IYY','UHH','UWW']

window = np.array([-1,1])
[D,anat,stop_times,start_times] = makeD_multi(pth,blocks,tokens,align_window = window, dtype='HG')
Ds = [D[d] for d in tokens]
Dall = np.concatenate(Ds,axis=2)
fig_filename = '/Users/david_conant/Dropbox/NeuroSpeech/Lab Meetings/Vowels1/EC84_ERPs_all.png'
ax = ev.plotERPs([Dall],align_window = np.array([-1,1]), anatomy = anat,labels = tokens, fig_filename=fig_filename)
# Out:
# File found; Loading...
# Loaded
#  [                       0%                       ]
#  [                       1%                       ]  2 of 256 complete
#  [                       1%                       ]  3 of 256 complete
#  [*                      2%                       ]  4 of 256 complete
#  [*                      2%                       ]  5 of 256 complete
#  [*                      2%                       ]  6 of 256 complete
#  [*                      3%                       ]  7 of 256 complete
#  [*                      3%                       ]  8 of 256 complete
#  [**                     4%                       ]  9 of 256 complete
#  [**                     4%                       ]  10 of 256 complete
#  [**                     4%                       ]  11 of 256 complete
#  [**                     5%                       ]  12 of 256 complete
#  [**                     5%                       ]  13 of 256 complete
# ...

# %% [markdown]
# EC84 had excellent motor coverage, and we see reponses all the way up, where you would expect hand/arms to be represented. This is curious, but Ben also identified this region as significantly modulated during his pitch tasks. In that light, he also exhibits the ventral/dorsal split of activity.

# %% [markdown]
# Conclusions:
#
#     -All subjects show numerous electrodes in vSMC modulated by vowel production
#     -3 of 5 subjects have a bimodal distribution in which electrodes in dorsal and ventral vSMC are active, but not inbetween. This is curious as it isn't in line with Kris's somatotopy of vSMC. That middle region is where the tongue should be.

# %% [markdown]
# Future Directions:
#
#     -Try the brain warping techniques developed by Liberty and Matt to get a more precise description of cross-subject variability.
#     -Instead of ERPs, a more insightful analysis would be to build encoding/decoding models of kinematics within vSMC. This will give us a much better idea of what aspect of the movement this activity is related to.
