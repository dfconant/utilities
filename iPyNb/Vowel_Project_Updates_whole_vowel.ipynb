# %% [markdown]
# ##Update - 5/18/15

# %% [markdown]
# Correcting All Vowel ERPs bug
# --
# First, I fixed the error that was causing 'HOOD' to show such high activity. It turned out to be a bug in how I was using the BRAIN format data annotations. Replotting the All Vowel ERPs:

# %%
#Intitialize
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from __future__ import division
import sys
import ecog_viz as ev
import numpy as np
import seaborn as sns
from brain_utils import brainBaseline
sys.path.append("/Users/david_conant/Dropbox/changrepo/python/brain")
from brain.dataformat.brainformat import *
from IPython.display import Image
sns.set_style('dark')

# %%
#Load Data
pth = '/Users/david_conant/Dropbox/EC56/EC56.prod.vow.B75_77.align1_1.neural.h5'
f = BrainDataFile(pth , 'r')
i = f.data().internal()
e = i.ecog_data_processed(0)
e_z = brainBaseline(e)
notes = np.array(e.dims(axis = 'channels', get_hdf = False)[1]['dataset'])
anat = np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset'])
#Slice data
vow = np.unique(np.array(e.dims(axis = 'channels', get_hdf = False)[1]['dataset']))
Ds = [];
for v in vow:
    filt = np.where(notes == v)
    anno_data = e.ecog_data()[:,:,filt[0]]
    Ds.append(anno_data[:,0:400,:])

# %%
ev.plotERPs(Ds,align_window = np.array([-1,1]),anatomy=anat,labels = vow, yscale = [0.25,5])
# Out:
#  [                       0%                       ]
#  [                       1%                       ]  2 of 256 complete
#  [                       1%                       ]  3 of 256 complete
#  [*                      2%                       ]  4 of 256 complete
#  [*                      2%                       ]  5 of 256 complete
#  [*                      2%                       ]  6 of 256 complete
#  [*                      3%                       ]  7 of 256 complete
#  [*                      3%                       ]  8 of 256 complete
#  [**                     4%                       ]  9 of 256 complete
#  [**                     4%                       ]  10 of 256 complete
#  [**                     4%                       ]  11 of 256 complete
#  [**                     5%                       ]  12 of 256 complete
#  [**                     5%                       ]  13 of 256 complete
# ...

# %%
ev.plotERPs(Ds,align_window = np.array([-1,1]),anatomy=anat,labels = vow, yscale = [0.25,3],elects = [74])
# Out:
#  [                       0%                       ]

# %%
#Load Data
pth = '/Users/david_conant/Dropbox/EC56/EC56.prod.vow.B75_77.align1_1.neural.h5'
f = BrainDataFile(pth , 'r')
i = f.data().internal()
e = i.ecog_data_processed(0)
e_z = brainBaseline(e)
notes = np.array(e.dims(axis = 'channels', get_hdf = False)[1]['dataset'])
anat = np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset']);
#Slice data
vow = np.unique(np.array(e.dims(axis = 'channels', get_hdf = False)[1]['dataset']))
Ds = [];
for v in vow:
    filt = np.where(notes == v)
    anno_data = e.ecog_data()[:,:,filt[0]]
    Ds.append(anno_data[:,0:400,:]) 
ev.plotERPs(Ds,align_window = np.array([-1,1]),anatomy=anat,labels = vow, yscale = [0.25,5])
# Out:
#  [                       0%                       ]
#  [                       1%                       ]  2 of 256 complete
#  [                       1%                       ]  3 of 256 complete
#  [*                      2%                       ]  4 of 256 complete
#  [*                      2%                       ]  5 of 256 complete
#  [*                      2%                       ]  6 of 256 complete
#  [*                      3%                       ]  7 of 256 complete
#  [*                      3%                       ]  8 of 256 complete
#  [**                     4%                       ]  9 of 256 complete
#  [**                     4%                       ]  10 of 256 complete
#  [**                     4%                       ]  11 of 256 complete
#  [**                     5%                       ]  12 of 256 complete
#  [**                     5%                       ]  13 of 256 complete
# ...

# %%
ev.plotERPs(Ds,align_window = np.array([-1,1]),anatomy=anat,labels = vow, yscale = [0.25,5],elects = [91])
# Out:
#  [                       0%                       ]

# %%
#Load Data
pth = '/Users/david_conant/Dropbox/EC41/EC41.prod.vow.B19_20_22_27.align1_1.neural.h5'
f = BrainDataFile(pth , 'r')
i = f.data().internal()
e = i.ecog_data_processed(0)
e_z = brainBaseline(e)
notes = np.array(e.dims(axis = 'channels', get_hdf = False)[1]['dataset'])
anat = np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset']);
#Slice data
vow = np.unique(np.array(e.dims(axis = 'channels', get_hdf = False)[1]['dataset']))
Ds = [];
for v in vow:
    filt = np.where(notes == v)
    anno_data = e.ecog_data()[:,:,filt[0]]
    Ds.append(anno_data[:,0:400,:])

# %%
ev.plotERPs(Ds,align_window = np.array([-1,1]),anatomy=anat,labels = vow, yscale = [0.25,5])
# Out:
#  [                       0%                       ]
#  [                       1%                       ]  2 of 256 complete
#  [                       1%                       ]  3 of 256 complete
#  [*                      2%                       ]  4 of 256 complete
#  [*                      2%                       ]  5 of 256 complete
#  [*                      2%                       ]  6 of 256 complete
#  [*                      3%                       ]  7 of 256 complete
#  [*                      3%                       ]  8 of 256 complete
#  [**                     4%                       ]  9 of 256 complete
#  [**                     4%                       ]  10 of 256 complete
#  [**                     4%                       ]  11 of 256 complete
#  [**                     5%                       ]  12 of 256 complete
#  [**                     5%                       ]  13 of 256 complete
# ...

# %%
#Load Data
pth = '/Users/david_conant/Dropbox/EC50/EC50.prod.vow.B21_22_25_76.align1_1.neural.h5'
f = BrainDataFile(pth , 'r')
i = f.data().internal()
e = i.ecog_data_processed(0)
e_z = brainBaseline(e)
notes = np.array(e.dims(axis = 'channels', get_hdf = False)[1]['dataset'])
anat = np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset']);
#Slice data
vow = np.unique(np.array(e.dims(axis = 'channels', get_hdf = False)[1]['dataset']))
Ds = [];
for v in vow:
    filt = np.where(notes == v)
    anno_data = e.ecog_data()[:,:,filt[0]]
    Ds.append(anno_data[:,0:400,:])

# %%
ev.plotERPs(Ds,align_window = np.array([-1,1]), anatomy = anat, labels = vow, yscale = [-0.5,7])
# Out:
#  [                       0%                       ]
#  [                       1%                       ]  2 of 256 complete
#  [                       1%                       ]  3 of 256 complete
#  [*                      2%                       ]  4 of 256 complete
#  [*                      2%                       ]  5 of 256 complete
#  [*                      2%                       ]  6 of 256 complete
#  [*                      3%                       ]  7 of 256 complete
#  [*                      3%                       ]  8 of 256 complete
#  [**                     4%                       ]  9 of 256 complete
#  [**                     4%                       ]  10 of 256 complete
#  [**                     4%                       ]  11 of 256 complete
#  [**                     5%                       ]  12 of 256 complete
#  [**                     5%                       ]  13 of 256 complete
# ...

# %%
#Load Data
pth = '/Users/david_conant/Dropbox/EC82/EC82.prod.vow.B21_38_40_44.align1_1.neural.h5'
f = BrainDataFile(pth , 'r')
i = f.data().internal()
e = i.ecog_data_processed(0)
e_z = brainBaseline(e)
notes = np.array(e.dims(axis = 'channels', get_hdf = False)[1]['dataset'])
anat = np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset']);
#Slice data
vow = np.unique(np.array(e.dims(axis = 'channels', get_hdf = False)[1]['dataset']))
Ds = [];
for v in vow:
    filt = np.where(notes == v)
    anno_data = e.ecog_data()[:,:,filt[0]]
    Ds.append(anno_data[:,0:400,:])

# %%
ev.plotERPs(Ds,align_window = np.array([-1,1]),anatomy=anat,labels = vow, yscale = [-.5,1])
# Out:
#  [                       0%                       ]
#  [                       1%                       ]  2 of 256 complete
#  [                       1%                       ]  3 of 256 complete
#  [*                      2%                       ]  4 of 256 complete
#  [*                      2%                       ]  5 of 256 complete
#  [*                      2%                       ]  6 of 256 complete
#  [*                      3%                       ]  7 of 256 complete
#  [*                      3%                       ]  8 of 256 complete
#  [**                     4%                       ]  9 of 256 complete
#  [**                     4%                       ]  10 of 256 complete
#  [**                     4%                       ]  11 of 256 complete
#  [**                     5%                       ]  12 of 256 complete
#  [**                     5%                       ]  13 of 256 complete
# ...

# %% [markdown]
# ERPs for EC84
# --
#
# Preprocessed EC84 and ran previous ERP analyses on it

# %%
#Intitialize
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from __future__ import division
import sys
import ecog_viz as ev
import numpy as np
from brain_utils import brainBaseline
from brain.dataformat.brainformat import *
from IPython.display import Image
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
Image(filename = '/Users/david_conant/Dropbox/NeuroSpeech/ChangLab/General Patient Info/EC84/brain+grid_3Drecon.jpg')

# %%
pth = '/Users/david_conant/Dropbox/EC84/EC84.prod.vow.B65_78_82_85_93_95.align1_1.neural.h5'
f = BrainDataFile(pth , 'r')
i = f.data().internal()
e = i.ecog_data_processed(0)
e_z = brainBaseline(e)
ev.plotERPs([np.array(e_z[:,0:400,:])],align_window = np.array([-1,1]),anatomy=np.array(e.dims(axis = 'space', 
    get_hdf = False)[2]['dataset']),fig_filename = '/Users/david_conant/Dropbox/EC84/EC84_AllERPs.png')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-cc2a6e299b50> in <module>()
#       5 e_z = brainBaseline(e)
#       6 ev.plotERPs([np.array(e_z[:,0:400,:])],align_window = np.array([-1,1]),anatomy=np.array(e.dims(axis = 'space',
# ----> 7     get_hdf = False)[2]['dataset']),fig_filename = '/Users/david_conant/Dropbox/EC84/EC84_AllERPs.png')
#
# IndexError: list index out of range

# %%
#Load data
pth = '/Users/david_conant/Dropbox/EC84/EC84.prod.vow.B65_78_82_85_93_95.align1_1.neural.h5'
f = BrainDataFile(pth , 'r')
i = f.data().internal()
e = i.ecog_data_processed(0)
e_z = brainBaseline(e)
notes = np.array(e.dims(axis = 'channels', get_hdf = False)[1]['dataset'])
anat = np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset'])
#Slice data
vow = ['HAWED','HEED','WHOOD']
Ds = [];
for v in vow:
    filt = np.where(notes == v)
    anno_data = e_z[:,:,filt[0]]
    Ds.append(anno_data[:,0:400,:])

# %%
ax = ev.plotERPs(Ds,align_window = np.array([-1,1]),anatomy=anat,labels = vow)

# %%
#Load Data
pth = '/Users/david_conant/Dropbox/EC84/EC84.prod.vow.B65_78_82_85_93_95.align1_1.neural.h5'
f = BrainDataFile(pth , 'r')
i = f.data().internal()
e = i.ecog_data_processed(0)
e_z = brainBaseline(e)
notes = np.array(e.dims(axis = 'channels', get_hdf = False)[1]['dataset'])
anat = np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset'])
#Slice data
vow = np.unique(np.array(e.dims(axis = 'channels', get_hdf = False)[1]['dataset']))
Ds = [];
for v in vow:
    filt = np.where(notes == v)
    anno_data = e_z[:,:,filt[0]]
    Ds.append(anno_data[:,0:400,:])

# %%
ev.plotERPs(Ds,align_window = np.array([-1,1]),anatomy=anat,labels = vow)

# %% [markdown]
# ____________

# %% [markdown]
# ##Update - 5/11/15

# %% [markdown]
# ERPs for EC82
# --
#
# Preprocessed EC82 and ran previous ERP analyses on it

# %%
#Intitialize
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from __future__ import division
import sys
import ecog_viz as ev
import numpy as np
from brain_utils import brainBaseline
from brain.dataformat.brainformat import *
from IPython.display import Image

# %%
Image(filename = '/Users/david_conant/Dropbox/NeuroSpeech/ChangLab/General Patient Info/EC82/brain+grid_3Drecon.jpg')

# %%
pth = '/Users/david_conant/Dropbox/EC82/EC82.prod.hVd.B21_38_40_44.align1_2.neural.h5'
f = BrainDataFile(pth , 'r')
i = f.data().internal()
e = i.ecog_data_processed(0)
e_z = brainBaseline(e)
ev.plotERPs([np.array(e_z[:,0:400,:])],align_window = np.array([-1,1]),anatomy=np.array(e.dims(axis = 'space', 
    get_hdf = False)[2]['dataset']),fig_filename = '/Users/david_conant/Dropbox/EC82/EC82_AllERPs.png')

# %% [markdown]
# Rather strange, he has several electrodes in the pre and post-central gyrus that have peak activation sometime after the onset of the vowel. Some have about the right timing to be related to word offset, others are peaking right in the middle of the vowel. Meanwhile there is a focus of electrodes in the anterior pre-central gyrus that peak around the right time to be related to word onset, but they start ramping up well before the word onset. Again, this pre-vocalization activity is dificult to interpret without the kinematic measures.

# %%
#Load data
pth = '/Users/david_conant/Dropbox/EC82/EC82.prod.hVd.B21_38_40_44.align1_2.neural.h5'
f = BrainDataFile(pth , 'r')
i = f.data().internal()
e = i.ecog_data_processed(0)
e_z = brainBaseline(e)
notes = np.array(e.dims(axis = 'channels', get_hdf = False)[1]['dataset'])
#Slice data
vow = ['HAWED','HEED','WHOOD']
Ds = [];
for v in vow:
    filt = np.where(notes == v)
    anno_data = e_z[:,:,filt[0]]
    Ds.append(anno_data[:,0:400,:])

# %%
ax = ev.plotERPs(Ds,align_window = np.array([-0.5,1]), anatomy=np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset']),labels = vow)

# %% [markdown]
# As for his AA/IY/UW comparative ERPs, they are disappointing; I don't see any eelctrodes taht show significant results between vowels. Most likely candidates:

# %%
ax = ev.plotERPs(Ds,align_window = np.array([-0.5,1]), anatomy=np.array(e.dims(axis = 'space',
    get_hdf = False)[2]['dataset']),labels = vow, elects =[135,136])

# %% [markdown]
# Looks like 136 has a preference for IY, that's about it. From these results, I don't think EC82 is going to be a good subject.

# %% [markdown]
# All Vowel ERPs
# --
# Last time I only showed you the AA/IY/UW distinction, what do the ERPs look like when you expand to all vowels?

# %% [markdown]
# #####EC56

# %%
#Load Data
pth = '/Users/david_conant/Dropbox/EC56/EC56.prod.hVd.B75_77.align1_2.neural.h5'
f = BrainDataFile(pth , 'r')
i = f.data().internal()
e = i.ecog_data_processed(0)
e_z = brainBaseline(e)
#Slice data
vow = np.unique(np.array(e.dims(axis = 'channels', get_hdf = False)[1]['dataset']))
annot1 = e.annotations(1)
Ds = [];
for v in vow:
    filt = annot1.description_contains_filter(v)
    a = annot1[filt]
    anno_data, anno_types, anno_descriptions, annos = a.data(stack=True)
    Ds.append(anno_data[:,100:400,:])

# %%
ev.plotERPs(Ds,align_window = np.array([-0.5,1]),anatomy=np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset']),
            labels = vow, yscale = [0.25,4])

# %%
Ds[7].shape

# %% [markdown]
# Looks like there are some difference, but damn, there is just across the board preference for 'HOOD', for both perception and production. I don't believe this is real, you even see higher values for 'UH' on electrodes that don't appear to modulate. I would guess this might be a baselining issue, but it's curious because none of the data transformations up to this point have any knowledge of the vowel category. I'll continue to look into it.
#
# For whatever it's worth, 'UH' tends to be one of the more difficult vowels for people to produce.
#
# Zooming in on thoes electrodes that might have differences outside of 'UH':

# %%
    ev.plotERPs(Ds,align_window = np.array([-0.5,1]),anatomy=np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset']),
            labels = vow, yscale = [0.5,4],elects = [102,119,120,69,74,75,8,181])

# %% [markdown]
# It looks like that for this subject the differences are very subtle and tend to occur after the onset of the vowel (Presumably feedback or word-ending)

# %% [markdown]
# #####EC41

# %%
#Load Data
pth = '/Users/david_conant/Dropbox/EC41/EC41.prod.hVd.B19_20_22_27.align1_2.neural.h5'
f = BrainDataFile(pth , 'r')
i = f.data().internal()
e = i.ecog_data_processed(0)
e_z = brainBaseline(e)
#Slice data
vow = np.unique(np.array(e.dims(axis = 'channels', get_hdf = False)[1]['dataset']))
annot1 = e.annotations(1)
Ds = [];
for v in vow:
    filt = annot1.description_contains_filter(v)
    a = annot1[filt]
    anno_data, anno_types, anno_descriptions, annos = a.data(stack=True)
    Ds.append(anno_data[:,100:400,:])

# %%
ev.plotERPs(Ds,align_window = np.array([-0.5,1]),anatomy=np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset']),
            labels = vow, yscale = [0.25,4])

# %% [markdown]
# Again, across the board preference for HOOD; either I have a bug somewhere, or the brain just really likes 'UH'
#
# Zooming in:

# %%
ev.plotERPs(Ds,align_window = np.array([-0.5,1]),anatomy=np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset']),
            labels = vow, yscale = [0.25,4],elects = [86,73,75])

# %% [markdown]
# #####EC50

# %%
#Load Data
pth = '/Users/david_conant/Dropbox/EC50/EC50.prod.hVd.B21_22_25_76.align1_2.neural.h5'
f = BrainDataFile(pth , 'r')
i = f.data().internal()
e = i.ecog_data_processed(0)
e_z = brainBaseline(e)
#Slice data
vow = np.unique(np.array(e.dims(axis = 'channels', get_hdf = False)[1]['dataset']))
annot1 = e.annotations(1)
Ds = [];
for v in vow:
    filt = annot1.description_contains_filter(v)
    a = annot1[filt]
    anno_data, anno_types, anno_descriptions, annos = a.data(stack=True)
    Ds.append(anno_data[:,100:400,:])

# %%
ev.plotERPs(Ds,align_window = np.array([-0.5,1]),anatomy=np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset']),
            labels = vow, yscale = [0.25,6])

# %% [markdown]
# Still a preference for 'UH' here, but the scales are much more reasonable. Several electrodes that look like they have variety between vowels.

# %%
ev.plotERPs(Ds,align_window = np.array([-0.5,1]),anatomy=np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset']),
            labels = vow, yscale = [0.25,6], elects = [206,189,190,173,156,155,142,143,126,127])

# %% [markdown]
# Looks like the same basic pattern for all of UH/AE/IH/ then the rest crowded together.

# %% [markdown]
# #####EC82

# %%
#Load Data
pth = '/Users/david_conant/Dropbox/EC82/EC82.prod.hVd.B21_38_40_44.align1_2.neural.h5'
f = BrainDataFile(pth , 'r')
i = f.data().internal()
e = i.ecog_data_processed(0)
e_z = brainBaseline(e)
#Slice data
vow = np.unique(np.array(e.dims(axis = 'channels', get_hdf = False)[1]['dataset']))
annot1 = e.annotations(1)
Ds = [];
for v in vow:
    filt = annot1.description_contains_filter(v)
    a = annot1[filt]
    anno_data, anno_types, anno_descriptions, annos = a.data(stack=True)
    Ds.append(anno_data[:,100:400,:])

# %%
ev.plotERPs(Ds,align_window = np.array([-0.5,1]),anatomy=np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset']),
            labels = vow, yscale = [-0.5,1])

# %% [markdown]
# Preference for 'UH', but very little distinction otherwise. Zoom in:

# %%
ev.plotERPs(Ds,align_window = np.array([-0.5,1]),anatomy=np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset']),
            labels = vow, yscale = [-1,1], elects = [198,199,120,182,135,136])

# %% [markdown]
# Yeah, not much difference between vowels. I don't think EC82 will be a good subject for us.

# %% [markdown]
# Vowel Space comparisons
# --
# Now that we've verified some differences in the ERPs, let's characterize these differences better. Using LDA to reduce dimensionality of neural data, how do vowels cluster in this space? And how does that compare to the Acoustic LDA space?

# %%
#Intitialize
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import ecog_viz as ev
import numpy as np
import scipy as sp
import matplotlib as mpl
from brain.dataformat.brainformat import *
from matplotlib import pyplot as plt
import numpy as np
from brain_utils import brainBaseline
import pandas as pd
from BDutils import ProgressBar
from DCstats import LDA_class
from Smooth import savitzky_golay
import prettyplotlib as ppl
import brewer2mpl
import matplotlib.gridspec as gridspec
import seaborn as sns

# %%
def LDA_timecourse(pth1,pth2):
    #Load Data
    f = BrainDataFile(pth1 , 'r')
    i = f.data().internal()
    e = i.ecog_data_processed(0)
    e_z = brainBaseline(e)

    f = BrainDataFile(pth2 , 'r')
    i = f.data().internal()
    a = i.ecog_data_processed(0)
    chans = np.array(e.dims(axis = 'space',get_hdf = False)[0]['dataset'])
    notes = np.array(e.dims(axis = 'channels', get_hdf = False)[1]['dataset'])
    forms = np.array(a.dims(axis = 'space', get_hdf = False)[0]['dataset'])

    LDA_score_e = np.empty((100,50))
    p = ProgressBar(50)
    for i,t in enumerate(range(0,500,10)):
        p.animate(i)
        win_e = pd.DataFrame(np.nanmean(e_z[:,t:t+20,:],axis = 1).transpose(),columns = chans, index = notes)
        win_e = win_e.fillna(win_e.median(),inplace=True)
        win_e = win_e.dropna(axis =1,how='any')
        LDA_score_e[:,i] = LDA_class(win_e.values,win_e.index)

    LDA_score_f = np.empty((100,50))
    sec = np.empty((50,1))
    p = ProgressBar(50)
    for i,t in enumerate(range(0,250,5)):
        p.animate(i)
        win_f = pd.DataFrame(np.nanmean(a.ecog_data()[:,t:t+10,:],axis = 1).transpose(), index = notes)
        win_f = win_f.fillna(win_f.median(),inplace=True)
        win_f = win_f.dropna(axis =1,how='any')
        LDA_score_f[:,i] = LDA_class(win_f.values,win_f.index)
        sec[i] = (t - 100)/100*1000+100
    f_mean = savitzky_golay(np.nanmean(LDA_score_f,axis = 0),5,3)
    f_se = np.nanstd(LDA_score_f,axis=0)/LDA_score_f.shape[0]
    e_mean = savitzky_golay(np.nanmean(LDA_score_e,axis = 0),11,3)
    e_se = np.nanstd(LDA_score_e,axis=0)/LDA_score_e.shape[0]
    max_f = np.argmax(f_mean,axis = 0)  
    max_f_win = np.arange(max_f*5-10,max_f*5+10)
    max_e = np.argmax(e_mean,axis = 0)
    max_e_win = np.arange(max_e*10-20,max_e*10+20)
    
    t = np.arange(50)*50-1000
    f_proj = pd.DataFrame(np.nanmean(a.ecog_data()[:,max_f_win,:],axis = 1).transpose(),columns = forms, index = notes)
    f_proj = f_proj.fillna(f_proj.median(),inplace=True)
    f_proj = f_proj.dropna(axis =1,how='any')

    e_proj = pd.DataFrame(np.nanmean(e.ecog_data()[:,max_e_win,:],axis = 1).transpose(),columns = chans, index = notes)
    e_proj = e_proj.fillna(e_proj.median(),inplace=True)
    e_proj = e_proj.dropna(axis =1,how='any')

    fig = plt.figure(figsize = (15,45))
    
    c0,c1,c2 = brewer2mpl.get_map('Set1', 'qualitative', 3).mpl_colors
    gs1 = gridspec.GridSpec(6,3)
    #gs1.update(left=0.05, right=.95, wspace=0.05)
    sns.set_style('darkgrid')
    sns.set_context('talk')
    
    ax1 = plt.subplot(gs1[0,:])
    ax2 = plt.subplot(gs1[1,:])

    ppl.plot(t,f_mean,ax = ax1,color = c1)
    ppl.fill_between(t,f_mean-f_se,f_mean+f_se,ax=ax1,color = c1)
    ppl.plot([max_f*50 - 1000,max_f*50 - 1000],[ax1.get_ylim()[0],ax1.get_ylim()[1]],ax = ax1);
    ax1.set_ylabel('Formant LDA Classification')
    ax1.set_xticklabels([]);

    ppl.plot(t,e_mean,ax = ax2, color = c2)
    ppl.fill_between(t,e_mean-e_se,e_mean+e_se,ax=ax2,color = c2)
    ppl.plot([max_e*50 - 1000,max_e*50 - 1000],[ax2.get_ylim()[0],ax2.get_ylim()[1]],ax = ax2);
    ax2.set_xlabel('time (ms)')
    ax2.set_ylabel('Neural LDA Classification')


    sns.set_style('white')
    sns.set_context('talk')
    sns.set_palette('Set1', n_colors = 9)

    ax3 = plt.subplot(gs1[2:4,:])
    ax3.set_xlabel('Formant LD1')
    ax3.set_ylabel('Formant LD2')
    ev.LDA_proj_scatter(f_proj)

    
    ax4 = plt.subplot(gs1[4:6,:])
    ax4.set_xlabel('Neural LD1')
    ax4.set_ylabel('Neural LD2')
    ev.LDA_proj_scatter(e_proj)

# %% [markdown]
# #####EC56

# %%
pth1 = '/Users/david_conant/Dropbox/EC56/EC56.prod.vow.B75_77.align1_1.neural.h5'
pth2 = '/Users/david_conant/Dropbox/EC56/EC56.prod.vow.B75_77.align1_1.form.h5'
LDA_timecourse(pth1,pth2)

# %% [markdown]
# To orient you, at the top we have timecourse of LDA classification performance as we take windows moving across the trial. A higher value indicates that the vowels are more separable in this data slice. The formants make sense, peaking sharply just after acoustic onset. That is consistent with what we saw in the behavior paper. The neural timecourse is interesting, as it peaks just after the acoustic, but starts to ramp up earlier.
#
# The bottom two scatter plots are the projections into 2D LD space for the Formants and for the Neural. The formants look in line with our behavior paper results, although a bit messier. The neural space is harder to say. If you squint the corner vowels are in the right place, as are a few others. It's clearly not exactly the acoutsics, but it does seeem to share some organization. What is needed is a method to quantify the degree to which the organization is similar. The way I plan to do this  is to take the centroid of each vowel in a given LD space, then calculate the pairwise distance between that vowel and all other vowels. This will result in a matrix of pairwise distances between vowels for a given space. We can then compare the organization between two spaces by subtracting those matrices from one another. Low values in the resulting matrix indicate that those two vowels are similarly spaced in the two spaces. With this we can say which vowels have similar organiation regardless of scale, rotation, or translations. I'm working on this now.

# %% [markdown]
# #####EC41

# %%
pth1 = '/Users/david_conant/Dropbox/EC41/EC41.prod.vow.B19_20_22_27.align1_1.neural.h5'
pth2 = '/Users/david_conant/Dropbox/EC41/EC41.prod.vow.B19_20_22_27.align1_1.form.h5'
LDA_timecourse(pth1,pth2)

# %% [markdown]
# Similar results as above, but the timecourse of neural classification is steeper. Similar difficulty interpreting results between formants and nueral.

# %% [markdown]
# #####EC50

# %%
pth1 = '/Users/david_conant/Dropbox/EC50/EC50.prod.vow.B21_22_25_76.align1_1.neural.h5'
pth2 = '/Users/david_conant/Dropbox/EC50/EC50.prod.vow.B21_22_25_76.align1_1.form.h5'
LDA_timecourse(pth1,pth2)

# %% [markdown]
# In this case the neural and acoustics peak at the same time, but the neural still has a more gradual and earliser rise.
#
# Spaces are similar to before, although neural data doesnt have great clustering.

# %% [markdown]
# #####EC82

# %%
pth1 = '/Users/david_conant/Dropbox/EC82/EC82.prod.vow.B21_38_40_44.align1_1.neural.h5'
pth2 = '/Users/david_conant/Dropbox/EC82/EC82.prod.vow.B21_38_40_44.align1_1.form.h5'
LDA_timecourse(pth1,pth2)

# %% [markdown]
# EC82's results don't look great, but that's to be expected from our previous observations about lack of differences in the ERPs. Neural classification doesn't have a clear peak, and the spaces are very jumbled.

# %% [markdown]
# #####Conclusions:
#     -EC82 doesn't show categorical differences, and likely won't be useful for analyses based on vowel category
#     -ERPs with all vowels show strange preference for 'HOOD', the degree of which varies between subjects. I think this must be from a bug in my code somewhere. There are other differences between vowels, but they are inconsistent between subjects with resepect to time, magnitude, and order. This is in line my previous observations that categorical behavior may not be consistent across subjects because their underlying articulatory behavior is different. Adding articulatory measures will help clear this up.
#     -LDA classification performance timecourses show fairly consistent timing of vowel structure in acoustic and neural data. Neural tends to start ramping up before acoustics, which is consistent with pre-articulation or planning. Neural tends to peak after acoustics, maybe because of feedback activity.
#     -LDA projections at peak classification performance show expected organization of vowels for the acosutics and some degree of similarity with the neural organization, however we need a way of quantifying this similarity.
#
#     -Next Steps:
#     1) Look into 'HOOD' preference issue in ERPs
#     2) Add more subjects (EC34 and 84 are left)
#     3) Quantify vowel organization using pair-wise distances
#     4) Process collected articulatory data for subjects

# %% [markdown]
# ---------

# %% [markdown]
# ##Update - 5/4/15

# %% [markdown]
# ERPs
# --
#
# Before we do anything else, we want to see if neural activity reflects behavior in any way. Without this, any more complex analyses likely will not produce results.

# %%
#Intiialize
# %load_ext autoreload
# %autoreload 2
import sys
import ecog_viz as ev
import numpy as np
from brain_utils import brainBaseline
sys.path.append("/Users/david_conant/Dropbox/changrepo/python/brain")
from brain.dataformat.brainformat import *
from IPython.display import Image

# %%
#Load Data
pth = '/Users/david_conant/Dropbox/EC56/EC56.prod.vow.B75_77.align1_1.neural.h5'
f = BrainDataFile(pth , 'r')
i = f.data().internal()
e = i.ecog_data_processed(0)
e_z = brainBaseline(e)

# %% [markdown]
# ###Across all trials

# %% [markdown]
# #####EC56
#    Right Grid

# %%
Image(filename = '/Users/david_conant/Dropbox/NeuroSpeech/ChangLab/General Patient Info/EC56/brain+grid_3Drecon.png')

# %%
#Load Data
pth = '/Users/david_conant/Dropbox/EC56/EC56.prod.hVd.B75_77.align1_2.neural.h5'
f = BrainDataFile(pth , 'r')
i = f.data().internal()
e = i.ecog_data_processed(0)
e_z = brainBaseline(e)
ev.plotERPs([np.array(e_z[:,0:400,:])],align_window = np.array([-1,1]),anatomy=np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset']))

# %% [markdown]
# To orient you, the background colors denote the anatomy: Blue is precentral, orange is postcentral, green is STG, and purple is other. Front of the brain is to the right. The data shown is for the HvD context, aligned to the onset of the vowel, with 0.5 sec before and 1 sec after.
#
# We can see robust activation locked to onset of the vowel from several electrodes primarily in ventral and dorsal precentral gyrus. Reminds me of the somatotopy of the larynx.
# There also seems to be a focus of electrodes in postcentral that are active about half a second after the vowel onset. Could be related to feedback, or perhaps the execution of the 'D', or even locked to word ending.

# %% [markdown]
# #####EC41
#    Right Grid

# %%
Image(filename = '/Users/david_conant/Dropbox/NeuroSpeech/ChangLab/General Patient Info/EC41/brain+grid_3Drecon.png')

# %%
pth = '/Users/david_conant/Dropbox/EC41/EC41.prod.hVd.B19_20_22_27.align1_2.neural.h5'
f = BrainDataFile(pth , 'r')
i = f.data().internal()
e = i.ecog_data_processed(0)
e_z = brainBaseline(e)
ev.plotERPs([np.array(e_z[:,0:400,:])],align_window = np.array([-1,1]),anatomy=np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset']))

# %% [markdown]
# Pretty robust activations in ventral and dorsal vSMC. Many active electrodes. Similar to EC56, these are mostly in pre-central while post-central are active later.

# %% [markdown]
# #####EC50
# Right Grid

# %%
Image(filename = '/Users/david_conant/Dropbox/NeuroSpeech/ChangLab/General Patient Info/EC50/brain+grid_3Drecon.png')

# %%
pth = '/Users/david_conant/Dropbox/EC50/EC50.prod.hVd.B21_22_25_76.align1_2.neural.h5'
f = BrainDataFile(pth , 'r')
i = f.data().internal()
e = i.ecog_data_processed(0)
e_z = brainBaseline(e)
ev.plotERPs([np.array(e_z[:,100:400,:])],align_window = np.array([-0.5,1]),anatomy=np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset']))

# %% [markdown]
# I haven't generated the anatomy file for EC50 yet, but she shows large and sustained activations for production primarily around the central sulcus. Not sure why the activity is high for such a long period. I'll have to regenerate the files with a longer time period before and after to get a beter sense of the timecourse. Not sure if it will concretely explain anything, but this was our German speaker and her pronounciation of the vowels was pretty atypical and she tended to really elongate her productions.

# %% [markdown]
# #####Conclusions:
#     -All subjects exhibit obvious modulation around the onset of the vowel in approximately the same regions.
#     -Some inter-subject variaiblity with timing that needs to be explored further.

# %% [markdown]
# ###By Vowel Type
#
# First, for the sake of clarity, starting with just the corner vowels

# %% [markdown]
# #####EC56

# %%
#Load data
pth = '/Users/david_conant/Dropbox/EC56/EC56.prod.hVd.B75_77.align1_2.neural.h5'
f = BrainDataFile(pth , 'r')
i = f.data().internal()
e = i.ecog_data_processed(0)
e_z = brainBaseline(e)
notes = np.array(e.dims(axis = 'channels', get_hdf = False)[1]['dataset'])
#Slice data
vow = ['HAWED','HEED','WHOOD']
Ds = [];
for v in vow:
    filt = np.where(notes == v)
    anno_data = e_z[:,:,filt[0]]
    Ds.append(anno_data[:,0:400,:])

# %%
ax = ev.plotERPs(Ds,align_window = np.array([-1,1]),yscale = [.37,4.5], anatomy=np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset']),labels = vow)

# %% [markdown]
# Several electrodes show differences between categories. Interestingly, almost all of them are in the post-central gyrus, which is where we saw average activity mostly after the onset of the vowel. However, the differences between category exist primarily before the onset of the vowel and was presumably washed out in the average.

# %%
ax = ev.plotERPs(Ds,align_window = np.array([-1,1]),yscale = [.37,4.5],anatomy=np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset']),labels = vow,elects = [101,121,122])

# %% [markdown]
# These electrodes show an ordering of AA UW IY, which is consistent with coding for tongue height. In all cases, these differences start at least 500 ms before the onset of the vowel. The consonant 'H' usually only exists for about 300 ms, so some of this activity may be due to prearticulation or planning. Looking at the actual kinematics will help us determine which.

# %%
ax = ev.plotERPs(Ds,align_window = np.array([-1,1]),yscale = [.37,4.5],anatomy=np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset']),labels = vow,elects = [120])

# %% [markdown]
# This electrode seems to care about IY and UW but not AA. Not sure how to interpret this.

# %%
ax = ev.plotERPs(Ds,align_window = np.array([-1,1]),yscale = [.37,4.5],anatomy=np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset']),labels = vow,elects = [102])

# %% [markdown]
# The electrode as the order of AA, UW, IY. This would roughly correspond to front tongue height? Again, unclear on it's own

# %%
ax = ev.plotERPs(Ds,align_window = np.array([-1,1]),yscale = [.37,4.5],anatomy=np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset']),labels = vow,elects = [8,9])

# %% [markdown]
# Finally there are these two electrodes in Broca's that are selective for UW primarily prior to the onset of the vowel. Lip movement planning?

# %% [markdown]
# #####EC41

# %%
#Load data
pth = '/Users/david_conant/Dropbox/EC41/EC41.prod.hVd.B19_20_22_27.align1_2.neural.h5'
f = BrainDataFile(pth , 'r')
i = f.data().internal()
e = i.ecog_data_processed(0)
e_z = brainBaseline(e)
notes = np.array(e.dims(axis = 'channels', get_hdf = False)[1]['dataset'])
#Slice data
vow = ['HAWED','HEED','WHOOD']
Ds = [];
for v in vow:
    filt = np.where(notes == v)
    anno_data = e_z[:,:,filt[0]]
    Ds.append(anno_data[:,0:400,:])

# %%
ax = ev.plotERPs(Ds,align_window = np.array([-1,1]),yscale = [0.4,4.5],anatomy=np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset']),labels = vow)

# %% [markdown]
# EC41, despite her clean average ERPs, doesn't have many electrodes that show differences between vowels. Also, despite the similarity in average ERPs with EC56, these electrodes are mostly in pre-central.

# %%
ax = ev.plotERPs(Ds,align_window = np.array([-1,1]),yscale = [.37,4.5],anatomy=np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset']),labels = vow,elects = [36,37])

# %% [markdown]
# These two electrodes in ventral precentral show a rather modest distinction betwen AA/IY and UW

# %%
ax = ev.plotERPs(Ds,align_window = np.array([-1,1]),yscale = [.37,4.5],anatomy=np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset']),labels = vow,elects = [86])

# %% [markdown]
# Here there is a difference first with AA, then with AA/IY, both after the onset of the vowel.

# %%
ax = ev.plotERPs(Ds,align_window = np.array([-1,1]),yscale = [.37,4.5],anatomy=np.array(e.dims(axis = 'space', get_hdf = False)[2]['dataset']),labels = vow,elects = [73])

# %% [markdown]
# Pretty clear preference for UW, but again only after the onset of the vowel.

# %% [markdown]
# #####EC50

# %%
#Load data
pth = '/Users/david_conant/Dropbox/EC50/EC50.prod.hVd.B21_22_25_76.align1_2.neural.h5'
f = BrainDataFile(pth , 'r')
i = f.data().internal()
e = i.ecog_data_processed(0)
e_z = brainBaseline(e)
notes = np.array(e.dims(axis = 'channels', get_hdf = False)[1]['dataset'])
#Slice data
vow = ['HAWED','HEED','WHOOD']
Ds = [];
for v in vow:
    filt = np.where(notes == v)
    anno_data = e_z[:,:,filt[0]]
    Ds.append(anno_data[:,0:400,:])

# %%
ax = ev.plotERPs(Ds,align_window = np.array([-1,1]),anatomy = np.array([]),labels = 'vow')

# %% [markdown]
# The single vowel traces resemble the averages, with long timecourses on the same electrodes.

# %%
ax = ev.plotERPs(Ds,align_window = np.array([-0.5,1]),anatomy = np.array([]),labels = vow,elects = [189, 173, 155])

# %% [markdown]
# These electrodes all show a preference for UW/IY, although at different time points

# %%
ax = ev.plotERPs(Ds,align_window = np.array([-0.5,1]),anatomy = np.array([]),labels = vow,elects = [156,206])

# %% [markdown]
# These two show sustained preference for UW. 207 is odd in that this seems to be flat throughout the time period. Again, extending the time range will help clear this up.
#
# 157 is also kind of interesting in that the diffrences with UW are diminished around the onset of the vowel. This is curious as the only thing that's likely happening at the onset of the vowel is vocal onset (people tend to prearticulate their tongue and lips during the H). Could make sense if the electrode were coding lips and larynx (all vowels are approximately the same pitch so that activity would presumably reduce differences from lip activity.)

# %% [markdown]
# #####Conclusions:
#     -All subjects exhibit some degree of categorical ERP differences, but these differences are rather inconsistent between subjects.
#     -It seems that there may not be a consistent encoding scheme at the level of individual electrodes. This makes some degree of sense as vowels movements aren't well represented by any one dimension. What is needed, then, is to examine encoding using a method that can account for differences across many dimensions (i.e. Looking at vowels in dimensionaly reduced space such as PCA or MDS, and regression models)
#     -Next steps: 1) Add more subjects, 2) Look at electrodes with all vowels plotted, 3) Comparing neural to acoustic and kinematics spaces using dimensionality reduction

# %% [markdown]
# ###All vowels

# %% [markdown]
# **There's a bug in my code that's keeping me from generating these at the moment**

# %% [markdown]
# Vowel Space comparisons
# --
# ######Neural vs Acoustics vs Kinematics

# %% [markdown]
# #####What do the LDA spaces look like at peak classification?

# %% [markdown]
# Behavior
# --
# Timecourses of Kinematics and Acoustics

# %% [markdown]
# Basic Decoding/Encoding of Kinematic and Acoustic Features
# --

# %% [markdown]
# Trial by Trial variability
# --
# a la Kris's Vowel Paper

# %% [markdown]
# Preparation and planning
# --
# raster of single trial erps from stimulus to go cue to execution
