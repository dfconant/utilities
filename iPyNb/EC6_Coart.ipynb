# %% [markdown]
# Behavioral Characterization
#
#     XEdit Artic_GUI to output better measuresX
#     -averages over time -> Need to remake D mats to fix categories, maybe         try the ellipse?
#     -onsets and offsets of movement ->
#     -Include single word trials

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import matplotlib as mpl
import Smooth as sm
import scipy.ndimage.filters as flt
import scipy as sp
import numpy as np
from scipy import stats
import coloring
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cmx
import Dtransform as dt
import mat2py
import CoartBehavior as cb
import seaborn as sns
import pandas as pd

# %%
dataFile = '/Users/david_conant/Dropbox/NeuroSpeech/Coart/EC6.prod.Coart2.B50_55_58_64_65.align2_-3.kin.Scaled.Transformed.mat'
labs,k,wlist = mat2py.loadh5(dataFile,['labs','kinY','wlist'],['ndarray','ndarray','ndarray'])
flabs = ['Lip Upper','Lip Lower','Lip Right','Lip Left','Nose X','Nose Y','Jaw Y','Jaw X','Lip Rounding']
lr = cb.defineRounding(k)
k = np.concatenate((k,lr),0)
badT = cb.id_bad_trials(lr,threshold = 200)
k = k[:,:,~badT]
k = dt.D2panel(k,[flabs,[map(str,range(k.shape[1]))],[map(str,range(k.shape[2]))]])

# %%
sns.tsplot(k[5,:,:],err_style="unit_traces")

# %%
badT.shape
# Out:
# (225,)

# %%
def sine_wave(n_x, obs_err_sd=1.5, tp_err_sd=.3):
    x = np.linspace(0, (n_x - 1) / 2, n_x)
    y = np.sin(x) + np.random.normal(0, obs_err_sd) + np.random.normal(0, tp_err_sd, n_x)
    return y
sines = np.array([sine_wave(31) for _ in range(20)])

# %%
sns.tsplot(sines)

# %% [markdown]
# ERPs
#
#     -Compare across align points
#     -Inclide single word trials
#     -Compare IY vs UW trials

# %% [markdown]
# Electrodes that follow Lip Rounding
#
#     -mean(Behavior - HG) across trials
#     -Encoding model (allows for linear scaling)

# %%
# %load_ext autoreload
# %autoreload 2
import h5py
import CoartBehavior as cb
import CoartEncoding as ce
import matplotlib.pyplot as plt
import scipy as sp
import numpy as np
from scipy import stats
from scipy import signal
import mat2py
import DCstats
import Dtransform as dt

dataFile = '/Users/david_conant/Dropbox/NeuroSpeech/Coart/EC6.prod.Coart2.B50_55_58_64_65.align2_-3.kin.Scaled.Transformed.mat'
labs,k = mat2py.loadh5(dataFile,['labs','kinY'],['ndarray','ndarray'])
tmp = cb.defineRounding(k)
badT = cb.id_bad_trials(tmp,threshold = 2)
lr = tmp[:,:,~badT]

dataFile = '/Users/david_conant/Dropbox/NeuroSpeech/Coart/EC6.prod.Coart2.B50_55_58_64_65.align2_-3.neural.cleaned.mat'
b,tmp,baseline = mat2py.loadh5(dataFile,['block','neuralY','baseline'],['ndarray','ndarray','list'])
e = tmp[:,:,~badT]
block = b[~badT]
e = DCstats.baselinez(e,baseline,block)

anat = sp.io.loadmat('/Users/david_conant/Dropbox/NeuroSpeech/Coart/EC6_anatomy.mat')
vsmc = np.concatenate([anat['anatomy'][0][0][3],anat['anatomy'][0][0][4]],axis=1)
stg = anat['anatomy'][0][0][6]
vsmc = vsmc -1; stg = stg -1;

#Linearly interpolate behavior to match fs of neural
lr = signal.resample(lr,e.shape[1],axis = 1)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
i = 220
scatter(e[1,:,i],lr[:,:,i])

# %%
e_lag, lr_lag = dt.D2laggedTS(e,lr,400,range(-200,200,10),200)

# %%
for i in range(lr.shape[2]):
    plot(lr[0,:,i])

# %%
# encoding regression
R2 = ce.lip_follow(e,lr,'regress',vsmc)
# Out:
# 56
# 70
# 71
# 72
# 73
# 74
# 86
# 87
# 88
# 89
# 90
# 91
# 92
# 93
# 94
# 95
# 103
# 104
# 105
# 106
# 107
# 108
# 109
# 110
# 111
# 119
# 120
# 121
# 122
# 123
# 124
# 125
# 126
# 135
# 136
# 137
# 138
# 139
# 140
# 141
# 142
# 151
# 152
# 153
# 154
# 155
# 156
# 157
# 158
# 159
# 171
# 172
# 173
# 174
# 175
# 189
# 190
# 191
# 207

# %%
e_lag, lr_lag = dt.D2laggedTS(e,lr,400,range(-200,200,10),200)

# %%
plt.plot(R2[7,:])

# %%
X = lr_lag.transpose();
Y = np.atleast_2d(e_lag[1, :, 11]).transpose()

X[30,0] = nan

badx = np.any(np.isnan(X),1)
bady = np.any(np.isnan(Y),1)
badObs = np.any([badx,bady],0)
X = X[~badObs, :]
Y = Y[~badObs, :]

# %% [markdown]
# Lip Rounding Decoding through time

# %%
R2.shape
# Out:
# (256, 40)

# %% [markdown]
# Comparison to single word trials

# %%
D2[:, w, :].reshape(D2.shape[0], t_length)

# %%
D1.shape[0], t_length

# %%
D2[:, w, :].shape

# %%
Y = e_lag[1,:,20].transpose()
X = lr_lag.transpose()
Y.shape = [X.shape[0],1]

from sklearn import linear_model
from sklearn.cross_validation import train_test_split

#Remove trials with NaN
badx = any(np.isnan(X),1)
bady = any(np.isnan(Y),1)
badObs = any([badx,bady],0)
X = X[~badObs, :]
Y = Y[~badObs, :]
    
#split into train and test
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2)

#iterate through features
R2 = np.empty(Y.shape[1])
coef = np.empty([X.shape[1],Y.shape[1]])
regr = linear_model.LinearRegression()
for feat in range(Y.shape[1]):
    regr.fit(X_train,Y_train[:,feat])
    R2[feat] = regr.score(X_test,Y_test)
    coef[:,feat] = regr.coef_
