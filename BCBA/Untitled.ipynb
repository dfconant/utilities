# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import numpy as np
from numpy.random import multivariate_normal
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set_style('white')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
np.tile(np.linspace(0,1,6),(2,1)).shape
# Out:
# (2, 6)

# %%
means = np.tile(np.linspace(0,1,6),(2,1))
cov = [[.01, 0], [0, .01]]
dat = [multivariate_normal(means[:,i],cov,(40)) for i in range(6)]

# %%
plt.figure(figsize=(7,7))
[plt.scatter(dat[i][:,0],dat[i][:,1],c='k') for i in range(6)]
plt.axis('equal')
# Out:
# (-0.40000000000000002,
#  1.3999999999999999,
#  -0.40000000000000002,
#  1.3999999999999999)

# %%
plt.figure(figsize=(7,7))
cmap = ['r','r','g','g','b','b']
[plt.scatter(dat[i][:,0],dat[i][:,1],c=cmap[i]) for i in range(6)]
plt.axis('equal')
# Out:
# (-0.40000000000000002,
#  1.3999999999999999,
#  -0.40000000000000002,
#  1.3999999999999999)

# %%
plt.figure(figsize=(7,7))
cmap = ['r','r','g','g','b','b']
marker = ['o','*','o','*','o','*']
[plt.scatter(dat[i][:,0],dat[i][:,1],c=cmap[i],marker=marker[i]) for i in range(6)]
plt.axis('equal')
# Out:
# (-0.40000000000000002,
#  1.3999999999999999,
#  -0.40000000000000002,
#  1.3999999999999999)

# %%
plt.figure(figsize=(7,7))
cmap = ['r','r','g','g','b','b']
marker = ['o','*','o','*','o','*']
alpha = np.linspace(.3,1,6)
[plt.scatter(dat[i][:,0],dat[i][:,1],c=cmap[i],marker=marker[i],alpha=alpha[i]) for i in range(6)]
plt.axis('equal')
# Out:
# (-0.40000000000000002,
#  1.3999999999999999,
#  -0.40000000000000002,
#  1.3999999999999999)

# %%
white = pd.read_csv('winequality-white.csv',sep=';')

# %%
sns.pairplot(white)

# %%
white.columns
# Out:
# Index([u'fixed acidity', u'volatile acidity', u'citric acid',
#        u'residual sugar', u'chlorides', u'free sulfur dioxide',
#        u'total sulfur dioxide', u'density', u'pH', u'sulphates', u'alcohol',
#        u'quality'],
#       dtype='object')

# %%
sns.jointplot(y='quality',x='alcohol',data=white)

# %%
sns.jointplot(y='quality',x='density',data=white)

# %%
sns.jointplot(y='quality',x='total sulfur dioxide',data=white)

# %%
red = pd.read_csv('winequality-red.csv',sep=';')
sns.pairplot(red)

# %%
fb = pd.read_csv('dataset_Facebook.csv',sep=';')
fb.fillna(fb.median(),inplace=True)
fb.columns
# Out:
# Index([u'Page total likes', u'Type', u'Category', u'Post Month',
#        u'Post Weekday', u'Post Hour', u'Paid', u'Lifetime Post Total Reach',
#        u'Lifetime Post Total Impressions', u'Lifetime Engaged Users',
#        u'Lifetime Post Consumers', u'Lifetime Post Consumptions',
#        u'Lifetime Post Impressions by people who have liked your Page',
#        u'Lifetime Post reach by people who like your Page',
#        u'Lifetime People who have liked your Page and engaged with your post',
#        u'comment', u'like', u'share', u'Total Interactions'],
#       dtype='object')

# %%
sns.jointplot(y='Page total likes',x='Paid',data=fb)

# %%
sns.jointplot(y='Total Interactions',x='Post Month',data=fb)

# %%
transfusion = pd.read_csv('transfusion.csv',sep=',')
sns.pairplot(transfusion)

# %%
transfusion = pd.read_csv('Wholesale customers data.csv',sep=',')
sns.pairplot(transfusion)

# %%
mpg = pd.read_csv('auto_mpg.csv',delim_whitespace=True)
sns.pairplot(mpg)

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  model  \
# 0    18.0          8         307.0       130.0  3504.0          12.0     70
# 1    15.0          8         350.0       165.0  3693.0          11.5     70
# 2    18.0          8         318.0       150.0  3436.0          11.0     70
# 3    16.0          8         304.0       150.0  3433.0          12.0     70
# 4    17.0          8         302.0       140.0  3449.0          10.5     70
# 5    15.0          8         429.0       198.0  4341.0          10.0     70
# 6    14.0          8         454.0       220.0  4354.0           9.0     70
# 7    14.0          8         440.0       215.0  4312.0           8.5     70
# 8    14.0          8         455.0       225.0  4425.0          10.0     70
# 9    15.0          8         390.0       190.0  3850.0           8.5     70
# 10   15.0          8         383.0       170.0  3563.0          10.0     70
# ...
